# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts
from scipy.cluster.vq import vq, kmeans, whiten
import dataframe_image as dfi
import math
import seaborn as sns
from sklearn.cluster import KMeans

# %%
pd.set_option('display.float_format', lambda x: '%.0f' % x)

# %%
# Es importante mencionar que esta base de datos proviene de la última actualización en el Banco de Información de Telecomunicaciones
# del IFT, consultado el 19 de agosto de 2022. 
# Por este motivo se incluye en este repositorio esa versión de la base de datos a efectos de que si desea replicar el 
# resultado, lo haga con este conjunto de datos, toda vez que la información en el BIT podría variar sin previo aviso.

ingresos = pd.read_csv('TD_INGRESOS_TELECOM_ITE_VA.csv', encoding ='Latin1')
ingresos
# Out:
#       FOLIO  ANIO  TRIM      FECHA  \
# 0    100028  2021     1  15-mar-21
# 1    100028  2021     2  15-jun-21
# 2    100028  2021     3  15-sep-21
# 3    100028  2021     4  15DEC2021
# 4    100029  2021     1  15-mar-21
# ...     ...   ...   ...        ...
# 2456 999997  2014     4  15DEC2014
# 2457 999997  2015     1  15-mar-15
# 2458 999997  2015     2  15-jun-15
# 2459    NaN   NaN   NaN        NaN
# 2460    NaN   NaN   NaN        NaN
#
#                                    CONCESIONARIO K_EMPRESA  \
# 0                           ADOLFO MERINO MEDINA     C0089
# 1                           ADOLFO MERINO MEDINA     C0089
# 2                           ADOLFO MERINO MEDINA     C0089
# 3                           ADOLFO MERINO MEDINA     C0089
# 4                           AGUSTIN PEREZ VIEYRA     C0009
# ...                                          ...       ...
# 2456  MICRO SISTEMAS INTERNACIONAL, S.A. DE C.V.     C0384
# 2457  MICRO SISTEMAS INTERNACIONAL, S.A. DE C.V.     C0384
# 2458  MICRO SISTEMAS INTERNACIONAL, S.A. DE C.V.     C0384
# 2459                                         NaN       NaN
# 2460                                         NaN       NaN
#
#                           EMPRESA K_GRUPO                        GRUPO  \
# 0                        CABLEMAS    G004               GRUPO TELEVISA
# 1                        CABLEMAS    G004               GRUPO TELEVISA
# 2                        CABLEMAS    G004               GRUPO TELEVISA
# 3                        CABLEMAS    G004               GRUPO TELEVISA
# 4            AGUSTIN PEREZ VIEYRA    C009         AGUSTIN PEREZ VIEYRA
# ...                           ...     ...                          ...
# 2456  MICROSISTEMAS INTERNACIONAL    C384  MICROSISTEMAS INTERNACIONAL
# 2457  MICROSISTEMAS INTERNACIONAL    C384  MICROSISTEMAS INTERNACIONAL
# 2458  MICROSISTEMAS INTERNACIONAL    C384  MICROSISTEMAS INTERNACIONAL
# 2459                          NaN     NaN                          NaN
# 2460                          NaN     NaN                          NaN
#
#      I_FIJO_MOVIL INGRESOS_TOTAL_E I_ANUAL_TRIM
# 0            Fijo           389669   Trimestral
# 1            Fijo           407900   Trimestral
# 2            Fijo           416000   Trimestral
# 3            Fijo           434431   Trimestral
# 4            Fijo        797686.05   Trimestral
# ...           ...              ...          ...
# 2456         Fijo              NaN   Trimestral
# 2457         Fijo              NaN   Trimestral
# 2458         Fijo       720,000.00   Trimestral
# 2459          NaN              NaN          NaN
# 2460          NaN              NaN          NaN
#
# [2461 rows x 12 columns]

# %%
ingresos['GRUPO'].unique()
# Out:
# array(['GRUPO TELEVISA', 'AGUSTIN PEREZ VIEYRA',
#        'ARELY ISABEL GONGORA PECH', 'FRANCISCO GUERRA GARCIA',
#        'GABRIEL BUTRON CHIAPA', 'GUILLERMO MEDELLIN MILAN',
#        'GUILLERMO ZARATE GARCIA', 'ISALIA MORENO ZETINA',
#        'JAIME SANCHEZ SANCHEZ', 'JESUS MIGUEL FERNANDEZ GUERRERO',
#        'JOSE JULIAN SACRAMENTO GARZA', 'MANUEL LOPEZ AVILA',
#        'MARCO ANTONIO ROSALES HERRERA', 'ROBERTO LOPEZ BRAVO',
#        'SARA QUIROZ CHAPA', 'IUSACELL-UNEFÓN', 'LOGITEL', 'TV-K',
#        'TELEFÓNICA', 'TELECAB', 'ULTRAVISION', 'STARGROUP', 'ALESTRA',
#        'AXTEL', 'MEGACABLE-MCM', 'TELESISTEMAS PENINSULARES', 'GLOBALSAT',
#        'TELECOM NACIONAL', 'TOTALPLAY', 'AXESAT', 'AIRECABLE', 'CABLECOM',
#        'USA TELECOM', 'CODITEL', 'COMCAB', 'SINOTECA', 'MULTICOM',
#        'COORDINADORA DE TV POR CABLE', 'TV OJO CALIENTE',
#        'GTAC REDES DE FIBRA OPTICA', 'TRANSTELCO', 'AMÉRICA MÓVIL',
#        'TELECABLE DE TICUL', 'EUTELSAT AMERICAS', 'TV REY',
#        'CABLEVISION RED', 'MARCATEL', 'LINK TE CONECTAMOS', 'HISPASAT',
#        'ELARA COMUNICACIONES', 'SKYTEL', 'CABLEVISION DE APATZINGAN',
#        'DISH-MVS', 'MAXICABLE', 'BT LATAM MEXICO', 'SERVITRON',
#        'TELECABLE DE COAHUAYANA', 'CONVERGIA', 'MARCALESS', 'OUI',
#        'VERIZON SERVICIOS EMPRESARIALES MEXICO', 'MVH TELECOMUNICACIONES',
#        'BBG COMUNICACION', 'CIERTO', 'MVSTV', 'SUPERCOM', 'JACE TELECOM',
#        'NEXTEL', 'SECSA', 'MAZ TIEMPO', 'RAVS CABLE', 'HNS DE MEXICO',
#        'MEGATEL', 'UC TELECOM', 'MAXCOM', 'EJA TELECOMM',
#        'TELECABLE DE AGUILILLA', 'HIPERCABLE DE MONCLOVA',
#        'TELECABLE DE TEKAX', 'STAR NET', 'TELECABLE DE XALTIANGUIS',
#        'IST', 'TOKA MOVIL', 'OPERADORA TELEFONICA PENINSULAR',
#        'VIRGIN MOBILE', 'BUENO CELL', 'IENTC', 'MULTIMEDIA CTI',
#        'CABLEVISION DE LA HUACANA', 'TELECABLE DE CAMPECHE', 'OTROS',
#        'TELECABLE DE VILLANUEVA', 'QBO CEL', 'CONCABLETV', 'WEEX',
#        'NEUS MOBILE', 'AT&T', 'TELECABLE MERIDA', 'TVDIG', 'NEXT TELEKOM',
#        'FLASH MOBILE', 'CABLE SISTEMA DEL CENTRO', 'SIMPATI',
#        'HERMOVISION', 'SIHI MEXICO', 'COMNET', 'PUBLIFON', 'VADSA',
#        'RBACATV', 'EYCO DE LOS ALTOS', 'HER MOBILE', 'FREEDOM', 'ALTAN',
#        'SIERRA MADRE TELECOM', 'VIASAT', 'SIMPLII', 'AVANZADA',
#        'QUATTROCOM', 'SIX MOVIL', 'NET LINK', 'SISCAB DE MEXICO', 'ESPID',
#        'TELECABLE DE CUERNAVACA', 'ALTCEL', 'AIRBUS', 'ESMERO SOLUTIONS',
#        'GILAT', 'VASANTA', 'GRUPO CORPORATIVO ZUNUN PAZ',
#        'INTEGRA COMUNICACIONES', 'CABLEPLAY', 'GEOS TELECOM', 'CARMEL',
#        'MIIO', 'MUCHOS MEGAS', 'YOBI TELECOM', 'NETWEY', 'GURUCOMM',
#        'SISTV', 'CCA', 'EDILAR', 'MOTOROLA SOLUTIONS',
#        'TELECABLE DE MARIANO ESCOBEDO', 'ADDINTELI', 'DIRI MOVIL',
#        'IGOU TELECOM', 'NEWWW', 'YONDER', 'WIMOTELECOM', 'CRO.NET',
#        'GOBO', 'RED DOG', 'TELMOVIL', 'MARKETING 358', 'BROMOVIL',
#        'EDUARDO PEDRERO PEREZ', 'MICROSISTEMAS INTERNACIONAL', nan],
#       dtype=object)

# %%
len(ingresos['GRUPO'].unique())
# Out:
# 158

# %%
ingresos.columns
# Out:
# Index(['FOLIO', 'ANIO', 'TRIM', 'FECHA', 'CONCESIONARIO', 'K_EMPRESA',
#        'EMPRESA', 'K_GRUPO', 'GRUPO', 'I_FIJO_MOVIL', 'INGRESOS_TOTAL_E',
#        'I_ANUAL_TRIM'],
#       dtype='object')

# %%
# seleccionamos columnas relevantes
variables_relevantes = ['ANIO','TRIM', 'CONCESIONARIO', 'EMPRESA', 'GRUPO', 'INGRESOS_TOTAL_E']

ingresos2 = ingresos[variables_relevantes]
ingresos2
# Out:
#       ANIO  TRIM                               CONCESIONARIO  \
# 0     2021     1                        ADOLFO MERINO MEDINA
# 1     2021     2                        ADOLFO MERINO MEDINA
# 2     2021     3                        ADOLFO MERINO MEDINA
# 3     2021     4                        ADOLFO MERINO MEDINA
# 4     2021     1                        AGUSTIN PEREZ VIEYRA
# ...    ...   ...                                         ...
# 2456  2014     4  MICRO SISTEMAS INTERNACIONAL, S.A. DE C.V.
# 2457  2015     1  MICRO SISTEMAS INTERNACIONAL, S.A. DE C.V.
# 2458  2015     2  MICRO SISTEMAS INTERNACIONAL, S.A. DE C.V.
# 2459   NaN   NaN                                         NaN
# 2460   NaN   NaN                                         NaN
#
#                           EMPRESA                        GRUPO  \
# 0                        CABLEMAS               GRUPO TELEVISA
# 1                        CABLEMAS               GRUPO TELEVISA
# 2                        CABLEMAS               GRUPO TELEVISA
# 3                        CABLEMAS               GRUPO TELEVISA
# 4            AGUSTIN PEREZ VIEYRA         AGUSTIN PEREZ VIEYRA
# ...                           ...                          ...
# 2456  MICROSISTEMAS INTERNACIONAL  MICROSISTEMAS INTERNACIONAL
# 2457  MICROSISTEMAS INTERNACIONAL  MICROSISTEMAS INTERNACIONAL
# 2458  MICROSISTEMAS INTERNACIONAL  MICROSISTEMAS INTERNACIONAL
# 2459                          NaN                          NaN
# 2460                          NaN                          NaN
#
#      INGRESOS_TOTAL_E
# 0              389669
# 1              407900
# 2              416000
# 3              434431
# 4           797686.05
# ...               ...
# 2456              NaN
# 2457              NaN
# 2458       720,000.00
# 2459              NaN
# 2460              NaN
#
# [2461 rows x 6 columns]

# %%
# seleccionar sólo los registro de 2021
ingresos = ingresos2[ingresos2['ANIO']==2021]
ingresos
# Out:
#       ANIO  TRIM                                CONCESIONARIO  \
# 0     2021     1                         ADOLFO MERINO MEDINA
# 1     2021     2                         ADOLFO MERINO MEDINA
# 2     2021     3                         ADOLFO MERINO MEDINA
# 3     2021     4                         ADOLFO MERINO MEDINA
# 4     2021     1                         AGUSTIN PEREZ VIEYRA
# ...    ...   ...                                          ...
# 2444  2021     1  BROCOMUNICACIONES MOVILES, S.A.P.I. DE C.V.
# 2445  2021     2  BROCOMUNICACIONES MOVILES, S.A.P.I. DE C.V.
# 2446  2021     3  BROCOMUNICACIONES MOVILES, S.A.P.I. DE C.V.
# 2447  2021     4  BROCOMUNICACIONES MOVILES, S.A.P.I. DE C.V.
# 2448  2021     4                        EDUARDO PEDRERO PEREZ
#
#                     EMPRESA                  GRUPO INGRESOS_TOTAL_E
# 0                  CABLEMAS         GRUPO TELEVISA           389669
# 1                  CABLEMAS         GRUPO TELEVISA           407900
# 2                  CABLEMAS         GRUPO TELEVISA           416000
# 3                  CABLEMAS         GRUPO TELEVISA           434431
# 4      AGUSTIN PEREZ VIEYRA   AGUSTIN PEREZ VIEYRA        797686.05
# ...                     ...                    ...              ...
# 2444               BROMOVIL               BROMOVIL              NaN
# 2445               BROMOVIL               BROMOVIL              NaN
# 2446               BROMOVIL               BROMOVIL         83434.44
# 2447               BROMOVIL               BROMOVIL         237150.7
# 2448  EDUARDO PEDRERO PEREZ  EDUARDO PEDRERO PEREZ            68200
#
# [532 rows x 6 columns]

# %% [markdown]
# # Corrección de grupos de interés en el conjunto de datos
#
# Con base en la información proporcionada por la Unidad de Competencia Económica respecto a los Grupos de Interés que tienen identificados, se realizaron los siguientes cambios al marco de datos de ingresos que estamos utilizando para el cálculo del umbral de pequeño operador; publicado en el BIT al 19 de agosto de 2022:
#
# - Se incluye en el grupo de interés económico HISPASAT a la empresa AXESS NET.SOLUTIONS MEXICO, S.A. DE C.V.
# - Se incluye en el grupo de interés económico GRUPO TELEVISA a la empresa GRUPO DE TELECOMUNICACIONES DE ALTA CAPACIDAD, S.A.P.I. DE C.V. (GTAC).
# - Se incluye en el grupo de interés económico TRANSTELCO a la empresa MAXCOM TELECOMUNICACIONES, S.A.B. DE C.V.
# - Se incluyen en el grupo de interés económico MVS las empresas: MVSTV y DSH.

# %%
# Primero HISPASAT
print(ingresos[ingresos['EMPRESA']=='AXESS'])
ingresos['GRUPO'] = ingresos['GRUPO'].replace(['AXESAT'],'HISPASAT')
ingresos[ingresos['EMPRESA']=='AXESS']
# Out:
#      ANIO  TRIM                             CONCESIONARIO EMPRESA   GRUPO  \
# 345  2021     2  AXESS NET.SOLUTIONS MEXICO, S.A. DE C.V.   AXESS  AXESAT
# 346  2021     3  AXESS NET.SOLUTIONS MEXICO, S.A. DE C.V.   AXESS  AXESAT
# 347  2021     4  AXESS NET.SOLUTIONS MEXICO, S.A. DE C.V.   AXESS  AXESAT
#
#     INGRESOS_TOTAL_E
# 345         60667313
# 346         68625291
# 347         88628131
# <ipython-input-9-7dc6878566fb>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ingresos['GRUPO'] = ingresos['GRUPO'].replace(['AXESAT'],'HISPASAT')
#      ANIO  TRIM                             CONCESIONARIO EMPRESA     GRUPO  \
# 345  2021     2  AXESS NET.SOLUTIONS MEXICO, S.A. DE C.V.   AXESS  HISPASAT
# 346  2021     3  AXESS NET.SOLUTIONS MEXICO, S.A. DE C.V.   AXESS  HISPASAT
# 347  2021     4  AXESS NET.SOLUTIONS MEXICO, S.A. DE C.V.   AXESS  HISPASAT
#
#     INGRESOS_TOTAL_E
# 345         60667313
# 346         68625291
# 347         88628131

# %%
# Segundo Grupo Televisa
print(ingresos[ingresos['CONCESIONARIO']=='GRUPO DE TELECOMUNICACIONES DE ALTA CAPACIDAD, S.A.P.I. DE C.V.'])
ingresos['GRUPO'] = ingresos['GRUPO'].replace(['GTAC REDES DE FIBRA OPTICA'],'GRUPO TELEVISA')
ingresos[ingresos['EMPRESA']=='GTAC REDES DE FIBRA OPTICA']
# Out:
#      ANIO  TRIM                                      CONCESIONARIO  \
# 525  2021     1  GRUPO DE TELECOMUNICACIONES DE ALTA CAPACIDAD,...
# 526  2021     2  GRUPO DE TELECOMUNICACIONES DE ALTA CAPACIDAD,...
# 527  2021     3  GRUPO DE TELECOMUNICACIONES DE ALTA CAPACIDAD,...
# 528  2021     4  GRUPO DE TELECOMUNICACIONES DE ALTA CAPACIDAD,...
#
#                         EMPRESA                       GRUPO INGRESOS_TOTAL_E
# 525  GTAC REDES DE FIBRA OPTICA  GTAC REDES DE FIBRA OPTICA        228948471
# 526  GTAC REDES DE FIBRA OPTICA  GTAC REDES DE FIBRA OPTICA        196098888
# 527  GTAC REDES DE FIBRA OPTICA  GTAC REDES DE FIBRA OPTICA        355289838
# 528  GTAC REDES DE FIBRA OPTICA  GTAC REDES DE FIBRA OPTICA        282197600
# <ipython-input-10-98df99182ec1>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ingresos['GRUPO'] = ingresos['GRUPO'].replace(['GTAC REDES DE FIBRA OPTICA'],'GRUPO TELEVISA')
#      ANIO  TRIM                                      CONCESIONARIO  \
# 525  2021     1  GRUPO DE TELECOMUNICACIONES DE ALTA CAPACIDAD,...
# 526  2021     2  GRUPO DE TELECOMUNICACIONES DE ALTA CAPACIDAD,...
# 527  2021     3  GRUPO DE TELECOMUNICACIONES DE ALTA CAPACIDAD,...
# 528  2021     4  GRUPO DE TELECOMUNICACIONES DE ALTA CAPACIDAD,...
#
#                         EMPRESA           GRUPO INGRESOS_TOTAL_E
# 525  GTAC REDES DE FIBRA OPTICA  GRUPO TELEVISA        228948471
# 526  GTAC REDES DE FIBRA OPTICA  GRUPO TELEVISA        196098888
# 527  GTAC REDES DE FIBRA OPTICA  GRUPO TELEVISA        355289838
# 528  GTAC REDES DE FIBRA OPTICA  GRUPO TELEVISA        282197600

# %%
# Tercero Transtelco
print(ingresos[ingresos['CONCESIONARIO']=='MAXCOM TELECOMUNICACIONES, S.A.B. DE C.V.'])
ingresos['GRUPO'] = ingresos['GRUPO'].replace(['MAXCOM'],'TRANSTELCO')
ingresos[ingresos['EMPRESA']=='MAXCOM']
# Out:
#       ANIO  TRIM                              CONCESIONARIO EMPRESA   GRUPO  \
# 1820  2021     1  MAXCOM TELECOMUNICACIONES, S.A.B. DE C.V.  MAXCOM  MAXCOM
# 1821  2021     2  MAXCOM TELECOMUNICACIONES, S.A.B. DE C.V.  MAXCOM  MAXCOM
# 1822  2021     3  MAXCOM TELECOMUNICACIONES, S.A.B. DE C.V.  MAXCOM  MAXCOM
# 1823  2021     4  MAXCOM TELECOMUNICACIONES, S.A.B. DE C.V.  MAXCOM  MAXCOM
#
#      INGRESOS_TOTAL_E
# 1820        154326158
# 1821        157745550
# 1822        154123979
# 1823        157402483
# <ipython-input-11-19fa40c9fb05>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ingresos['GRUPO'] = ingresos['GRUPO'].replace(['MAXCOM'],'TRANSTELCO')
#       ANIO  TRIM                              CONCESIONARIO EMPRESA  \
# 1820  2021     1  MAXCOM TELECOMUNICACIONES, S.A.B. DE C.V.  MAXCOM
# 1821  2021     2  MAXCOM TELECOMUNICACIONES, S.A.B. DE C.V.  MAXCOM
# 1822  2021     3  MAXCOM TELECOMUNICACIONES, S.A.B. DE C.V.  MAXCOM
# 1823  2021     4  MAXCOM TELECOMUNICACIONES, S.A.B. DE C.V.  MAXCOM
#
#            GRUPO INGRESOS_TOTAL_E
# 1820  TRANSTELCO        154326158
# 1821  TRANSTELCO        157745550
# 1822  TRANSTELCO        154123979
# 1823  TRANSTELCO        157402483

# %%
ingresos[ingresos['EMPRESA']=='DISH']
# Out:
#       ANIO  TRIM                                      CONCESIONARIO EMPRESA  \
# 1067  2021     1  COMERCIALIZADORA DE FRECUENCIAS SATELITALES, S...    DISH
# 1068  2021     2  COMERCIALIZADORA DE FRECUENCIAS SATELITALES, S...    DISH
# 1069  2021     3  COMERCIALIZADORA DE FRECUENCIAS SATELITALES, S...    DISH
# 1070  2021     4  COMERCIALIZADORA DE FRECUENCIAS SATELITALES, S...    DISH
#
#          GRUPO INGRESOS_TOTAL_E
# 1067  DISH-MVS       1373486398
# 1068  DISH-MVS       1298658657
# 1069  DISH-MVS       1264047268
# 1070  DISH-MVS       1211104115

# %%
# Quinto DISH-MVS
print(ingresos[ingresos['CONCESIONARIO']=='COMERCIALIZADORA DE FRECUENCIAS SATELITALES, S. DE R.L. DE C.V.'])
ingresos['GRUPO'] = ingresos['GRUPO'].replace(['DISH-MVS'],'MVS')
ingresos[ingresos['EMPRESA']=='DISH']
# Out:
#       ANIO  TRIM                                      CONCESIONARIO EMPRESA  \
# 1067  2021     1  COMERCIALIZADORA DE FRECUENCIAS SATELITALES, S...    DISH
# 1068  2021     2  COMERCIALIZADORA DE FRECUENCIAS SATELITALES, S...    DISH
# 1069  2021     3  COMERCIALIZADORA DE FRECUENCIAS SATELITALES, S...    DISH
# 1070  2021     4  COMERCIALIZADORA DE FRECUENCIAS SATELITALES, S...    DISH
#
#          GRUPO INGRESOS_TOTAL_E
# 1067  DISH-MVS       1373486398
# 1068  DISH-MVS       1298658657
# 1069  DISH-MVS       1264047268
# 1070  DISH-MVS       1211104115
# <ipython-input-13-3309da2ae005>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ingresos['GRUPO'] = ingresos['GRUPO'].replace(['DISH-MVS'],'MVS')
#       ANIO  TRIM                                      CONCESIONARIO EMPRESA  \
# 1067  2021     1  COMERCIALIZADORA DE FRECUENCIAS SATELITALES, S...    DISH
# 1068  2021     2  COMERCIALIZADORA DE FRECUENCIAS SATELITALES, S...    DISH
# 1069  2021     3  COMERCIALIZADORA DE FRECUENCIAS SATELITALES, S...    DISH
# 1070  2021     4  COMERCIALIZADORA DE FRECUENCIAS SATELITALES, S...    DISH
#
#      GRUPO INGRESOS_TOTAL_E
# 1067   MVS       1373486398
# 1068   MVS       1298658657
# 1069   MVS       1264047268
# 1070   MVS       1211104115

# %%
# Sexto DISH-MVS
print(ingresos[ingresos['EMPRESA']=='MVSTV'])
ingresos['GRUPO'] = ingresos['GRUPO'].replace(['MVSTV'],'MVS')
ingresos[ingresos['EMPRESA']=='MVSTV']
# Out:
#       ANIO  TRIM          CONCESIONARIO EMPRESA  GRUPO INGRESOS_TOTAL_E
# 1704  2021     1  COMBAND, S.A. DE C.V.   MVSTV  MVSTV       1854470.77
# 1705  2021     2  COMBAND, S.A. DE C.V.   MVSTV  MVSTV       1355173.22
# 1706  2021     3  COMBAND, S.A. DE C.V.   MVSTV  MVSTV       2842490.96
# 1707  2021     4  COMBAND, S.A. DE C.V.   MVSTV  MVSTV       5357193.15
# <ipython-input-14-b827a2e0f14c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ingresos['GRUPO'] = ingresos['GRUPO'].replace(['MVSTV'],'MVS')
#       ANIO  TRIM          CONCESIONARIO EMPRESA GRUPO INGRESOS_TOTAL_E
# 1704  2021     1  COMBAND, S.A. DE C.V.   MVSTV   MVS       1854470.77
# 1705  2021     2  COMBAND, S.A. DE C.V.   MVSTV   MVS       1355173.22
# 1706  2021     3  COMBAND, S.A. DE C.V.   MVSTV   MVS       2842490.96
# 1707  2021     4  COMBAND, S.A. DE C.V.   MVSTV   MVS       5357193.15

# %%
# Existen huecos en los datos públicos en proveedores importantes como Axtel (4T2021), Cablevisión, Virgin Mobile (4T2021), QBO CEL (2T Y 4T2021), por mencionar algunos.
ingresos[ingresos['INGRESOS_TOTAL_E'].isna()==True]
# no obstante, partimos de que es la información disponible para este ejercicio.
# Out:
#       ANIO  TRIM                                      CONCESIONARIO  \
# 267   2021     4                              AXTEL, S.A.B. DE C.V.
# 514   2021     2          CABLEMAS TELECOMUNICACIONES, S.A. DE C.V.
# 766   2021     2                      CABLEVISION RED, S.A. DE C.V.
# 838   2021     2                  TV CABLE DE ORIENTE, S.A. DE C.V.
# 940   2021     2             TELEVISION INTERNACIONAL, S.A. DE C.V.
# 1434  2021     2                          CABLEVISION, S.A. DE C.V.
# 1929  2021     4           VIRGIN MOBILE MEXICO, S. DE R.L. DE C.V.
# 2010  2021     2                         KUBO CEL, S.A.P.I. DE C.V.
# 2012  2021     4                         KUBO CEL, S.A.P.I. DE C.V.
# 2151  2021     1                               COMNET, S.A. DE C.V.
# 2166  2021     3               VALOR AGREGADO DIGITAL, S.A. DE C.V.
# 2167  2021     4               VALOR AGREGADO DIGITAL, S.A. DE C.V.
# 2400  2021     1  SOLUCIONES Y ASESORIA EN COBRANZA, S. DE R.L. ...
# 2432  2021     1    CONVERGENCIA Y DESARROLLO DIGITAL, S.A. DE C.V.
# 2436  2021     1                         TELMOV MOVIL, S.A. DE C.V.
# 2440  2021     1                        MARKETING 358, S.A. DE C.V.
# 2441  2021     2                        MARKETING 358, S.A. DE C.V.
# 2444  2021     1        BROCOMUNICACIONES MOVILES, S.A.P.I. DE C.V.
# 2445  2021     2        BROCOMUNICACIONES MOVILES, S.A.P.I. DE C.V.
#
#                        EMPRESA           GRUPO INGRESOS_TOTAL_E
# 267                      AXTEL           AXTEL              NaN
# 514                       IZZI  GRUPO TELEVISA              NaN
# 766            CABLEVISION RED  GRUPO TELEVISA              NaN
# 838                       IZZI  GRUPO TELEVISA              NaN
# 940   TELEVISION INTERNACIONAL  GRUPO TELEVISA              NaN
# 1434               CABLEVISION  GRUPO TELEVISA              NaN
# 1929             VIRGIN MOBILE   VIRGIN MOBILE              NaN
# 2010                   QBO CEL         QBO CEL              NaN
# 2012                   QBO CEL         QBO CEL              NaN
# 2151                    COMNET          COMNET              NaN
# 2166                     VADSA           VADSA              NaN
# 2167                     VADSA           VADSA              NaN
# 2400              IGOU TELECOM    IGOU TELECOM              NaN
# 2432                   RED DOG         RED DOG              NaN
# 2436                  TELMOVIL        TELMOVIL              NaN
# 2440             MARKETING 358   MARKETING 358              NaN
# 2441             MARKETING 358   MARKETING 358              NaN
# 2444                  BROMOVIL        BROMOVIL              NaN
# 2445                  BROMOVIL        BROMOVIL              NaN

# %%
ingresos.dtypes
# Out:
# ANIO                float64
# TRIM                float64
# CONCESIONARIO        object
# EMPRESA              object
# GRUPO                object
# INGRESOS_TOTAL_E     object
# dtype: object

# %%
# no consideremos los missing values

ingresos = ingresos[ingresos['INGRESOS_TOTAL_E'].isna()!=True]
ingresos
# Out:
#       ANIO  TRIM                                CONCESIONARIO  \
# 0     2021     1                         ADOLFO MERINO MEDINA
# 1     2021     2                         ADOLFO MERINO MEDINA
# 2     2021     3                         ADOLFO MERINO MEDINA
# 3     2021     4                         ADOLFO MERINO MEDINA
# 4     2021     1                         AGUSTIN PEREZ VIEYRA
# ...    ...   ...                                          ...
# 2442  2021     3                  MARKETING 358, S.A. DE C.V.
# 2443  2021     4                  MARKETING 358, S.A. DE C.V.
# 2446  2021     3  BROCOMUNICACIONES MOVILES, S.A.P.I. DE C.V.
# 2447  2021     4  BROCOMUNICACIONES MOVILES, S.A.P.I. DE C.V.
# 2448  2021     4                        EDUARDO PEDRERO PEREZ
#
#                     EMPRESA                  GRUPO INGRESOS_TOTAL_E
# 0                  CABLEMAS         GRUPO TELEVISA           389669
# 1                  CABLEMAS         GRUPO TELEVISA           407900
# 2                  CABLEMAS         GRUPO TELEVISA           416000
# 3                  CABLEMAS         GRUPO TELEVISA           434431
# 4      AGUSTIN PEREZ VIEYRA   AGUSTIN PEREZ VIEYRA        797686.05
# ...                     ...                    ...              ...
# 2442          MARKETING 358          MARKETING 358        398927.16
# 2443          MARKETING 358          MARKETING 358       1924097.07
# 2446               BROMOVIL               BROMOVIL         83434.44
# 2447               BROMOVIL               BROMOVIL         237150.7
# 2448  EDUARDO PEDRERO PEREZ  EDUARDO PEDRERO PEREZ            68200
#
# [513 rows x 6 columns]

# %%
lista_columnas = ['GRUPO', 'INGRESOS_TOTAL_E']
ingresos2 = ingresos[lista_columnas]
ingresos2
# Out:
#                       GRUPO INGRESOS_TOTAL_E
# 0            GRUPO TELEVISA           389669
# 1            GRUPO TELEVISA           407900
# 2            GRUPO TELEVISA           416000
# 3            GRUPO TELEVISA           434431
# 4      AGUSTIN PEREZ VIEYRA        797686.05
# ...                     ...              ...
# 2442          MARKETING 358        398927.16
# 2443          MARKETING 358       1924097.07
# 2446               BROMOVIL         83434.44
# 2447               BROMOVIL         237150.7
# 2448  EDUARDO PEDRERO PEREZ            68200
#
# [513 rows x 2 columns]

# %%
ingresos2['INGRESOS_TOTAL_E'] = pd.to_numeric(ingresos2['INGRESOS_TOTAL_E'])
# Out:
# <ipython-input-19-0e8230c4d54c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ingresos2['INGRESOS_TOTAL_E'] = pd.to_numeric(ingresos2['INGRESOS_TOTAL_E'])

# %%
# ya no tenemos missings

ingresos2.dtypes
# Out:
# GRUPO                object
# INGRESOS_TOTAL_E    float64
# dtype: object

# %%
# Agrupados
ingresos_agrupados = ingresos2.groupby(['GRUPO']).sum()
ingresos_agrupados
# Out:
#                                         INGRESOS_TOTAL_E
# GRUPO
# ADDINTELI                                        5534961
# AGUSTIN PEREZ VIEYRA                             2726562
# AIRECABLE                                       13327321
# ALTAN                                         2834607753
# AMÉRICA MÓVIL                               338320139531
# ...                                                  ...
# VERIZON SERVICIOS EMPRESARIALES MEXICO         258650617
# VIRGIN MOBILE                                  146563495
# WEEX                                            33446465
# WIMOTELECOM                                    166683899
# YOBI TELECOM                                    43316605
#
# [116 rows x 1 columns]

# %%
ingresos_agrupados = ingresos_agrupados.reset_index().sort_values(by=['INGRESOS_TOTAL_E'], ascending=False)
ingresos_agrupados
# Out:
#                            GRUPO  INGRESOS_TOTAL_E
# 4                  AMÉRICA MÓVIL      338320139531
# 36                GRUPO TELEVISA       59301496226
# 6                           AT&T       55793781168
# 98                    TELEFÓNICA       24871583943
# 60                 MEGACABLE-MCM       24676771857
# ..                           ...               ...
# 35   GRUPO CORPORATIVO ZUNUN PAZ            340986
# 100                     TELMOVIL            332069
# 9                       BROMOVIL            320585
# 23         EDUARDO PEDRERO PEREZ             68200
# 18                        COMNET             43293
#
# [116 rows x 2 columns]

# %%
plt.hist(ingresos_agrupados['INGRESOS_TOTAL_E'])
plt.xlabel('Ingresos ($)')
plt.ylabel('Frecuencia absoluta')
plt.show()
print(sts.normaltest(ingresos_agrupados['INGRESOS_TOTAL_E'])) # no pasa la prueba de normalidad (sesgo)
# Out:
# NormaltestResult(statistic=238.15581101258346, pvalue=1.928069666088079e-52)

# %%
# cuántos ceros tenemos en las cifras
m = ingresos_agrupados[ingresos_agrupados['INGRESOS_TOTAL_E']!=0]

ingresos_agrupados_transformables = m

ingresos_agrupados_transformables
# Out:
#                            GRUPO  INGRESOS_TOTAL_E
# 4                  AMÉRICA MÓVIL      338320139531
# 36                GRUPO TELEVISA       59301496226
# 6                           AT&T       55793781168
# 98                    TELEFÓNICA       24871583943
# 60                 MEGACABLE-MCM       24676771857
# ..                           ...               ...
# 35   GRUPO CORPORATIVO ZUNUN PAZ            340986
# 100                     TELMOVIL            332069
# 9                       BROMOVIL            320585
# 23         EDUARDO PEDRERO PEREZ             68200
# 18                        COMNET             43293
#
# [116 rows x 2 columns]

# %%
# Aplicar logarítmos para reducir el efecto de la magnitud de los datos.
ln_ingresos = np.log(ingresos_agrupados_transformables['INGRESOS_TOTAL_E']) 

plt.hist(ln_ingresos)
plt.xlabel('Ingresos ($)')
plt.ylabel('Frecuencia absoluta')
plt.show()
print(sts.normaltest(ln_ingresos))
# Out:
# NormaltestResult(statistic=19.12498898738056, pvalue=7.03171739590705e-05)

# %%
# Análisis de varianza
var_numpy = np.var(ln_ingresos, ddof = 0)
print(f"La varianza del ln de los ingresos totales en 2021 es de {var_numpy}")
print(f'Lo que implica $ {np.exp(var_numpy)}')

sd_numpy = np.std(ln_ingresos,ddof = 0)
print(f"La desviación estándar del ln de los ingresos totales en 2021 es de {sd_numpy}")
print(f'Lo que implica $ {np.exp(sd_numpy)}')
# Out:
# La varianza del ln de los ingresos totales en 2021 es de 8.286548415208602
# Lo que implica $ 3970.1073563151735
# La desviación estándar del ln de los ingresos totales en 2021 es de 2.878636554900358
# Lo que implica $ 17.79000094683033

# %%
var_numpy2 = np.var(ingresos_agrupados['INGRESOS_TOTAL_E'], ddof = 0)
print(f"La varianza del ln de los ingresos totales en 2021 es de {var_numpy2}")

sd_numpy2 = np.std(ingresos_agrupados['INGRESOS_TOTAL_E'],ddof = 0)
print(f"La desviación estándar de los ingresos totales en 2021 es de {sd_numpy2}")
# Out:
# La varianza del ln de los ingresos totales en 2021 es de 1.0373849757817884e+21
# La desviación estándar de los ingresos totales en 2021 es de 32208461245.17265

# %%
# La media
media = np.mean(ln_ingresos)
print(f"La media del ln de los ingresos 2021 es de {media}")
print(f'Lo que implica una media de $ {np.exp(media)}')
# Out:
# La media del ln de los ingresos 2021 es de 16.876571019213984
# Lo que implica una media de $ 21350186.206439875

# %%
# Calculando la regla de 68-95-99.7 usando la desviación estándar:
print(f"Casi el 68% de los datos está entre {round(media-sd_numpy,3)} y {round(media+sd_numpy,3)}")
print(f'Lo que implica que el 68% de los operadores tienen ingresos entre {round(np.exp(media-sd_numpy),2)} y {round(np.exp(media+sd_numpy),2)}')
print(f"Casi el 95% de los datos está entre {round(media-2*sd_numpy,3)} y {round(media +2*sd_numpy,3)}")
print(f'Lo que implica que el 95% de los operadores tienen ingresos entre {round(np.exp(media-2*sd_numpy),2)} y {round(np.exp(media +2*sd_numpy),2)}')
print(f"Casi el 99.7% de los datos está entre {round(media-3*sd_numpy,3)} y {round(media+3*sd_numpy,3)}")
print(f'Lo que implica que el 99.7% de los operadores tienen ingresos entre {round(np.exp(media-3*sd_numpy),2)} y {round(np.exp(media +3*sd_numpy),2)}')
# Out:
# Casi el 68% de los datos está entre 13.998 y 19.755
# Lo que implica que el 68% de los operadores tienen ingresos entre 1200122.83 y 379819832.83
# Casi el 95% de los datos está entre 11.119 y 22.634
# Lo que implica que el 95% de los operadores tienen ingresos entre 67460.53 y 6756995185.63
# Casi el 99.7% de los datos está entre 8.241 y 25.512
# Lo que implica que el 99.7% de los operadores tienen ingresos entre 3792.05 y 120206950750.04

# %%
# El score z nos dice el número de desviaciones estándar en el que un dato de ingreso está cerca de la media
z_scipy = sts.zscore(ln_ingresos)
print(f"Los score z es {z_scipy}")
# Out:
# Los score z es [ 3.35946801  2.75454341  2.73336251  2.45269614  2.44996444  2.42224358
#   2.08948259  1.90624292  1.69823397  1.42227946  1.22655634  1.21114929
#   1.17223751  1.13960329  1.09791125  1.033615    0.95147706  0.86652749
#   0.80083652  0.776976    0.72278666  0.71691058  0.71389309  0.68195652
#   0.66920511  0.57713694  0.529582    0.492777    0.48350637  0.47457978
#   0.47347242  0.47063683  0.3466482   0.34041538  0.34041538  0.32752049
#   0.24677569  0.2457676   0.22914791  0.22824258  0.21611638  0.19524039
#   0.15593689  0.12950964  0.12595781  0.06486042  0.03715059  0.02512625
#   0.02407649  0.02203962  0.01691373 -0.00610232 -0.01283765 -0.13367125
#  -0.13863448 -0.14720463 -0.163704   -0.16598494 -0.16750832 -0.17423663
#  -0.17439576 -0.18790852 -0.19028517 -0.20993631 -0.22722884 -0.24240511
#  -0.32323577 -0.33194837 -0.34124606 -0.34605042 -0.37276338 -0.41136477
#  -0.43955823 -0.46896366 -0.47283957 -0.51003327 -0.51867379 -0.52159124
#  -0.55217502 -0.55941645 -0.58148777 -0.64861277 -0.66093463 -0.69871059
#  -0.70115489 -0.70941391 -0.7110097  -0.71492836 -0.71605493 -0.73169658
#  -0.73169658 -0.75058331 -0.76420438 -0.76439368 -0.77056986 -0.77580858
#  -0.77714909 -0.78136142 -0.78954153 -0.7983284  -0.86593579 -0.91486633
#  -0.91884845 -0.94024249 -1.03198122 -1.0640209  -1.25956128 -1.30615379
#  -1.32241723 -1.32241723 -1.36139924 -1.43712978 -1.44633515 -1.45856129
#  -1.99621281 -2.15408362]

# %%
# Prueba de outliers (los grandes operadores)
green_diamond = dict(markerfacecolor='g', marker='D')
fig1, ax1 = plt.subplots(figsize=(10, 8))
ax1.set_title('Ingresos acumulados totales por operador al cierre 2021 (ln)')
ax1.set_ylabel('ln(MX$)')
ax1.boxplot(ln_ingresos, flierprops=green_diamond, whis=0.75, vert=False)
plt.savefig('criterio_2021.png')
plt.show()

# %%
ln_ingresos
# Out:
# 4     27
# 36    25
# 6     25
# 98    24
# 60    24
#       ..
# 35    13
# 100   13
# 9     13
# 23    11
# 18    11
# Name: INGRESOS_TOTAL_E, Length: 116, dtype: float64

# %%
sns.set_style("darkgrid", {"axes.facecolor": ".9"})
df = ln_ingresos

# Usual boxplot
ax = sns.boxplot(data=df, orient="h")
 
# Add jitter with the swarmplot function
ax = sns.swarmplot(color="blue", data=df, orient="h")
plt.show()

# %%
ln_ingresos2 = pd.DataFrame(ln_ingresos)
ln_ingresos3 = ln_ingresos2['INGRESOS_TOTAL_E'].values.astype("float")
ln_ingresos3
# Out:
# array([26.54725844, 24.80590037, 24.74492825, 23.93699178, 23.92912823,
#        23.84932993, 22.89143199, 22.36395156, 21.76516941, 20.97079665,
#        20.40738094, 20.36302965, 20.25101676, 20.15707471, 20.03705847,
#        19.85197294, 19.61552768, 19.37098874, 19.18188829, 19.11320254,
#        18.95721111, 18.94029603, 18.93160975, 18.839676  , 18.80296931,
#        18.53793852, 18.40104514, 18.29509691, 18.26841012, 18.24271372,
#        18.23952603, 18.23136339, 17.87444519, 17.85650317, 17.85650317,
#        17.81938348, 17.58694855, 17.5840466 , 17.53620457, 17.53359844,
#        17.49869154, 17.43859714, 17.32545666, 17.24938221, 17.23915779,
#        17.06328059, 16.98351405, 16.94890035, 16.94587848, 16.94001508,
#        16.92525951, 16.85900466, 16.83961608, 16.49178006, 16.47749274,
#        16.45282239, 16.40532671, 16.39876071, 16.39437544, 16.37500708,
#        16.374549  , 16.33565069, 16.32880917, 16.27224068, 16.22246178,
#        16.1787748 , 15.94609271, 15.92101231, 15.89424763, 15.88041764,
#        15.80352074, 15.69240137, 15.61124264, 15.52659508, 15.51543775,
#        15.40837061, 15.38349769, 15.3750994 , 15.28705982, 15.26621437,
#        15.20267905, 15.0094506 , 14.97398043, 14.86523718, 14.85820092,
#        14.83442622, 14.82983249, 14.81855211, 14.81530912, 14.7702825 ,
#        14.7702825 , 14.71591447, 14.67670435, 14.67615943, 14.65838044,
#        14.64330008, 14.63944123, 14.62731548, 14.6037679 , 14.57847371,
#        14.3838566 , 14.24300335, 14.23154027, 14.16995462, 13.90587215,
#        13.81364156, 13.25075188, 13.11662897, 13.06981245, 13.06981245,
#        12.95759741, 12.7395967 , 12.71309779, 12.67790317, 11.13019984,
#        10.67574716])

# %%
ln_ingresos2.index
# Out:
# Int64Index([  4,  36,   6,  98,  60, 102,   7,  62,   3,  84,
#             ...
#              91,  47,  50,  12,  45,  35, 100,   9,  23,  18],
#            dtype='int64', length=116)

# %%
# Busquemos los clusters estadísticamente significativos
#use the kmeans function from scipy
from numpy import random
random.seed((1000,2000))
centroids, avg_distance = kmeans(ln_ingresos3, 3, iter=1000)
#extract the groups from the data
groups, cdit = vq(ln_ingresos3, centroids+1)
#plot the results
#assign groups back to the dataframe
ln_ingresos2["Tipo_de_Operadores"] = groups
#plot the scatter plot
# Usual boxplot

ax = sns.swarmplot(data=ln_ingresos2, x=np.ones(len(ln_ingresos2)), 
              y='INGRESOS_TOTAL_E', 
              hue=ln_ingresos2['Tipo_de_Operadores'])

ax = sns.swarmplot(data=centroids+1, color="red")
#ax = sns.boxplot(data=ln_ingresos2["INGRESOS_TOTAL_E"])

# remove legend if necessary
# plt.legend().remove()
plt.savefig('clusters_ingresos.png')
plt.show()

# %%
grande = ln_ingresos2[ln_ingresos2['Tipo_de_Operadores']==1].reset_index()
grande

mediano =  ln_ingresos2[ln_ingresos2['Tipo_de_Operadores']==2].reset_index()
mediano

pequeño = ln_ingresos2[ln_ingresos2['Tipo_de_Operadores']==0].reset_index()
pequeño
# Out:
#     index  INGRESOS_TOTAL_E  Tipo_de_Operadores
# 0      77                18                   0
# 1     115                18                   0
# 2      20                18                   0
# 3      72                18                   0
# 4      53                17                   0
# ..    ...               ...                 ...
# 75     35                13                   0
# 76    100                13                   0
# 77      9                13                   0
# 78     23                11                   0
# 79     18                11                   0
#
# [80 rows x 3 columns]

# %%
ln_ingresos2["Tipo_de_Operadores"].replace({2: "Mediano", 1: "Grande", 0:"Pequeño"}, inplace=True)
ln_ingresos2 = ln_ingresos2.reset_index()
ln_ingresos2
# Out:
#      index  INGRESOS_TOTAL_E Tipo_de_Operadores
# 0        4                27             Grande
# 1       36                25             Grande
# 2        6                25             Grande
# 3       98                24             Grande
# 4       60                24             Grande
# ..     ...               ...                ...
# 111     35                13            Pequeño
# 112    100                13            Pequeño
# 113      9                13            Pequeño
# 114     23                11            Pequeño
# 115     18                11            Pequeño
#
# [116 rows x 3 columns]

# %%
grande = ln_ingresos2[ln_ingresos2['Tipo_de_Operadores']=="Grande"]
grande

mediano =  ln_ingresos2[ln_ingresos2['Tipo_de_Operadores']=="Mediano"]
mediano

pequeño = ln_ingresos2[ln_ingresos2['Tipo_de_Operadores']=="Pequeño"]
pequeño
# Out:
#      index  INGRESOS_TOTAL_E Tipo_de_Operadores
# 36      77                18            Pequeño
# 37     115                18            Pequeño
# 38      20                18            Pequeño
# 39      72                18            Pequeño
# 40      53                17            Pequeño
# ..     ...               ...                ...
# 111     35                13            Pequeño
# 112    100                13            Pequeño
# 113      9                13            Pequeño
# 114     23                11            Pequeño
# 115     18                11            Pequeño
#
# [80 rows x 3 columns]

# %%
ax = sns.swarmplot(data=ln_ingresos2, x="INGRESOS_TOTAL_E", y="Tipo_de_Operadores", alpha=0.8, linewidth=.9)
ax = sns.boxplot(data=ln_ingresos2, x='INGRESOS_TOTAL_E', y="Tipo_de_Operadores",orient="h", color="lightblue")
plt.savefig("clusters_distribución.jpg")
#plt.show()
# Out:
# D:\Users\rodrigo.guarneros\Anaconda4\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 11.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
ax = sns.boxplot(data=ln_ingresos2, x='INGRESOS_TOTAL_E', y="Tipo_de_Operadores",orient="h", color="lightblue")

# %%
dir(ax)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_add_text',
#  '_adjustable',
#  '_agg_filter',
#  '_alias_map',
#  '_alpha',
#  '_anchor',
#  '_animated',
#  '_aspect',
#  '_autoscaleXon',
#  '_autoscaleYon',
#  '_autotitlepos',
#  '_axes',
#  '_axes_class',
#  '_axes_locator',
#  '_axisbelow',
#  '_box_aspect',
#  '_clipon',
#  '_clippath',
#  '_contains',
#  '_convert_dx',
#  '_current_image',
#  '_default_contains',
#  '_facecolor',
#  '_fill_between_x_or_y',
#  '_frameon',
#  '_gci',
#  '_gen_axes_patch',
#  '_gen_axes_spines',
#  '_get_axis_list',
#  '_get_axis_map',
#  '_get_clipping_extent_bbox',
#  '_get_lines',
#  '_get_patches_for_fill',
#  '_get_view',
#  '_gid',
#  '_gridOn',
#  '_in_layout',
#  '_init_axis',
#  '_label',
#  '_layoutbox',
#  '_left_title',
#  '_make_twin_axes',
#  '_mouseover',
#  '_mouseover_set',
#  '_navigate',
#  '_navigate_mode',
#  '_oid',
#  '_on_units_changed',
#  '_originalPosition',
#  '_parse_scatter_color_args',
#  '_path_effects',
#  '_pcolorargs',
#  '_picker',
#  '_position',
#  '_poslayoutbox',
#  '_process_unit_info',
#  '_propobservers',
#  '_quiver_units',
#  '_rasterization_zorder',
#  '_rasterized',
#  '_remove_legend',
#  '_remove_method',
#  '_request_autoscale_view',
#  '_right_title',
#  '_sci',
#  '_set_artist_props',
#  '_set_gc_clip',
#  '_set_lim_and_transforms',
#  '_set_position',
#  '_set_title_offset_trans',
#  '_set_view',
#  '_set_view_from_bbox',
#  '_shared_x_axes',
#  '_shared_y_axes',
#  '_sharex',
#  '_sharey',
#  '_sketch',
#  '_snap',
#  '_stale',
#  '_stale_viewlim_x',
#  '_stale_viewlim_y',
#  '_sticky_edges',
#  '_subplotspec',
#  '_tight',
#  '_transform',
#  '_transformSet',
#  '_twinned_axes',
#  '_unstale_viewLim',
#  '_update_image_limits',
#  '_update_line_limits',
#  '_update_patch_limits',
#  '_update_title_position',
#  '_update_transScale',
#  '_url',
#  '_use_sticky_edges',
#  '_validate_converted_limits',
#  '_viewLim',
#  '_visible',
#  '_xaxis_transform',
#  '_xcid',
#  '_xmargin',
#  '_yaxis_transform',
#  '_ycid',
#  '_ymargin',
#  'acorr',
#  'add_artist',
#  'add_callback',
#  'add_child_axes',
#  'add_collection',
#  'add_container',
#  'add_image',
#  'add_line',
#  'add_patch',
#  'add_table',
#  'angle_spectrum',
#  'annotate',
#  'apply_aspect',
#  'arrow',
#  'artists',
#  'autoscale',
#  'autoscale_view',
#  'axes',
#  'axhline',
#  'axhspan',
#  'axis',
#  'axison',
#  'axline',
#  'axvline',
#  'axvspan',
#  'bar',
#  'barbs',
#  'barh',
#  'bbox',
#  'boxplot',
#  'broken_barh',
#  'bxp',
#  'callbacks',
#  'can_pan',
#  'can_zoom',
#  'change_geometry',
#  'child_axes',
#  'cla',
#  'clabel',
#  'clear',
#  'clipbox',
#  'cohere',
#  'colNum',
#  'collections',
#  'containers',
#  'contains',
#  'contains_point',
#  'contour',
#  'contourf',
#  'convert_xunits',
#  'convert_yunits',
#  'csd',
#  'dataLim',
#  'drag_pan',
#  'draw',
#  'draw_artist',
#  'end_pan',
#  'errorbar',
#  'eventplot',
#  'eventson',
#  'figbox',
#  'figure',
#  'fill',
#  'fill_between',
#  'fill_betweenx',
#  'findobj',
#  'fmt_xdata',
#  'fmt_ydata',
#  'format_coord',
#  'format_cursor_data',
#  'format_xdata',
#  'format_ydata',
#  'get_adjustable',
#  'get_agg_filter',
#  'get_alpha',
#  'get_anchor',
#  'get_animated',
#  'get_aspect',
#  'get_autoscale_on',
#  'get_autoscalex_on',
#  'get_autoscaley_on',
#  'get_axes_locator',
#  'get_axisbelow',
#  'get_box_aspect',
#  'get_children',
#  'get_clip_box',
#  'get_clip_on',
#  'get_clip_path',
#  'get_contains',
#  'get_cursor_data',
#  'get_data_ratio',
#  'get_data_ratio_log',
#  'get_default_bbox_extra_artists',
#  'get_facecolor',
#  'get_fc',
#  'get_figure',
#  'get_frame_on',
#  'get_geometry',
#  'get_gid',
#  'get_gridspec',
#  'get_images',
#  'get_in_layout',
#  'get_label',
#  'get_legend',
#  'get_legend_handles_labels',
#  'get_lines',
#  'get_navigate',
#  'get_navigate_mode',
#  'get_path_effects',
#  'get_picker',
#  'get_position',
#  'get_rasterization_zorder',
#  'get_rasterized',
#  'get_renderer_cache',
#  'get_shared_x_axes',
#  'get_shared_y_axes',
#  'get_sketch_params',
#  'get_snap',
#  'get_subplotspec',
#  'get_tightbbox',
#  'get_title',
#  'get_transform',
#  'get_transformed_clip_path_and_affine',
#  'get_url',
#  'get_visible',
#  'get_window_extent',
#  'get_xaxis',
#  'get_xaxis_text1_transform',
#  'get_xaxis_text2_transform',
#  'get_xaxis_transform',
#  'get_xbound',
#  'get_xgridlines',
#  'get_xlabel',
#  'get_xlim',
#  'get_xmajorticklabels',
#  'get_xminorticklabels',
#  'get_xscale',
#  'get_xticklabels',
#  'get_xticklines',
#  'get_xticks',
#  'get_yaxis',
#  'get_yaxis_text1_transform',
#  'get_yaxis_text2_transform',
#  'get_yaxis_transform',
#  'get_ybound',
#  'get_ygridlines',
#  'get_ylabel',
#  'get_ylim',
#  'get_ymajorticklabels',
#  'get_yminorticklabels',
#  'get_yscale',
#  'get_yticklabels',
#  'get_yticklines',
#  'get_yticks',
#  'get_zorder',
#  'grid',
#  'has_data',
#  'have_units',
#  'hexbin',
#  'hist',
#  'hist2d',
#  'hlines',
#  'ignore_existing_data_limits',
#  'images',
#  'imshow',
#  'in_axes',
#  'indicate_inset',
#  'indicate_inset_zoom',
#  'inset_axes',
#  'invert_xaxis',
#  'invert_yaxis',
#  'is_first_col',
#  'is_first_row',
#  'is_last_col',
#  'is_last_row',
#  'is_transform_set',
#  'label_outer',
#  'legend',
#  'legend_',
#  'lines',
#  'locator_params',
#  'loglog',
#  'magnitude_spectrum',
#  'margins',
#  'matshow',
#  'minorticks_off',
#  'minorticks_on',
#  'mouseover',
#  'name',
#  'numCols',
#  'numRows',
#  'patch',
#  'patches',
#  'pchanged',
#  'pcolor',
#  'pcolorfast',
#  'pcolormesh',
#  'phase_spectrum',
#  'pick',
#  'pickable',
#  'pie',
#  'plot',
#  'plot_date',
#  'properties',
#  'psd',
#  'quiver',
#  'quiverkey',
#  'redraw_in_frame',
#  'relim',
#  'remove',
#  'remove_callback',
#  'reset_position',
#  'rowNum',
#  'scatter',
#  'secondary_xaxis',
#  'secondary_yaxis',
#  'semilogx',
#  'semilogy',
#  'set',
#  'set_adjustable',
#  'set_agg_filter',
#  'set_alpha',
#  'set_anchor',
#  'set_animated',
#  'set_aspect',
#  'set_autoscale_on',
#  'set_autoscalex_on',
#  'set_autoscaley_on',
#  'set_axes_locator',
#  'set_axis_off',
#  'set_axis_on',
#  'set_axisbelow',
#  'set_box_aspect',
#  'set_clip_box',
#  'set_clip_on',
#  'set_clip_path',
#  'set_contains',
#  'set_facecolor',
#  'set_fc',
#  'set_figure',
#  'set_frame_on',
#  'set_gid',
#  'set_in_layout',
#  'set_label',
#  'set_navigate',
#  'set_navigate_mode',
#  'set_path_effects',
#  'set_picker',
#  'set_position',
#  'set_prop_cycle',
#  'set_rasterization_zorder',
#  'set_rasterized',
#  'set_sketch_params',
#  'set_snap',
#  'set_subplotspec',
#  'set_title',
#  'set_transform',
#  'set_url',
#  'set_visible',
#  'set_xbound',
#  'set_xlabel',
#  'set_xlim',
#  'set_xmargin',
#  'set_xscale',
#  'set_xticklabels',
#  'set_xticks',
#  'set_ybound',
#  'set_ylabel',
#  'set_ylim',
#  'set_ymargin',
#  'set_yscale',
#  'set_yticklabels',
#  'set_yticks',
#  'set_zorder',
#  'sharex',
#  'sharey',
#  'specgram',
#  'spines',
#  'spy',
#  'stackplot',
#  'stale',
#  'stale_callback',
#  'start_pan',
#  'stem',
#  'step',
#  'sticky_edges',
#  'streamplot',
#  'table',
#  'tables',
#  'text',
#  'texts',
#  'tick_params',
#  'ticklabel_format',
#  'title',
#  'titleOffsetTrans',
#  'transAxes',
#  'transData',
#  'transLimits',
#  'transScale',
#  'tricontour',
#  'tricontourf',
#  'tripcolor',
#  'triplot',
#  'twinx',
#  'twiny',
#  'update',
#  'update_datalim',
#  'update_datalim_bounds',
#  'update_from',
#  'update_params',
#  'use_sticky_edges',
#  'viewLim',
#  'violin',
#  'violinplot',
#  'vlines',
#  'xaxis',
#  'xaxis_date',
#  'xaxis_inverted',
#  'xcorr',
#  'yaxis',
#  'yaxis_date',
#  'yaxis_inverted',
#  'zorder']

# %%
print(ax.findobj())
# Out:
# [<matplotlib.spines.Spine object at 0x000002CF55DF03A0>, <matplotlib.spines.Spine object at 0x000002CF55DF0490>, <matplotlib.spines.Spine object at 0x000002CF55DF0580>, <matplotlib.spines.Spine object at 0x000002CF55DF0670>, Text(0.5, 16.200000000000003, ''), Text(1, 17.200000000000003, ''), <matplotlib.lines.Line2D object at 0x000002CF55DFC4C0>, <matplotlib.lines.Line2D object at 0x000002CF55DFCAF0>, <matplotlib.lines.Line2D object at 0x000002CF55D894F0>, Text(0, 0, ''), Text(0, 1, ''), <matplotlib.axis.XTick object at 0x000002CF55DFC4F0>, <matplotlib.lines.Line2D object at 0x000002CF55DFC220>, <matplotlib.lines.Line2D object at 0x000002CF55DFCDC0>, <matplotlib.lines.Line2D object at 0x000002CF55DFCD90>, Text(0, 0, ''), Text(0, 1, ''), <matplotlib.axis.XTick object at 0x000002CF55DFC640>, <matplotlib.lines.Line2D object at 0x000002CF55DC6A90>, <matplotlib.lines.Line2D object at 0x000002CF55DC69A0>, <matplotlib.lines.Line2D object at 0x000002CF55DC6B80>, Text(0, 0, ''), Text(0, 1, ''), <matplotlib.axis.XTick object at 0x000002CF55DC68E0>, <matplotlib.lines.Line2D object at 0x000002CF55D89A30>, <matplotlib.lines.Line2D object at 0x000002CF55DA40D0>, <matplotlib.lines.Line2D object at 0x000002CF55DA46A0>, Text(0, 0, ''), Text(0, 1, ''), <matplotlib.axis.XTick object at 0x000002CF55D89790>, <matplotlib.lines.Line2D object at 0x000002CF55DDD100>, <matplotlib.lines.Line2D object at 0x000002CF55DDD0D0>, <matplotlib.lines.Line2D object at 0x000002CF55DDDDC0>, Text(0, 0, ''), Text(0, 1, ''), <matplotlib.axis.XTick object at 0x000002CF55DDD040>, <matplotlib.lines.Line2D object at 0x000002CF55DDDBB0>, <matplotlib.lines.Line2D object at 0x000002CF55DDDC70>, <matplotlib.lines.Line2D object at 0x000002CF55DDDE50>, Text(0, 0, ''), Text(0, 1, ''), <matplotlib.axis.XTick object at 0x000002CF55DDDB20>, <matplotlib.lines.Line2D object at 0x000002CF55DD2460>, <matplotlib.lines.Line2D object at 0x000002CF55DD2970>, <matplotlib.lines.Line2D object at 0x000002CF55DD2B80>, Text(0, 0, ''), Text(0, 1, ''), <matplotlib.axis.XTick object at 0x000002CF55DD2520>, <matplotlib.lines.Line2D object at 0x000002CF55DD2250>, <matplotlib.lines.Line2D object at 0x000002CF55DD2100>, <matplotlib.lines.Line2D object at 0x000002CF55DD2D60>, Text(0, 0, ''), Text(0, 1, ''), <matplotlib.axis.XTick object at 0x000002CF55DD2160>, <matplotlib.axis.XAxis object at 0x000002CF55DF0310>, Text(16.200000000000003, 0.5, ''), Text(0, 256.64, ''), <matplotlib.lines.Line2D object at 0x000002CF55E09910>, <matplotlib.lines.Line2D object at 0x000002CF55E09E50>, <matplotlib.lines.Line2D object at 0x000002CF55DF0D90>, Text(0, 0, ''), Text(1, 0, ''), <matplotlib.axis.YTick object at 0x000002CF55DA4340>, <matplotlib.lines.Line2D object at 0x000002CF55E09F40>, <matplotlib.lines.Line2D object at 0x000002CF55E09A60>, <matplotlib.lines.Line2D object at 0x000002CF55E09C40>, Text(0, 0, ''), Text(1, 0, ''), <matplotlib.axis.YTick object at 0x000002CF55E09AF0>, <matplotlib.lines.Line2D object at 0x000002CF55DD2CA0>, <matplotlib.lines.Line2D object at 0x000002CF55DD2F10>, <matplotlib.lines.Line2D object at 0x000002CF55DD27F0>, Text(0, 0, ''), Text(1, 0, ''), <matplotlib.axis.YTick object at 0x000002CF55DD27C0>, <matplotlib.lines.Line2D object at 0x000002CF55D96760>, <matplotlib.lines.Line2D object at 0x000002CF55D961F0>, <matplotlib.lines.Line2D object at 0x000002CF55D96130>, Text(0, 0, ''), Text(1, 0, ''), <matplotlib.axis.YTick object at 0x000002CF55D967F0>, <matplotlib.lines.Line2D object at 0x000002CF55D96AC0>, <matplotlib.lines.Line2D object at 0x000002CF55D96FD0>, <matplotlib.lines.Line2D object at 0x000002CF55D96C40>, Text(0, 0, ''), Text(1, 0, ''), <matplotlib.axis.YTick object at 0x000002CF55D96B50>, <matplotlib.lines.Line2D object at 0x000002CF55DD2C70>, <matplotlib.lines.Line2D object at 0x000002CF55DD23D0>, <matplotlib.lines.Line2D object at 0x000002CF55DD2DF0>, Text(0, 0, ''), Text(1, 0, ''), <matplotlib.axis.YTick object at 0x000002CF55DD2220>, <matplotlib.lines.Line2D object at 0x0000 ...

# %%
np.exp(17.7200000000003)
# Out:
# 49624737.138494045

# %%
avg_distance
# Out:
# 0.9637354825313781

# %% [markdown]
# # ¿Quiénes son los operadores en cada cluster?

# %%
# Primero preparemos la lista de operadores
ingresos = ingresos[['CONCESIONARIO', 'EMPRESA', 'GRUPO', 'INGRESOS_TOTAL_E']]
ingresos['INGRESOS_TOTAL_E'] = pd.to_numeric(ingresos['INGRESOS_TOTAL_E'])
ingresos = ingresos.groupby(['CONCESIONARIO', 'EMPRESA', 'GRUPO']).sum().reset_index().sort_values(by=['INGRESOS_TOTAL_E'], ascending=False)
ingresos
# Out:
# <ipython-input-42-daabab6c15c7>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ingresos['INGRESOS_TOTAL_E'] = pd.to_numeric(ingresos['INGRESOS_TOTAL_E'])
#                                          CONCESIONARIO  \
# 88                      RADIOMOVIL DIPSA, S.A. DE C.V.
# 117                TELEFONOS DE MEXICO, S.A.B. DE C.V.
# 6    AT&T COMUNICACIONES DIGITALES, S. DE R.L. DE C.V.
# 87                            PEGASO PCS, S.A. DE C.V.
# 33   CORPORACION DE RADIO Y TELEVISION DEL NORTE DE...
# ..                                                 ...
# 45          GRUPO CORPORATIVO ZUNUN PAZ, S. A. DE C.V.
# 124                         TELMOV MOVIL, S.A. DE C.V.
# 11         BROCOMUNICACIONES MOVILES, S.A.P.I. DE C.V.
# 36                               EDUARDO PEDRERO PEREZ
# 26                                COMNET, S.A. DE C.V.
#
#                          EMPRESA                        GRUPO  \
# 88                        TELCEL                AMÉRICA MÓVIL
# 117                       TELMEX                AMÉRICA MÓVIL
# 6                           AT&T                         AT&T
# 87                      MOVISTAR                   TELEFÓNICA
# 33                           SKY               GRUPO TELEVISA
# ..                           ...                          ...
# 45   GRUPO CORPORATIVO ZUNUN PAZ  GRUPO CORPORATIVO ZUNUN PAZ
# 124                     TELMOVIL                     TELMOVIL
# 11                      BROMOVIL                     BROMOVIL
# 36         EDUARDO PEDRERO PEREZ        EDUARDO PEDRERO PEREZ
# 26                        COMNET                       COMNET
#
#      INGRESOS_TOTAL_E
# 88       218288998808
# 117      120031140723
# 6         55793781168
# 87        24871583943
# 33        24112031768
# ..                ...
# 45             340986
# 124            332069
# 11             320585
# 36              68200
# 26              43293
#
# [136 rows x 4 columns]

# %% [markdown]
# ## Grandes

# %%
lista_grandes = grande["index"]
lista_original = ingresos_agrupados_transformables.reset_index()
grandes_operadores = lista_original[lista_original['index'].isin(lista_grandes)]
grandes_operadores.sort_values(by=["INGRESOS_TOTAL_E"], ascending=False)
# Out:
#    index           GRUPO  INGRESOS_TOTAL_E
# 0      4   AMÉRICA MÓVIL      338320139531
# 1     36  GRUPO TELEVISA       59301496226
# 2      6            AT&T       55793781168
# 3     98      TELEFÓNICA       24871583943
# 4     60   MEGACABLE-MCM       24676771857
# 5    102       TOTALPLAY       22784126736
# 6      7           AXTEL        8742237448
# 7     62             MVS        5158705766

# %%
# Las empresas que no serían elegibles por estar en el cluster de los grandes operadores:

lista_cluster_grande = grandes_operadores['GRUPO'].unique()
lista_cluster_grande
# Out:
# array(['AMÉRICA MÓVIL', 'GRUPO TELEVISA', 'AT&T', 'TELEFÓNICA',
#        'MEGACABLE-MCM', 'TOTALPLAY', 'AXTEL', 'MVS'], dtype=object)

# %%
# Se trata de 24 operadores que son por sí solos grandes operadores o pertenecen a un GIE grande. 

lista_empresas_cluster_grande = ingresos[ingresos['GRUPO'].isin(lista_cluster_grande)].sort_values(by=['INGRESOS_TOTAL_E'], ascending = False)

lista_empresas_cluster_grande
# Out:
#                                          CONCESIONARIO  \
# 88                      RADIOMOVIL DIPSA, S.A. DE C.V.
# 117                TELEFONOS DE MEXICO, S.A.B. DE C.V.
# 6    AT&T COMUNICACIONES DIGITALES, S. DE R.L. DE C.V.
# 87                            PEGASO PCS, S.A. DE C.V.
# 33   CORPORACION DE RADIO Y TELEVISION DEL NORTE DE...
# 76                            MEGA CABLE, S.A. DE C.V.
# 125        TOTAL PLAY TELECOMUNICACIONES, S.A. DE C.V.
# 15           CABLEMAS TELECOMUNICACIONES, S.A. DE C.V.
# 9                                AXTEL, S.A.B. DE C.V.
# 20                           CABLEVISION, S.A. DE C.V.
# 25   COMERCIALIZADORA DE FRECUENCIAS SATELITALES, S...
# 123             TELEVISION INTERNACIONAL, S.A. DE C.V.
# 78   MEXICO RED DE TELECOMUNICACIONES, S. DE R.L. D...
# 126                  TV CABLE DE ORIENTE, S.A. DE C.V.
# 19                       CABLEVISION RED, S.A. DE C.V.
# 86                               OPERBES, S.A. DE C.V.
# 77    MEGACABLE COMUNICACIONES DE MEXICO, S.A. DE C.V.
# 46   GRUPO DE TELECOMUNICACIONES DE ALTA CAPACIDAD,...
# 14                            CABLE SORO, S.A. DE C.V.
# 23                               COMBAND, S.A. DE C.V.
# 107                  TELECABLE DE COENEO, S.A. DE C.V.
# 116           TELEDISTRIBUCION POR CABLE, S.A. DE C.V.
# 0                                 ADOLFO MERINO MEDINA
#
#                         EMPRESA           GRUPO  INGRESOS_TOTAL_E
# 88                       TELCEL   AMÉRICA MÓVIL      218288998808
# 117                      TELMEX   AMÉRICA MÓVIL      120031140723
# 6                          AT&T            AT&T       55793781168
# 87                     MOVISTAR      TELEFÓNICA       24871583943
# 33                          SKY  GRUPO TELEVISA       24112031768
# 76                    MEGACABLE   MEGACABLE-MCM       23567319612
# 125                   TOTALPLAY       TOTALPLAY       22784126736
# 15                         IZZI  GRUPO TELEVISA        9765026568
# 9                         AXTEL           AXTEL        8742237448
# 20                  CABLEVISION  GRUPO TELEVISA        7858397482
# 25                         DISH             MVS        5147296438
# 123    TELEVISION INTERNACIONAL  GRUPO TELEVISA        4877002991
# 78                     CABLECOM  GRUPO TELEVISA        2954414555
# 126                        IZZI  GRUPO TELEVISA        2907451220
# 19              CABLEVISION RED  GRUPO TELEVISA        2883757649
# 86                       BESTEL  GRUPO TELEVISA        2879231196
# 77                  MCM TELECOM   MEGACABLE-MCM        1075678092
# 46   GTAC REDES DE FIBRA OPTICA  GRUPO TELEVISA        1062534797
# 14                    MEGACABLE   MEGACABLE-MCM          13749617
# 23                        MVSTV             MVS          11409328
# 107                   MEGACABLE   MEGACABLE-MCM          11094520
# 116                   MEGACABLE   MEGACABLE-MCM           8930016
# 0                      CABLEMAS  GRUPO TELEVISA           1648000

# %% [markdown]
# ## Medianos

# %%
lista_medianos = mediano["index"]
lista_original = ingresos_agrupados_transformables.reset_index()
operadores_medianos = lista_original[lista_original['index'].isin(lista_medianos)]
operadores_medianos.sort_values(by=["INGRESOS_TOTAL_E"], ascending=False)
# Out:
#     index                                   GRUPO  INGRESOS_TOTAL_E
# 8       3                                   ALTAN        2834607753
# 9      84                               STARGROUP        1280858832
# 10     68                                     OUI         729143370
# 11     56                                MARCATEL         697511564
# 12    103                              TRANSTELCO         623598170
# 13     26                       EUTELSAT AMERICAS         567683561
# 14     43                           HNS DE MEXICO         503481972
# 15     42                                HISPASAT         418410240
# 16    107                              UC TELECOM         330305215
# 17    111  VERIZON SERVICIOS EMPRESARIALES MEXICO         258650617
# 18     10                         BT LATAM MEXICO         214085985
# 19     24                    ELARA COMUNICACIONES         199874961
# 20     33                               GLOBALSAT         171006327
# 21     64                                   NEWWW         168138067
# 22    114                             WIMOTELECOM         166683899
# 23     44                                   IENTC         152043314
# 24    112                           VIRGIN MOBILE         146563495
# 25     30                                 FREEDOM         112440924
# 26     22                              DIRI MOVIL          98055592
# 27     78                             SIHI MEXICO          88198182
# 28     28                            FLASH MOBILE          85875585
# 29     48                                     IST          83697002
# 30     41                  HIPERCABLE DE MONCLOVA          83430627
# 31     70                              QUATTROCOM          82752385
# 32     96                        TELECABLE MERIDA          57912580
# 33     71                              RAVS CABLE          56882777
# 34     99               TELESISTEMAS PENINSULARES          56882777
# 35    110                                 VASANTA          54810014

# %%
# Las empresas que no serían elegibles por estar en el cluster de los medianos operadores:

lista_cluster_mediano = operadores_medianos['GRUPO'].unique()
lista_cluster_mediano
# Out:
# array(['ALTAN', 'STARGROUP', 'OUI', 'MARCATEL', 'TRANSTELCO',
#        'EUTELSAT AMERICAS', 'HNS DE MEXICO', 'HISPASAT', 'UC TELECOM',
#        'VERIZON SERVICIOS EMPRESARIALES MEXICO', 'BT LATAM MEXICO',
#        'ELARA COMUNICACIONES', 'GLOBALSAT', 'NEWWW', 'WIMOTELECOM',
#        'IENTC', 'VIRGIN MOBILE', 'FREEDOM', 'DIRI MOVIL', 'SIHI MEXICO',
#        'FLASH MOBILE', 'IST', 'HIPERCABLE DE MONCLOVA', 'QUATTROCOM',
#        'TELECABLE MERIDA', 'RAVS CABLE', 'TELESISTEMAS PENINSULARES',
#        'VASANTA'], dtype=object)

# %%
# Se trata de 32 operadores que son por sí solos son medianos operadores o pertenecen a un GIE mediano. 

lista_empresas_cluster_medianos = ingresos[ingresos['GRUPO'].isin(lista_cluster_mediano)].sort_values(by=['INGRESOS_TOTAL_E'], ascending = False)

lista_empresas_cluster_medianos
# Out:
#                                          CONCESIONARIO  \
# 4                        ALTAN REDES, S.A.P.I. DE C.V.
# 47                           GRUPO W COM, S.A. DE C.V.
# 115               TELECOMUNICACIONES 360, S.A. DE C.V.
# 71                          MARCATEL COM, S.A. DE C.V.
# 74           MAXCOM TELECOMUNICACIONES, S.A.B. DE C.V.
# 93                   SATELITES MEXICANOS, S.A. DE C.V.
# 55                         HNS DE MEXICO, S.A. DE C.V.
# 122                     TELEVERA RED, S.A.P.I. DE C.V.
# 128            UC TELECOMUNICACIONES, S.A.P.I. DE C.V.
# 132  VERIZON SERVICIOS EMPRESARIALES MEXICO, S. DE ...
# 8             AXESS NET.SOLUTIONS MEXICO, S.A. DE C.V.
# 12                       BT LATAM MEXICO, S.A. DE C.V.
# 48                   GSAT COMUNICACIONES, S.A. DE C.V.
# 103                    TALENTO NET, S. DE R.L. DE C.V.
# 135                          WIMOTELECOM, S.A. DE C.V.
# 57                           IENTC, S. DE R.L. DE C.V.
# 133           VIRGIN MOBILE MEXICO, S. DE R.L. DE C.V.
# 54                       HISPASAT MEXICO, S.A. DE C.V.
# 37              ELARA COMUNICACIONES, S.A.P.I. DE C.V.
# 41                     FREEDOMPOP MEXICO, S.A. DE C.V.
# 35               DIRI TELECOMUNICACIONES, S.A. DE C.V.
# 96                     SIHI MEXICO, S. DE R.L. DE C.V.
# 69            LOGISTICA ACN MEXICO, S. DE R.L. DE C.V.
# 59   INTEGRACION DE SERVICIOS Y TECNOLOGIA, S.A. DE...
# 53                HIPERCABLE DE MONCLOVA, S.A. DE C.V.
# 67                         LANTOINTERNET, S.A. DE C.V.
# 38              ELARA COMUNICACIONES, S.A.P.I. DE C.V.
# 7             AXESS NET.SOLUTIONS MEXICO, S.A. DE C.V.
# 109                  TELECABLE DE MERIDA, S.A. DE C.V.
# 119            TELESISTEMAS PENINSULARES, S.A. DE C.V.
# 90                 ROBERTO ANTONIO MALDONADO GUTIERREZ
# 131           VASANTA COMUNICACIONES, S.A.P.I. DE C.V.
#
#                                     EMPRESA  \
# 4                                     ALTAN
# 47                          STAR GO/STAR TV
# 115                                     OUI
# 71                                 MARCATEL
# 74                                   MAXCOM
# 93                        EUTELSAT AMERICAS
# 55                            HNS DE MEXICO
# 122                            TELEVERA RED
# 128                              UC TELECOM
# 132  VERIZON SERVICIOS EMPRESARIALES MEXICO
# 8                                     AXESS
# 12                          BT LATAM MEXICO
# 48                               GLOBAL SAT
# 103                                   NEWWW
# 135                             WIMOTELECOM
# 57                 IENTC TELECOMUNICACIONES
# 133                           VIRGIN MOBILE
# 54                                 HISPASAT
# 37                     ELARA COMUNICACIONES
# 41                               FREEDOMPOP
# 35                               DIRI MOVIL
# 96                              SIHI MEXICO
# 69                             FLASH MOBILE
# 59                                      IST
# 53                   HIPERCABLE DE MONCLOVA
# 67                               QUATTROCOM
# 38                 IVEEP INTERNET SATELITAL
# 7                                    AXESAT
# 109                        TELECABLE MERIDA
# 119               TELESISTEMAS PENINSULARES
# 90                               RAVS CABLE
# 131                                 VASANTA
#
#                                       GRUPO  INGRESOS_TOTAL_E
# 4                                     ALTAN        2834607753
# 47                                STARGROUP         858427009
# 115                                     OUI         729143370
# 71                                 MARCATEL         697511564
# 74                               TRANSTELCO         623598170
# 93                        EUTELSAT AMERICAS         567683561
# 55                            HNS DE MEXICO         503481972
# 122                               STARGROUP         422431823
# 128                              UC TELECOM         330305215
# 132  VERIZON SERVICIOS EMPRESARIALES MEXICO         258650617
# 8                                  HISPASAT         217920735
# 12                          BT LATAM MEXICO         214085985
# 48                                GLOBALSAT         171006327
# 103                                   NEWWW         168138067
# 135                             WIMOTELECOM         166683899
# 57                                    IENTC         152043314
# 133                           VIRGIN MOBILE         146563495
# 54                                 HISPASAT         139535703
# 37                     ELARA COMUNICACIONES         134141678
# 41                                  FREEDOM         112440924
# 35                               DIRI MOVIL          98055592
# 96                              SIHI MEXICO          88198182
# 69                             FLASH MOBILE          85875585
# 59                                      IST          83697002
# 53                   HIPERCABLE DE MONCLOVA          83430627
# 67                               QUATTROCOM          82752385
# 38                     ELARA COMUNICACIONES          65733284
# 7                                  HISPASAT          60953802
# 109                        TELECABLE MERIDA          57912580
# 119               TELESISTEMAS PENINSULARES          56882777
# 90                               RAVS CABLE          56882777
# 131                                 VASANTA          54810014

# %% [markdown]
# ## Pequeños

# %%
lista_pequeños = pequeño["index"]
operadores_pequeños = lista_original[lista_original['index'].isin(lista_pequeños)]
operadores_pequeños.sort_values(by=["INGRESOS_TOTAL_E"], ascending=False)
# Out:
#      index                         GRUPO  INGRESOS_TOTAL_E
# 36      77          SIERRA MADRE TELECOM          43442490
# 37     115                  YOBI TELECOM          43316605
# 38      20  COORDINADORA DE TV POR CABLE          41293042
# 39      72                       RBACATV          41185567
# 40      53            LINK TE CONECTAMOS          39772709
# ..     ...                           ...               ...
# 111     35   GRUPO CORPORATIVO ZUNUN PAZ            340986
# 112    100                      TELMOVIL            332069
# 113      9                      BROMOVIL            320585
# 114     23         EDUARDO PEDRERO PEREZ             68200
# 115     18                        COMNET             43293
#
# [80 rows x 3 columns]

# %%
print(operadores_pequeños.to_markdown())
# Out:
# |     |   index | GRUPO                           |   INGRESOS_TOTAL_E |
# |----:|--------:|:--------------------------------|-------------------:|
# |  36 |      77 | SIERRA MADRE TELECOM            |        4.34425e+07 |
# |  37 |     115 | YOBI TELECOM                    |        4.33166e+07 |
# |  38 |      20 | COORDINADORA DE TV POR CABLE    |        4.1293e+07  |
# |  39 |      72 | RBACATV                         |        4.11856e+07 |
# |  40 |      53 | LINK TE CONECTAMOS              |        3.97727e+07 |
# |  41 |      88 | TELECABLE DE CAMPECHE           |        3.7453e+07  |
# |  42 |     113 | WEEX                            |        3.34465e+07 |
# |  43 |       8 | BBG COMUNICACION                |        3.09964e+07 |
# |  44 |      75 | SARA QUIROZ CHAPA               |        3.06811e+07 |
# |  45 |      16 | CCA                             |        2.57329e+07 |
# |  46 |      32 | GILAT                           |        2.376e+07   |
# |  47 |      14 | CABLEVISION DE APATZINGAN       |        2.29516e+07 |
# |  48 |      57 | MARCO ANTONIO ROSALES HERRERA   |        2.28824e+07 |
# |  49 |     101 | TOKA MOVIL                      |        2.27486e+07 |
# |  50 |      65 | NEXT TELEKOM                    |        2.24154e+07 |
# |  51 |      95 | TELECABLE DE XALTIANGUIS        |        2.09784e+07 |
# |  52 |      97 | TELECOM NACIONAL                |        2.05756e+07 |
# |  53 |     108 | USA TELECOM                     |        1.45308e+07 |
# |  54 |      85 | SUPERCOM                        |        1.43247e+07 |
# |  55 |      93 | TELECABLE DE TICUL              |        1.39756e+07 |
# |  56 |       2 | AIRECABLE                       |        1.33273e+07 |
# |  57 |      66 | OPERADORA TELEFONICA PENINSULAR |        1.32401e+07 |
# |  58 |      59 | MAXICABLE                       |        1.31822e+07 |
# |  59 |      17 | COMCAB                          |        1.29293e+07 |
# |  60 |      39 | GURUCOMM                        |        1.29234e+07 |
# |  61 |      13 | CABLEPLAY                       |        1.24303e+07 |
# |  62 |      79 | SIMPATI                         |        1.23456e+07 |
# |  63 |      61 | MUCHOS MEGAS                    |        1.16666e+07 |
# |  64 |      54 | LOGITEL                         |        1.11001e+07 |
# |  65 |      67 | OTROS                           |        1.06256e+07 |
# |  66 |     104 | TV OJO CALIENTE                 |        8.41977e+06 |
# |  67 |      29 | FRANCISCO GUERRA GARCIA         |        8.21122e+06 |
# |  68 |      89 | TELECABLE DE COAHUAYANA         |        7.99437e+06 |
# |  69 |      90 | TELECABLE DE CUERNAVACA         |        7.88457e+06 |
# |  70 |      11 | BUENO CELL                      |        7.30099e+06 |
# |  71 |      82 | SISTV                           |        6.53316e+06 |
# |  72 |     106 | TVDIG                           |        6.02388e+06 |
# |  73 |       0 | ADDINTELI                       |        5.53496e+06 |
# |  74 |      92 | TELECABLE DE TEKAX              |        5.47355e+06 |
# |  75 |      40 | HERMOVISION                     |        4.91779e+06 |
# |  76 |      27 | EYCO DE LOS ALTOS               |        4.79698e+06 |
# |  77 |      63 | NET LINK                        |        4.75686e+06 |
# |  78 |      94 | TELECABLE DE VILLANUEVA         |        4.35598e+06 |
# |  79 |      31 | GABRIEL BUTRON CHIAPA           |        4.26612e+06 |
# |  80 |      81 | SISCAB DE MEXICO                |        4.0035e+06  |
# |  81 |      49 | JACE TELECOM                    |        3.30006e+06 |
# |  82 |     109 | VADSA                           |        3.18506e+06 |
# |  83 |      83 | STAR NET                        |        2.85687e+06 |
# |  84 |      80 | SINOTECA                        |        2.83684e+06 |
# |  85 |      37 | GUILLERMO MEDELLIN MILAN        |        2.77019e+06 |
# |  86 |       5 | ARELY ISABEL GONGORA PECH       |        2.75749e+06 |
# |  87 |       1 | AGUSTIN PEREZ VIEYRA            |        2.72656e+06 |
# |  88 |      76 | SECSA                           |        2.71773e+06 |
# |  89 |      46 | INTEGRA COMUNICACIONES          |        2.59808e+06 |
# |  90 |      34 | GOBO                            |        2.59808e+06 |
# |  91 |      87 | TELECABLE DE AGUILILLA          |        2.4606e+06  |
# |  92 |      86 | TELECAB                         |        2.36598e+06 |
# |  93 |      74 | ROBERTO LOPEZ BRAVO             |        2.36469e+06 |
# |  94 |      58 | MARKETING 358                   |        2.32302e+06 |
# |  95 |      19 | CONCABLETV                      |        2.28826e+06 |
# |  96 |      51 | JESUS MIGUEL FERNANDEZ GUERRERO |        2.27944e+06 |
# |  97 |      25 | ESPID                           |        2.25197e+06 |
# |  98 |      55 | MANUEL LOPEZ AVILA              |        2.19956e+06 |
# |  99 |      73 | RED DOG                         |        2.14462e+06 |
# | 100 |      38 | GUILLERMO ZARATE GARCIA         |        1.76534e+06 |
# | 101 |      52 | JOSE JULIAN SACRAMENTO GARZA    |        1.53341e+06 |
# | 102 |      15 | CABLEVISION DE LA HUACANA       |        1.51593e+06 |
# | 103 |      21 | CRO.NET                         |        1.42539e+06 |
# | 104 |     105 | TV-K                            |        1.09457e+06 |
# | 105 |      69 | QBO CEL                         |   998133           |
# | 106 |      91 | TELECABLE DE MARIANO ESCOBEDO   |   568497           |
# | 107 |      47 | ISALIA MORENO ZETINA            |   497141           |
# | 108 |      50 | JAIME SANCHEZ SANCHEZ           |   474403           |
# | 109 |      12 | CABLE SISTEMA DEL CENTRO        |   474403           |
# | 110 |      45 | IGOU TELECOM                    |   424046           |
# | 111 |      35 | GRUPO CORPORATIVO ZUNUN PAZ     |   340986           |
# | 112 |     100 | TELMOVIL                        |   332069           |
# | 113 |       9 | BROMOVIL                        |   320585           |
# | 114 |      23 | EDUARDO PEDRERO PEREZ           |    68200           |
# | 115 |      18 | COMNET                          |    43293           |

# %%
# Las empresas que no serían elegibles por estar en el cluster de los medianos operadores:
lista_cluster_pequeños = operadores_pequeños['GRUPO'].unique()
lista_cluster_pequeños
# Out:
# array(['SIERRA MADRE TELECOM', 'YOBI TELECOM',
#        'COORDINADORA DE TV POR CABLE', 'RBACATV', 'LINK TE CONECTAMOS',
#        'TELECABLE DE CAMPECHE', 'WEEX', 'BBG COMUNICACION',
#        'SARA QUIROZ CHAPA', 'CCA', 'GILAT', 'CABLEVISION DE APATZINGAN',
#        'MARCO ANTONIO ROSALES HERRERA', 'TOKA MOVIL', 'NEXT TELEKOM',
#        'TELECABLE DE XALTIANGUIS', 'TELECOM NACIONAL', 'USA TELECOM',
#        'SUPERCOM', 'TELECABLE DE TICUL', 'AIRECABLE',
#        'OPERADORA TELEFONICA PENINSULAR', 'MAXICABLE', 'COMCAB',
#        'GURUCOMM', 'CABLEPLAY', 'SIMPATI', 'MUCHOS MEGAS', 'LOGITEL',
#        'OTROS', 'TV OJO CALIENTE', 'FRANCISCO GUERRA GARCIA',
#        'TELECABLE DE COAHUAYANA', 'TELECABLE DE CUERNAVACA', 'BUENO CELL',
#        'SISTV', 'TVDIG', 'ADDINTELI', 'TELECABLE DE TEKAX', 'HERMOVISION',
#        'EYCO DE LOS ALTOS', 'NET LINK', 'TELECABLE DE VILLANUEVA',
#        'GABRIEL BUTRON CHIAPA', 'SISCAB DE MEXICO', 'JACE TELECOM',
#        'VADSA', 'STAR NET', 'SINOTECA', 'GUILLERMO MEDELLIN MILAN',
#        'ARELY ISABEL GONGORA PECH', 'AGUSTIN PEREZ VIEYRA', 'SECSA',
#        'INTEGRA COMUNICACIONES', 'GOBO', 'TELECABLE DE AGUILILLA',
#        'TELECAB', 'ROBERTO LOPEZ BRAVO', 'MARKETING 358', 'CONCABLETV',
#        'JESUS MIGUEL FERNANDEZ GUERRERO', 'ESPID', 'MANUEL LOPEZ AVILA',
#        'RED DOG', 'GUILLERMO ZARATE GARCIA',
#        'JOSE JULIAN SACRAMENTO GARZA', 'CABLEVISION DE LA HUACANA',
#        'CRO.NET', 'TV-K', 'QBO CEL', 'TELECABLE DE MARIANO ESCOBEDO',
#        'ISALIA MORENO ZETINA', 'JAIME SANCHEZ SANCHEZ',
#        'CABLE SISTEMA DEL CENTRO', 'IGOU TELECOM',
#        'GRUPO CORPORATIVO ZUNUN PAZ', 'TELMOVIL', 'BROMOVIL',
#        'EDUARDO PEDRERO PEREZ', 'COMNET'], dtype=object)

# %%
# Se trata de 81 operadores que son por sí solos son pequeños operadores o pertenecen a un GIE pequeño. 

lista_empresas_cluster_pequeños = ingresos[ingresos['GRUPO'].isin(lista_cluster_pequeños)].sort_values(by=['INGRESOS_TOTAL_E'], ascending = False)

lista_empresas_cluster_pequeños
# Out:
#                                    CONCESIONARIO  \
# 94           SIERRA MADRE INTERNET, S.A. DE C.V.
# 21                    CELMAX MOVIL, S.A. DE C.V.
# 32    COORDINADORA DE TV POR CABLE, S.A. DE C.V.
# 89                        RBA CATV, S.A. DE C.V.
# 105          TELECABLE DE CAMPECHE, S.A. DE C.V.
# ..                                           ...
# 45    GRUPO CORPORATIVO ZUNUN PAZ, S. A. DE C.V.
# 124                   TELMOV MOVIL, S.A. DE C.V.
# 11   BROCOMUNICACIONES MOVILES, S.A.P.I. DE C.V.
# 36                         EDUARDO PEDRERO PEREZ
# 26                          COMNET, S.A. DE C.V.
#
#                           EMPRESA                         GRUPO  \
# 94                   SIERRA MADRE          SIERRA MADRE TELECOM
# 21                   YOBI TELECOM                  YOBI TELECOM
# 32   COORDINADORA DE TV POR CABLE  COORDINADORA DE TV POR CABLE
# 89                        RBACATV                       RBACATV
# 105         TELECABLE DE CAMPECHE         TELECABLE DE CAMPECHE
# ..                            ...                           ...
# 45    GRUPO CORPORATIVO ZUNUN PAZ   GRUPO CORPORATIVO ZUNUN PAZ
# 124                      TELMOVIL                      TELMOVIL
# 11                       BROMOVIL                      BROMOVIL
# 36          EDUARDO PEDRERO PEREZ         EDUARDO PEDRERO PEREZ
# 26                         COMNET                        COMNET
#
#      INGRESOS_TOTAL_E
# 94           43442490
# 21           43316605
# 32           41293042
# 89           41185567
# 105          37452991
# ..                ...
# 45             340986
# 124            332069
# 11             320585
# 36              68200
# 26              43293
#
# [81 rows x 4 columns]

# %%
# Análisis con quartiles y rango intercuantil para efectos de identificar los outliers

quartiles = lista_empresas_cluster_pequeños["INGRESOS_TOTAL_E"].quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

print(f"El cuartil más bajo de los ingresos es: {lowerq}")
print(f"El cuartil más alto de los ingresos es: {upperq}")
print(f"El rango intercuantil de los ingresos es: {iqr}")
print(f"El ingreso medio es: {quartiles[0.5]} ")


lower_bound = lowerq - (3*iqr)
upper_bound = upperq + (3*iqr) # se circunscribe completamente la distribución considerando una distribución gausiana.
print(f"Umbral final donde los valores por encima de {upper_bound} no son elegibles.")
# Out:
# El cuartil más bajo de los ingresos es: 2288255.0
# El cuartil más alto de los ingresos es: 13975584.41
# El rango intercuantil de los ingresos es: 11687329.41
# El ingreso medio es: 4917794.0
# Umbral final donde los valores por encima de 49037572.64 no son elegibles.

# %% [markdown]
# # El umbral para ser elegible como pequeño operador implica ingresos nominales acumulados al cierre de 2021 menores o iguales a $49,037,573 millones de pesos
