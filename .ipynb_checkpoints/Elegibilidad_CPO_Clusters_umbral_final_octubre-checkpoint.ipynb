# %% [markdown]
# # Aplicación del modelo de aprendizaje automático no supervisado K-Means (1-D) para efectos de identificar los clusters y el umbral máximo a partir del cual un operador de telecomunicaciones se considera pequeño para efectos de determinar su elegibilidad en el Comité de Pequeños Operadores.
#
# ### Datos
#
# El umbral máximo para determinar si un proveedor de servicios de telecomunicaciones, con fines comerciales, es elegible para participar en el Comité, será calculado a partir de los datos de ingreso nominal acumulados anualmente (al cuarto trimestre del año anterior), los cuales han sido reportados por los operadores y publicados en el Banco de Información de Telecomunicaciones del Instituto Federal de Telecomunicaciones.
#
# Como primer paso, serán acumulados los ingresos anuales publicados en el Banco de Información de Telecomunicaciones, con información al cierre del cuarto trimestre del año inmediato anterior y se realizan algunos ajustes tendientes a consolidar los datos por grupo de interés económico, a fin de comenzar el análisis correspondiente.
#
#
# ### Metodología
#
# El referido umbral se calcula a partir del método de agrupamiento conocido como k-medias o k-means (como se le denomina en el idioma inglés). Se trata de un algoritmo de aprendizaje automático no supervisado que busca identificar los grupos de observaciones (i.e. los ingresos nominales acumulados anualmente) que son similares. Para ello, se parte del concepto básico de “distancia” para determinar similitudes entre los operadores de telecomunicaciones. Por ejemplo, si tomamos los ingresos nominales acumulados anuales de dos empresas, la distancia entre sus respectivos datos es una medida del grado de cercanía o similitud que existe entre las mismas.
#
# Como se ilustra en el siguiente diagrama, se define aleatoriamente un prototipo para cada grupo y se mide la distancia que tienen los ingresos nominales acumulados anualmente de cada elemento respecto al prototipo o centroide (v.gr. punto medio de los objetos). Posteriormente, ese centroide se vuelve a definir para cada grupo y este proceso se repite hasta que los objetos no cambien de grupo y que los centroides no sufran variaciones; lo que confirma que existe evidencia de que los grupos están correctamente definidos.
#
# Para la determinación del número óptimo de clusters o grupos (k), se utiliza el criterio denominado Elbow, que consiste en seleccionar el k donde la reducción de la suma de la distancia cuadrática de los elementos de cada grupo a su centroide (inercia) ya no es significativa. Lo que implica que un cluster adicional ya no aumenta significativamente la similitud entre los elementos de cada grupo, reduciendo la eficiencia en la agrupación sin una ganancia significativa en la convergencia o similitud de cada elemento en cada grupo . En este sentido, el principio de selección óptima de k es el de tener un valor reducido de inercia y el número menor de centroides o agrupaciones.
#
# <img title="a title" alt="Alt text" src="kmeans.png">

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts
from scipy.cluster.vq import vq, kmeans, whiten
import dataframe_image as dfi
import math
import seaborn as sns
from sklearn.cluster import KMeans

# %%
pd.set_option('display.float_format', lambda x: '%.0f' % x)

# %%
# Es importante mencionar que esta base de datos proviene de la última actualización en el Banco de Información de Telecomunicaciones
# del IFT, consultado el 18 de octubre de 2022. 
# Por este motivo se incluye en este repositorio esa versión de la base de datos a efectos de que si desea replicar el 
# resultado, lo haga con este conjunto de datos, toda vez que la información en el BIT podría variar sin previo aviso.

ingresos = pd.read_csv('TD_INGRESOS_TELECOM_ITE_VA_octubre.csv', encoding ='Latin1')
ingresos
# Out:
#        FOLIO  ANIO  TRIM      FECHA  \
# 0     100025  2021     1  15-mar-21
# 1     100025  2021     2  15-jun-21
# 2     100025  2021     3  15-sep-21
# 3     100025  2021     4  15DEC2021
# 4     100028  2021     1  15-mar-21
# ...      ...   ...   ...        ...
# 2650  999997  2014     2  15-jun-14
# 2651  999997  2014     3  15-sep-14
# 2652  999997  2014     4  15DEC2014
# 2653  999997  2015     1  15-mar-15
# 2654  999997  2015     2  15-jun-15
#
#                                    CONCESIONARIO K_EMPRESA  \
# 0                        ABILIO VILLARREAL MORGA     C0004
# 1                        ABILIO VILLARREAL MORGA     C0004
# 2                        ABILIO VILLARREAL MORGA     C0004
# 3                        ABILIO VILLARREAL MORGA     C0004
# 4                           ADOLFO MERINO MEDINA     C0089
# ...                                          ...       ...
# 2650  MICRO SISTEMAS INTERNACIONAL, S.A. DE C.V.     C0384
# 2651  MICRO SISTEMAS INTERNACIONAL, S.A. DE C.V.     C0384
# 2652  MICRO SISTEMAS INTERNACIONAL, S.A. DE C.V.     C0384
# 2653  MICRO SISTEMAS INTERNACIONAL, S.A. DE C.V.     C0384
# 2654  MICRO SISTEMAS INTERNACIONAL, S.A. DE C.V.     C0384
#
#                           EMPRESA K_GRUPO                        GRUPO  \
# 0         ABILIO VILLARREAL MORGA    C004      ABILIO VILLARREAL MORGA
# 1         ABILIO VILLARREAL MORGA    C004      ABILIO VILLARREAL MORGA
# 2         ABILIO VILLARREAL MORGA    C004      ABILIO VILLARREAL MORGA
# 3         ABILIO VILLARREAL MORGA    C004      ABILIO VILLARREAL MORGA
# 4                        CABLEMAS    G004               GRUPO TELEVISA
# ...                           ...     ...                          ...
# 2650  MICROSISTEMAS INTERNACIONAL    C384  MICROSISTEMAS INTERNACIONAL
# 2651  MICROSISTEMAS INTERNACIONAL    C384  MICROSISTEMAS INTERNACIONAL
# 2652  MICROSISTEMAS INTERNACIONAL    C384  MICROSISTEMAS INTERNACIONAL
# 2653  MICROSISTEMAS INTERNACIONAL    C384  MICROSISTEMAS INTERNACIONAL
# 2654  MICROSISTEMAS INTERNACIONAL    C384  MICROSISTEMAS INTERNACIONAL
#
#      I_FIJO_MOVIL  INGRESOS_TOTAL_E I_ANUAL_TRIM
# 0            Fijo                 0   Trimestral
# 1            Fijo                 0   Trimestral
# 2            Fijo                 0   Trimestral
# 3            Fijo                 0   Trimestral
# 4            Fijo            389669   Trimestral
# ...           ...               ...          ...
# 2650         Fijo               NaN   Trimestral
# 2651         Fijo               NaN   Trimestral
# 2652         Fijo               NaN   Trimestral
# 2653         Fijo               NaN   Trimestral
# 2654         Fijo            720000   Trimestral
#
# [2655 rows x 12 columns]

# %%
ingresos['GRUPO'].unique()
# Out:
# array(['ABILIO VILLARREAL MORGA', 'GRUPO TELEVISA',
#        'AGUSTIN PEREZ VIEYRA', 'ALEJANDRO ALFONSO MELGAREJO ALTAMIRANO',
#        'ALEJANDRO MELGAREJO CORTES', 'ARELY ISABEL GONGORA PECH',
#        'ADA CRISTINA MAGAÑA CASTRO', 'DANIEL GARCIA GODINEZ',
#        'FRANCISCO GUERRA GARCIA', 'GABRIEL BUTRON CHIAPA',
#        'GENY MARGARITA MOGUEL REJON', 'GUILLERMO MEDELLIN MILAN',
#        'GUILLERMO ZARATE GARCIA', 'JAIME SANCHEZ SANCHEZ',
#        'JESUS MIGUEL FERNANDEZ GUERRERO', 'JOSE JULIAN SACRAMENTO GARZA',
#        'MANUEL LOPEZ AVILA', 'MARCO ANTONIO ROSALES HERRERA',
#        'RAFAEL SANCHEZ NAZARIEGA', 'ROBERTO LOPEZ BRAVO',
#        'SARA QUIROZ CHAPA', 'IUSACELL-UNEFÓN', 'LOGITEL', 'TV-K',
#        'TELEFÓNICA', 'COSMORED', 'TELECAB', 'ULTRAVISION', 'STARGROUP',
#        'ALESTRA', 'AXTEL', 'MEGACABLE-MCM', 'TELECABLE DE RIOVERDE',
#        'GRUPO TELECABLE', 'GLOBALSAT', 'TELECOM NACIONAL',
#        'GRUPO SALINAS', 'AXESAT', 'AIRECABLE', 'CABLECOM', 'USA TELECOM',
#        'CODITEL', 'COMCAB', 'SINOTECA', 'MULTICOM', 'TELECABLE',
#        'TV OJO CALIENTE', 'SCT', 'TELEVISION DE PEDRO ESCOBEDO',
#        'SPACENET', 'GTAC REDES DE FIBRA OPTICA', 'CABLE DIVERSION',
#        'TRANSTELCO', 'AMÉRICA MÓVIL', 'TV REY', 'CABLEVISION RED',
#        'COMUNICACION B15', 'MARCATEL', 'LINK TE CONECTAMOS', 'HISPASAT',
#        'ELARA COMUNICACIONES', 'TELECOMUNICACIONES DE CERRITOS',
#        'CABLE DEL VALLE DE TOLUCA', 'SKYTEL', 'CABLEVISION DE APATZINGAN',
#        'DISH-MVS', 'MAXICABLE', 'INTERCABLE DEL MAYAB', 'BT LATAM MEXICO',
#        'SISTEMA DE CABLE HKAN', 'ES TV COM',
#        'ENTRETENIMIENTO Y TELECOMUNICACIONES', 'SERVITRON',
#        'TELECABLE DE TAMAYO', 'TELECABLE DE COAHUAYANA', 'CONVERGIA',
#        'MARCALESS', 'VERIZON SERVICIOS EMPRESARIALES MEXICO',
#        'MVH TELECOMUNICACIONES', 'BBG COMUNICACION', 'CIERTO', 'SUPERCOM',
#        'JACE TELECOM', 'NEXTEL', 'SECSA', 'SERGIO PEDROZA AGUILERA',
#        'MAZ TIEMPO', 'RAVS CABLE', 'HNS DE MEXICO', 'MEGATEL', 'TV ZAC',
#        'UC TELECOM', 'CENTURYLINK', 'MAXCOM', 'EJA TELECOMM',
#        'TELECABLE DE AGUILILLA', 'CONSORCIO JAGO COMUNICACIONES',
#        'TOMAS CRISTOBAL CRUZ', 'TELECABLE DEL MINERAL',
#        'HIPERCABLE DE MONCLOVA', 'DIVERSICABLE', 'STAR NET',
#        'TELECABLE DE XALTIANGUIS', 'IST',
#        'TELEVISION POR CABLE DE MUZQUIZ', 'TOKA MOVIL',
#        'OPERADORA TELEFONICA PENINSULAR', 'VIRGIN MOBILE', 'BUENO CELL',
#        'IENTC', 'MULTIMEDIA CTI', 'CABLEVISION DE LA HUACANA', 'OTROS',
#        'TELECABLE DE VILLANUEVA', 'QBO CEL', 'CONCABLETV', 'WEEX',
#        'TELEWEB', 'NEUS MOBILE', 'AT&T', 'TELECABLE MERIDA', 'TVDIG',
#        'NEXT TELEKOM', 'FLASH MOBILE', 'CABLE SISTEMA DEL CENTRO',
#        'SIMPATI', 'HERMOVISION', 'SIHI MEXICO', 'COMNET', 'ANKLA',
#        'LUMENET COMUNICACIONES', 'PUBLIFON', 'VADSA',
#        'CABLE SALTO DEL AGUA', 'RBACATV', 'PROTOKOL TELECOMUNICACIONES',
#        'EYCO DE LOS ALTOS', 'HER MOBILE', 'FREEDOM', 'ALTAN',
#        'SUPERCABLE TIXKOKOB', 'TELECOMUNICACIONES DIVERSIFICADAS',
#        'SIERRA MADRE TELECOM', 'VIASAT', 'SIMPLII', 'AVANZADA', 'STARKA',
#        'RADIO FRECUENCIAS CONCESIONADAS', 'QUATTROCOM', 'SIX MOVIL',
#        'LAREDONET', 'NET LINK', 'SISCAB DE MEXICO', 'ESPID', 'ALTCEL',
#        'AIRBUS', 'ESMERO SOLUTIONS', 'GILAT', 'VASANTA',
#        'GRUPO CORPORATIVO ZUNUN PAZ', 'INTEGRA COMUNICACIONES',
#        'CABLEPLAY', 'GEOS TELECOM', 'CARMEL', 'MIIO', 'MUCHOS MEGAS',
#        'YOBI TELECOM', 'NETWEY', 'GURUCOMM', 'SISTV',
#        'TELIA CARRIER COMMUNICATIONS MEXICO', 'CCA', 'EDILAR',
#        'MOTOROLA SOLUTIONS', 'TELECABLE DE MARIANO ESCOBEDO',
#        'TELECABLE DE EL NARANJO', 'ADDINTELI', 'DIRI MOVIL',
#        'IGOU TELECOM', 'JOAQUIN LEON ASPANO', 'NEWWW',
#        'NORMA GUTIERREZ FONG', 'YONDER', 'WIMOTELECOM',
#        'AXIA CABLECENTRO', 'CRO.NET', 'HUGO ABEL PUENTE ANGUIANO', 'GOBO',
#        'RED DOG', 'TELMOVIL', 'CABLEXTREMO', 'MARKETING 358', 'BROMOVIL',
#        'SPACEX-STARLINK', 'REX MOVIL', 'CITRO TELECOM',
#        'EDUARDO PEDRERO PEREZ', 'MICROSISTEMAS INTERNACIONAL'],
#       dtype=object)

# %%
len(ingresos['GRUPO'].unique())
# Out:
# 198

# %%
ingresos.columns
# Out:
# Index(['FOLIO', 'ANIO', 'TRIM', 'FECHA', 'CONCESIONARIO', 'K_EMPRESA',
#        'EMPRESA', 'K_GRUPO', 'GRUPO', 'I_FIJO_MOVIL', 'INGRESOS_TOTAL_E',
#        'I_ANUAL_TRIM'],
#       dtype='object')

# %%
# seleccionamos columnas relevantes
variables_relevantes = ['ANIO','TRIM', 'CONCESIONARIO', 'EMPRESA', 'GRUPO', 'INGRESOS_TOTAL_E']

ingresos2 = ingresos[variables_relevantes]
ingresos2
# Out:
#       ANIO  TRIM                               CONCESIONARIO  \
# 0     2021     1                     ABILIO VILLARREAL MORGA
# 1     2021     2                     ABILIO VILLARREAL MORGA
# 2     2021     3                     ABILIO VILLARREAL MORGA
# 3     2021     4                     ABILIO VILLARREAL MORGA
# 4     2021     1                        ADOLFO MERINO MEDINA
# ...    ...   ...                                         ...
# 2650  2014     2  MICRO SISTEMAS INTERNACIONAL, S.A. DE C.V.
# 2651  2014     3  MICRO SISTEMAS INTERNACIONAL, S.A. DE C.V.
# 2652  2014     4  MICRO SISTEMAS INTERNACIONAL, S.A. DE C.V.
# 2653  2015     1  MICRO SISTEMAS INTERNACIONAL, S.A. DE C.V.
# 2654  2015     2  MICRO SISTEMAS INTERNACIONAL, S.A. DE C.V.
#
#                           EMPRESA                        GRUPO  \
# 0         ABILIO VILLARREAL MORGA      ABILIO VILLARREAL MORGA
# 1         ABILIO VILLARREAL MORGA      ABILIO VILLARREAL MORGA
# 2         ABILIO VILLARREAL MORGA      ABILIO VILLARREAL MORGA
# 3         ABILIO VILLARREAL MORGA      ABILIO VILLARREAL MORGA
# 4                        CABLEMAS               GRUPO TELEVISA
# ...                           ...                          ...
# 2650  MICROSISTEMAS INTERNACIONAL  MICROSISTEMAS INTERNACIONAL
# 2651  MICROSISTEMAS INTERNACIONAL  MICROSISTEMAS INTERNACIONAL
# 2652  MICROSISTEMAS INTERNACIONAL  MICROSISTEMAS INTERNACIONAL
# 2653  MICROSISTEMAS INTERNACIONAL  MICROSISTEMAS INTERNACIONAL
# 2654  MICROSISTEMAS INTERNACIONAL  MICROSISTEMAS INTERNACIONAL
#
#       INGRESOS_TOTAL_E
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4               389669
# ...                ...
# 2650               NaN
# 2651               NaN
# 2652               NaN
# 2653               NaN
# 2654            720000
#
# [2655 rows x 6 columns]

# %%
# seleccionar sólo los registro de 2021
ingresos = ingresos2[ingresos2['ANIO']==2021]
ingresos
# Out:
#       ANIO  TRIM                CONCESIONARIO                  EMPRESA  \
# 0     2021     1      ABILIO VILLARREAL MORGA  ABILIO VILLARREAL MORGA
# 1     2021     2      ABILIO VILLARREAL MORGA  ABILIO VILLARREAL MORGA
# 2     2021     3      ABILIO VILLARREAL MORGA  ABILIO VILLARREAL MORGA
# 3     2021     4      ABILIO VILLARREAL MORGA  ABILIO VILLARREAL MORGA
# 4     2021     1         ADOLFO MERINO MEDINA                 CABLEMAS
# ...    ...   ...                          ...                      ...
# 2640  2021     1  CITRO TELECOM, S.A. DE C.V.            CITRO TELECOM
# 2641  2021     2  CITRO TELECOM, S.A. DE C.V.            CITRO TELECOM
# 2642  2021     3  CITRO TELECOM, S.A. DE C.V.            CITRO TELECOM
# 2643  2021     4  CITRO TELECOM, S.A. DE C.V.            CITRO TELECOM
# 2644  2021     4        EDUARDO PEDRERO PEREZ    EDUARDO PEDRERO PEREZ
#
#                         GRUPO  INGRESOS_TOTAL_E
# 0     ABILIO VILLARREAL MORGA                 0
# 1     ABILIO VILLARREAL MORGA                 0
# 2     ABILIO VILLARREAL MORGA                 0
# 3     ABILIO VILLARREAL MORGA                 0
# 4              GRUPO TELEVISA            389669
# ...                       ...               ...
# 2640            CITRO TELECOM                 0
# 2641            CITRO TELECOM                 0
# 2642            CITRO TELECOM                 0
# 2643            CITRO TELECOM            123094
# 2644    EDUARDO PEDRERO PEREZ             68200
#
# [760 rows x 6 columns]

# %% [markdown]
# # Corrección de grupos de interés en el conjunto de datos
#
# Con base en la información proporcionada por la Unidad de Competencia Económica respecto a los Grupos de Interés que tienen identificados, se realizaron los siguientes cambios al marco de datos de ingresos que estamos utilizando para el cálculo del umbral de pequeño operador; publicado en el BIT al 19 de agosto de 2022:
#
# - Se incluye en el grupo de interés económico HISPASAT a la empresa AXESS NET.SOLUTIONS MEXICO, S.A. DE C.V.
# - Se incluye en el grupo de interés económico GRUPO TELEVISA a la empresa GRUPO DE TELECOMUNICACIONES DE ALTA CAPACIDAD, S.A.P.I. DE C.V. (GTAC).
# - Se incluye en el grupo de interés económico TRANSTELCO a la empresa MAXCOM TELECOMUNICACIONES, S.A.B. DE C.V.
# - Se incluyen en el grupo de interés económico MVS las empresas: MVSTV y DSH.

# %%
# Primero HISPASAT
print(ingresos[ingresos['EMPRESA']=='AXESS'])
ingresos['GRUPO'] = ingresos['GRUPO'].replace(['AXESAT'],'HISPASAT')
ingresos[ingresos['EMPRESA']=='AXESS']
# Out:
#      ANIO  TRIM                             CONCESIONARIO EMPRESA   GRUPO  \
# 385  2021     2  AXESS NET.SOLUTIONS MEXICO, S.A. DE C.V.   AXESS  AXESAT
# 386  2021     3  AXESS NET.SOLUTIONS MEXICO, S.A. DE C.V.   AXESS  AXESAT
# 387  2021     4  AXESS NET.SOLUTIONS MEXICO, S.A. DE C.V.   AXESS  AXESAT
#
#      INGRESOS_TOTAL_E
# 385          60667313
# 386          68625291
# 387          88628131
# <ipython-input-9-7dc6878566fb>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ingresos['GRUPO'] = ingresos['GRUPO'].replace(['AXESAT'],'HISPASAT')
#      ANIO  TRIM                             CONCESIONARIO EMPRESA     GRUPO  \
# 385  2021     2  AXESS NET.SOLUTIONS MEXICO, S.A. DE C.V.   AXESS  HISPASAT
# 386  2021     3  AXESS NET.SOLUTIONS MEXICO, S.A. DE C.V.   AXESS  HISPASAT
# 387  2021     4  AXESS NET.SOLUTIONS MEXICO, S.A. DE C.V.   AXESS  HISPASAT
#
#      INGRESOS_TOTAL_E
# 385          60667313
# 386          68625291
# 387          88628131

# %%
# Segundo Grupo Televisa
print(ingresos[ingresos['CONCESIONARIO']=='GRUPO DE TELECOMUNICACIONES DE ALTA CAPACIDAD, S.A.P.I. DE C.V.'])
ingresos['GRUPO'] = ingresos['GRUPO'].replace(['GTAC REDES DE FIBRA OPTICA'],'GRUPO TELEVISA')
ingresos[ingresos['EMPRESA']=='GTAC REDES DE FIBRA OPTICA']
# Out:
#      ANIO  TRIM                                      CONCESIONARIO  \
# 581  2021     1  GRUPO DE TELECOMUNICACIONES DE ALTA CAPACIDAD,...
# 582  2021     2  GRUPO DE TELECOMUNICACIONES DE ALTA CAPACIDAD,...
# 583  2021     3  GRUPO DE TELECOMUNICACIONES DE ALTA CAPACIDAD,...
# 584  2021     4  GRUPO DE TELECOMUNICACIONES DE ALTA CAPACIDAD,...
#
#                         EMPRESA                       GRUPO  INGRESOS_TOTAL_E
# 581  GTAC REDES DE FIBRA OPTICA  GTAC REDES DE FIBRA OPTICA         228948471
# 582  GTAC REDES DE FIBRA OPTICA  GTAC REDES DE FIBRA OPTICA         196098888
# 583  GTAC REDES DE FIBRA OPTICA  GTAC REDES DE FIBRA OPTICA         355289838
# 584  GTAC REDES DE FIBRA OPTICA  GTAC REDES DE FIBRA OPTICA         282197600
# <ipython-input-10-98df99182ec1>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ingresos['GRUPO'] = ingresos['GRUPO'].replace(['GTAC REDES DE FIBRA OPTICA'],'GRUPO TELEVISA')
#      ANIO  TRIM                                      CONCESIONARIO  \
# 581  2021     1  GRUPO DE TELECOMUNICACIONES DE ALTA CAPACIDAD,...
# 582  2021     2  GRUPO DE TELECOMUNICACIONES DE ALTA CAPACIDAD,...
# 583  2021     3  GRUPO DE TELECOMUNICACIONES DE ALTA CAPACIDAD,...
# 584  2021     4  GRUPO DE TELECOMUNICACIONES DE ALTA CAPACIDAD,...
#
#                         EMPRESA           GRUPO  INGRESOS_TOTAL_E
# 581  GTAC REDES DE FIBRA OPTICA  GRUPO TELEVISA         228948471
# 582  GTAC REDES DE FIBRA OPTICA  GRUPO TELEVISA         196098888
# 583  GTAC REDES DE FIBRA OPTICA  GRUPO TELEVISA         355289838
# 584  GTAC REDES DE FIBRA OPTICA  GRUPO TELEVISA         282197600

# %%
# Tercero Transtelco
print(ingresos[ingresos['CONCESIONARIO']=='MAXCOM TELECOMUNICACIONES, S.A.B. DE C.V.'])
ingresos['GRUPO'] = ingresos['GRUPO'].replace(['MAXCOM'],'TRANSTELCO')
ingresos[ingresos['EMPRESA']=='MAXCOM']
# Out:
#       ANIO  TRIM                              CONCESIONARIO EMPRESA   GRUPO  \
# 1896  2021     1  MAXCOM TELECOMUNICACIONES, S.A.B. DE C.V.  MAXCOM  MAXCOM
# 1897  2021     2  MAXCOM TELECOMUNICACIONES, S.A.B. DE C.V.  MAXCOM  MAXCOM
# 1898  2021     3  MAXCOM TELECOMUNICACIONES, S.A.B. DE C.V.  MAXCOM  MAXCOM
# 1899  2021     4  MAXCOM TELECOMUNICACIONES, S.A.B. DE C.V.  MAXCOM  MAXCOM
#
#       INGRESOS_TOTAL_E
# 1896         154326158
# 1897         157745550
# 1898         154123979
# 1899         157402483
# <ipython-input-11-19fa40c9fb05>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ingresos['GRUPO'] = ingresos['GRUPO'].replace(['MAXCOM'],'TRANSTELCO')
#       ANIO  TRIM                              CONCESIONARIO EMPRESA  \
# 1896  2021     1  MAXCOM TELECOMUNICACIONES, S.A.B. DE C.V.  MAXCOM
# 1897  2021     2  MAXCOM TELECOMUNICACIONES, S.A.B. DE C.V.  MAXCOM
# 1898  2021     3  MAXCOM TELECOMUNICACIONES, S.A.B. DE C.V.  MAXCOM
# 1899  2021     4  MAXCOM TELECOMUNICACIONES, S.A.B. DE C.V.  MAXCOM
#
#            GRUPO  INGRESOS_TOTAL_E
# 1896  TRANSTELCO         154326158
# 1897  TRANSTELCO         157745550
# 1898  TRANSTELCO         154123979
# 1899  TRANSTELCO         157402483

# %%
ingresos[ingresos['EMPRESA']=='DISH']
# Out:
#       ANIO  TRIM                                      CONCESIONARIO EMPRESA  \
# 1103  2021     1  COMERCIALIZADORA DE FRECUENCIAS SATELITALES, S...    DISH
# 1104  2021     2  COMERCIALIZADORA DE FRECUENCIAS SATELITALES, S...    DISH
# 1105  2021     3  COMERCIALIZADORA DE FRECUENCIAS SATELITALES, S...    DISH
# 1106  2021     4  COMERCIALIZADORA DE FRECUENCIAS SATELITALES, S...    DISH
#
#          GRUPO  INGRESOS_TOTAL_E
# 1103  DISH-MVS        1373486398
# 1104  DISH-MVS        1298658657
# 1105  DISH-MVS        1264047268
# 1106  DISH-MVS        1211104115

# %%
# Quinto DISH-MVS
print(ingresos[ingresos['CONCESIONARIO']=='COMERCIALIZADORA DE FRECUENCIAS SATELITALES, S. DE R.L. DE C.V.'])
ingresos['GRUPO'] = ingresos['GRUPO'].replace(['DISH-MVS'],'MVS')
ingresos[ingresos['EMPRESA']=='DISH']
# Out:
#       ANIO  TRIM                                      CONCESIONARIO EMPRESA  \
# 1103  2021     1  COMERCIALIZADORA DE FRECUENCIAS SATELITALES, S...    DISH
# 1104  2021     2  COMERCIALIZADORA DE FRECUENCIAS SATELITALES, S...    DISH
# 1105  2021     3  COMERCIALIZADORA DE FRECUENCIAS SATELITALES, S...    DISH
# 1106  2021     4  COMERCIALIZADORA DE FRECUENCIAS SATELITALES, S...    DISH
#
#          GRUPO  INGRESOS_TOTAL_E
# 1103  DISH-MVS        1373486398
# 1104  DISH-MVS        1298658657
# 1105  DISH-MVS        1264047268
# 1106  DISH-MVS        1211104115
# <ipython-input-13-3309da2ae005>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ingresos['GRUPO'] = ingresos['GRUPO'].replace(['DISH-MVS'],'MVS')
#       ANIO  TRIM                                      CONCESIONARIO EMPRESA  \
# 1103  2021     1  COMERCIALIZADORA DE FRECUENCIAS SATELITALES, S...    DISH
# 1104  2021     2  COMERCIALIZADORA DE FRECUENCIAS SATELITALES, S...    DISH
# 1105  2021     3  COMERCIALIZADORA DE FRECUENCIAS SATELITALES, S...    DISH
# 1106  2021     4  COMERCIALIZADORA DE FRECUENCIAS SATELITALES, S...    DISH
#
#      GRUPO  INGRESOS_TOTAL_E
# 1103   MVS        1373486398
# 1104   MVS        1298658657
# 1105   MVS        1264047268
# 1106   MVS        1211104115

# %%
# Sexto DISH-MVS
print(ingresos[ingresos['EMPRESA']=='MVSTV'])
ingresos['GRUPO'] = ingresos['GRUPO'].replace(['MVSTV'],'MVS')
ingresos[ingresos['EMPRESA']=='MVSTV']
# Out:
#       ANIO  TRIM          CONCESIONARIO EMPRESA GRUPO  INGRESOS_TOTAL_E
# 1764  2021     1  COMBAND, S.A. DE C.V.   MVSTV   MVS           1854471
# 1765  2021     2  COMBAND, S.A. DE C.V.   MVSTV   MVS           1355173
# 1766  2021     3  COMBAND, S.A. DE C.V.   MVSTV   MVS           2842491
# 1767  2021     4  COMBAND, S.A. DE C.V.   MVSTV   MVS           5357193
# <ipython-input-14-b827a2e0f14c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ingresos['GRUPO'] = ingresos['GRUPO'].replace(['MVSTV'],'MVS')
#       ANIO  TRIM          CONCESIONARIO EMPRESA GRUPO  INGRESOS_TOTAL_E
# 1764  2021     1  COMBAND, S.A. DE C.V.   MVSTV   MVS           1854471
# 1765  2021     2  COMBAND, S.A. DE C.V.   MVSTV   MVS           1355173
# 1766  2021     3  COMBAND, S.A. DE C.V.   MVSTV   MVS           2842491
# 1767  2021     4  COMBAND, S.A. DE C.V.   MVSTV   MVS           5357193

# %%
# Existen huecos en los datos públicos en proveedores importantes como Axtel (4T2021), Cablevisión, Virgin Mobile (4T2021), QBO CEL (2T Y 4T2021), por mencionar algunos.
ingresos[ingresos['INGRESOS_TOTAL_E'].isna()==True]
# no obstante, partimos de que es la información disponible para este ejercicio.
# Out:
#       ANIO  TRIM                                  CONCESIONARIO  \
# 570   2021     2      CABLEMAS TELECOMUNICACIONES, S.A. DE C.V.
# 790   2021     2                  CABLEVISION RED, S.A. DE C.V.
# 866   2021     2              TV CABLE DE ORIENTE, S.A. DE C.V.
# 968   2021     2         TELEVISION INTERNACIONAL, S.A. DE C.V.
# 1494  2021     2                      CABLEVISION, S.A. DE C.V.
# 1862  2021     3                 CTL MEXICO LANDING, S. DE R.L.
# 1945  2021     1                ELEKTRA SATELITAL, S.A. DE C.V.
# 2029  2021     4       VIRGIN MOBILE MEXICO, S. DE R.L. DE C.V.
# 2110  2021     2                     KUBO CEL, S.A.P.I. DE C.V.
# 2112  2021     4                     KUBO CEL, S.A.P.I. DE C.V.
# 2198  2021     1                          MVS NET, S.A. DE C.V.
# 2199  2021     2                          MVS NET, S.A. DE C.V.
# 2200  2021     3                          MVS NET, S.A. DE C.V.
# 2201  2021     4                          MVS NET, S.A. DE C.V.
# 2282  2021     3           VALOR AGREGADO DIGITAL, S.A. DE C.V.
# 2283  2021     4           VALOR AGREGADO DIGITAL, S.A. DE C.V.
# 2446  2021     1  GILAT SATELLITE NETWORKS MEXICO, S.A. DE C.V.
# 2447  2021     2  GILAT SATELLITE NETWORKS MEXICO, S.A. DE C.V.
# 2448  2021     3  GILAT SATELLITE NETWORKS MEXICO, S.A. DE C.V.
# 2449  2021     4  GILAT SATELLITE NETWORKS MEXICO, S.A. DE C.V.
# 2616  2021     1                     TELMOV MOVIL, S.A. DE C.V.
# 2624  2021     1                    MARKETING 358, S.A. DE C.V.
# 2625  2021     2                    MARKETING 358, S.A. DE C.V.
#
#                        EMPRESA           GRUPO  INGRESOS_TOTAL_E
# 570                       IZZI  GRUPO TELEVISA               NaN
# 790            CABLEVISION RED  GRUPO TELEVISA               NaN
# 866                       IZZI  GRUPO TELEVISA               NaN
# 968   TELEVISION INTERNACIONAL  GRUPO TELEVISA               NaN
# 1494               CABLEVISION  GRUPO TELEVISA               NaN
# 1862               CENTURYLINK     CENTURYLINK               NaN
# 1945             GRUPO ELEKTRA   GRUPO SALINAS               NaN
# 2029             VIRGIN MOBILE   VIRGIN MOBILE               NaN
# 2110                   QBO CEL         QBO CEL               NaN
# 2112                   QBO CEL         QBO CEL               NaN
# 2198                       MVS             MVS               NaN
# 2199                       MVS             MVS               NaN
# 2200                       MVS             MVS               NaN
# 2201                       MVS             MVS               NaN
# 2282                     VADSA           VADSA               NaN
# 2283                     VADSA           VADSA               NaN
# 2446                     GILAT           GILAT               NaN
# 2447                     GILAT           GILAT               NaN
# 2448                     GILAT           GILAT               NaN
# 2449                     GILAT           GILAT               NaN
# 2616                  TELMOVIL        TELMOVIL               NaN
# 2624             MARKETING 358   MARKETING 358               NaN
# 2625             MARKETING 358   MARKETING 358               NaN

# %%
ingresos.dtypes
# Out:
# ANIO                  int64
# TRIM                  int64
# CONCESIONARIO        object
# EMPRESA              object
# GRUPO                object
# INGRESOS_TOTAL_E    float64
# dtype: object

# %%
# no consideremos los missing values

ingresos = ingresos[ingresos['INGRESOS_TOTAL_E'].isna()!=True]
ingresos
# Out:
#       ANIO  TRIM                CONCESIONARIO                  EMPRESA  \
# 0     2021     1      ABILIO VILLARREAL MORGA  ABILIO VILLARREAL MORGA
# 1     2021     2      ABILIO VILLARREAL MORGA  ABILIO VILLARREAL MORGA
# 2     2021     3      ABILIO VILLARREAL MORGA  ABILIO VILLARREAL MORGA
# 3     2021     4      ABILIO VILLARREAL MORGA  ABILIO VILLARREAL MORGA
# 4     2021     1         ADOLFO MERINO MEDINA                 CABLEMAS
# ...    ...   ...                          ...                      ...
# 2640  2021     1  CITRO TELECOM, S.A. DE C.V.            CITRO TELECOM
# 2641  2021     2  CITRO TELECOM, S.A. DE C.V.            CITRO TELECOM
# 2642  2021     3  CITRO TELECOM, S.A. DE C.V.            CITRO TELECOM
# 2643  2021     4  CITRO TELECOM, S.A. DE C.V.            CITRO TELECOM
# 2644  2021     4        EDUARDO PEDRERO PEREZ    EDUARDO PEDRERO PEREZ
#
#                         GRUPO  INGRESOS_TOTAL_E
# 0     ABILIO VILLARREAL MORGA                 0
# 1     ABILIO VILLARREAL MORGA                 0
# 2     ABILIO VILLARREAL MORGA                 0
# 3     ABILIO VILLARREAL MORGA                 0
# 4              GRUPO TELEVISA            389669
# ...                       ...               ...
# 2640            CITRO TELECOM                 0
# 2641            CITRO TELECOM                 0
# 2642            CITRO TELECOM                 0
# 2643            CITRO TELECOM            123094
# 2644    EDUARDO PEDRERO PEREZ             68200
#
# [737 rows x 6 columns]

# %%
lista_columnas = ['GRUPO', 'INGRESOS_TOTAL_E']
ingresos2 = ingresos[lista_columnas]
ingresos2
# Out:
#                         GRUPO  INGRESOS_TOTAL_E
# 0     ABILIO VILLARREAL MORGA                 0
# 1     ABILIO VILLARREAL MORGA                 0
# 2     ABILIO VILLARREAL MORGA                 0
# 3     ABILIO VILLARREAL MORGA                 0
# 4              GRUPO TELEVISA            389669
# ...                       ...               ...
# 2640            CITRO TELECOM                 0
# 2641            CITRO TELECOM                 0
# 2642            CITRO TELECOM                 0
# 2643            CITRO TELECOM            123094
# 2644    EDUARDO PEDRERO PEREZ             68200
#
# [737 rows x 2 columns]

# %%
ingresos2['INGRESOS_TOTAL_E'] = pd.to_numeric(ingresos2['INGRESOS_TOTAL_E'])
# Out:
# <ipython-input-19-0e8230c4d54c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ingresos2['INGRESOS_TOTAL_E'] = pd.to_numeric(ingresos2['INGRESOS_TOTAL_E'])

# %%
# ya no tenemos missings

ingresos2
# Out:
#                         GRUPO  INGRESOS_TOTAL_E
# 0     ABILIO VILLARREAL MORGA                 0
# 1     ABILIO VILLARREAL MORGA                 0
# 2     ABILIO VILLARREAL MORGA                 0
# 3     ABILIO VILLARREAL MORGA                 0
# 4              GRUPO TELEVISA            389669
# ...                       ...               ...
# 2640            CITRO TELECOM                 0
# 2641            CITRO TELECOM                 0
# 2642            CITRO TELECOM                 0
# 2643            CITRO TELECOM            123094
# 2644    EDUARDO PEDRERO PEREZ             68200
#
# [737 rows x 2 columns]

# %%
# Agrupados
ingresos_agrupados = ingresos2.groupby(['GRUPO']).sum()
ingresos_agrupados
# Out:
#                                         INGRESOS_TOTAL_E
# GRUPO
# ABILIO VILLARREAL MORGA                                0
# ADA CRISTINA MAGAÑA CASTRO                             0
# ADDINTELI                                        5534961
# AGUSTIN PEREZ VIEYRA                             2726562
# AIRECABLE                                       13327321
# ...                                                  ...
# VERIZON SERVICIOS EMPRESARIALES MEXICO         195055919
# VIRGIN MOBILE                                  146563495
# WEEX                                            33446465
# WIMOTELECOM                                    166683899
# YOBI TELECOM                                    43316605
#
# [161 rows x 1 columns]

# %%
ingresos_agrupados = ingresos_agrupados.reset_index().sort_values(by=['INGRESOS_TOTAL_E'], ascending=False)
ingresos_agrupados
# Out:
#                           GRUPO  INGRESOS_TOTAL_E
# 9                 AMÉRICA MÓVIL      338320139531
# 56               GRUPO TELEVISA       59302114566
# 12                         AT&T       55793781168
# 84                MEGACABLE-MCM       25905272620
# 139                  TELEFÓNICA       24871583943
# ..                          ...               ...
# 108     SERGIO PEDROZA AGUILERA                 0
# 1    ADA CRISTINA MAGAÑA CASTRO                 0
# 73          JOAQUIN LEON ASPANO                 0
# 26                  CABLEXTREMO                 0
# 0       ABILIO VILLARREAL MORGA                 0
#
# [161 rows x 2 columns]

# %%
plt.hist(ingresos_agrupados['INGRESOS_TOTAL_E'])
plt.xlabel('Ingresos ($)')
plt.ylabel('Frecuencia absoluta')
plt.show()
print(sts.normaltest(ingresos_agrupados['INGRESOS_TOTAL_E'])) # no pasa la prueba de normalidad (sesgo)
# Out:
# NormaltestResult(statistic=335.1417446263944, pvalue=1.67839751044495e-73)

# %%
# cuántos ceros tenemos en las cifras
m = ingresos_agrupados[ingresos_agrupados['INGRESOS_TOTAL_E']!=0]

ingresos_agrupados_transformables = m

ingresos_agrupados_transformables
# Out:
#                          GRUPO  INGRESOS_TOTAL_E
# 9                AMÉRICA MÓVIL      338320139531
# 56              GRUPO TELEVISA       59302114566
# 12                        AT&T       55793781168
# 84               MEGACABLE-MCM       25905272620
# 139                 TELEFÓNICA       24871583943
# ..                         ...               ...
# 40       EDUARDO PEDRERO PEREZ             68200
# 13            AXIA CABLECENTRO             43500
# 31                      COMNET             43293
# 103                  REX MOVIL             11422
# 64   HUGO ABEL PUENTE ANGUIANO              2845
#
# [153 rows x 2 columns]

# %%
# Aplicar logarítmos para reducir el efecto de la magnitud de los datos.
ln_ingresos = np.log(ingresos_agrupados_transformables['INGRESOS_TOTAL_E']).dropna() 

plt.hist(ln_ingresos)
plt.xlabel('Ingresos ($)')
plt.ylabel('Frecuencia absoluta')
plt.show()
print(sts.normaltest(ln_ingresos))
# Out:
# NormaltestResult(statistic=20.812485323225516, pvalue=3.024309507239512e-05)

# %%
# Análisis de varianza
var_numpy = np.var(ln_ingresos, ddof = 0)
print(f"La varianza del ln de los ingresos totales en 2021 es de {var_numpy}")
print(f'Lo que implica $ {np.exp(var_numpy)}')

sd_numpy = np.std(ln_ingresos,ddof = 0)
print(f"La desviación estándar del ln de los ingresos totales en 2021 es de {sd_numpy}")
print(f'Lo que implica $ {np.exp(sd_numpy)}')
# Out:
# La varianza del ln de los ingresos totales en 2021 es de 8.202781794468986
# Lo que implica $ 3651.0927833604774
# La desviación estándar del ln de los ingresos totales en 2021 es de 2.8640498938511856
# Lo que implica $ 17.53238765950314

# %%
var_numpy2 = np.var(ingresos_agrupados['INGRESOS_TOTAL_E'], ddof = 0)
print(f"La varianza del ln de los ingresos totales en 2021 es de {var_numpy2}")

sd_numpy2 = np.std(ingresos_agrupados['INGRESOS_TOTAL_E'],ddof = 0)
print(f"La desviación estándar de los ingresos totales en 2021 es de {sd_numpy2}")
# Out:
# La varianza del ln de los ingresos totales en 2021 es de 7.526844672239898e+20
# La desviación estándar de los ingresos totales en 2021 es de 27435095538.816517

# %%
# La media
media = np.mean(ln_ingresos)
print(f"La media del ln de los ingresos 2021 es de {media}")
print(f'Lo que implica una media de $ {np.exp(media)}')
# Out:
# La media del ln de los ingresos 2021 es de 16.438232438632784
# Lo que implica una media de $ 13773161.513244966

# %%
# Calculando la regla de 68-95-99.7 usando la desviación estándar:
print(f"Casi el 68% de los datos está entre {round(media-sd_numpy,3)} y {round(media+sd_numpy,3)}")
print(f'Lo que implica que el 68% de los operadores tienen ingresos entre {round(np.exp(media-sd_numpy),2)} y {round(np.exp(media+sd_numpy),2)}')
print(f"Casi el 95% de los datos está entre {round(media-2*sd_numpy,3)} y {round(media +2*sd_numpy,3)}")
print(f'Lo que implica que el 95% de los operadores tienen ingresos entre {round(np.exp(media-2*sd_numpy),2)} y {round(np.exp(media +2*sd_numpy),2)}')
print(f"Casi el 99.7% de los datos está entre {round(media-3*sd_numpy,3)} y {round(media+3*sd_numpy,3)}")
print(f'Lo que implica que el 99.7% de los operadores tienen ingresos entre {round(np.exp(media-3*sd_numpy),2)} y {round(np.exp(media +3*sd_numpy),2)}')
# Out:
# Casi el 68% de los datos está entre 13.574 y 19.302
# Lo que implica que el 68% de los operadores tienen ingresos entre 785583.9 y 241476406.95
# Casi el 95% de los datos está entre 10.71 y 22.166
# Lo que implica que el 95% de los operadores tienen ingresos entre 44807.58 y 4233657977.22
# Casi el 99.7% de los datos está entre 7.846 y 25.03
# Lo que implica que el 99.7% de los operadores tienen ingresos entre 2555.7 y 74226132874.4

# %%
# El score z nos dice el número de desviaciones estándar en el que un dato de ingreso está cerca de la media
z_scipy = sts.zscore(ln_ingresos)
print(f"Los score z es {z_scipy}")
# Out:
# Los score z es [ 3.52962636  2.92162451  2.90033209  2.63245411  2.61823628  2.59862734
#   2.34880848  2.06899996  1.85993162  1.53389892  1.37036621  1.35523552
#   1.33125625  1.26298131  1.25655144  1.19538813  1.19192774  1.10846992
#   1.05156579  0.93398167  0.92546028  0.87951634  0.87361033  0.87057747
#   0.83847826  0.82837712  0.8256619   0.76066629  0.73893026  0.73312483
#   0.68532769  0.63901739  0.63004534  0.62893234  0.6260823   0.5014622
#   0.49519763  0.48223707  0.44020077  0.40108104  0.40006781  0.38336348
#   0.38245353  0.37026558  0.3097796   0.28321775  0.27964783  0.25589202
#   0.24096086  0.23142296  0.21823927  0.17830273  0.17724762  0.17004839
#   0.16944616  0.15130248  0.14691511  0.14014548  0.13125713  0.12381163
#   0.1188109   0.06570471  0.06569461  0.01869647  0.01370797  0.00464257
#  -0.01148923 -0.01378179 -0.01531293 -0.02207551 -0.02223545 -0.03581703
#  -0.03820578 -0.05795701 -0.07533761 -0.07962583 -0.09059117 -0.13546315
#  -0.1718335  -0.18059047 -0.18993552 -0.20036491 -0.21689088 -0.22103297
#  -0.22161335 -0.26041134 -0.27609701 -0.28757491 -0.28874839 -0.29212564
#  -0.31830359 -0.32447525 -0.35958236 -0.36826689 -0.3711992  -0.37390236
#  -0.40193875 -0.40921706 -0.42008709 -0.43140079 -0.45156171 -0.49886765
#  -0.50163997 -0.51125227 -0.52487409 -0.54922062 -0.5522775  -0.56552099
#  -0.5666533  -0.58237461 -0.58237461 -0.58387358 -0.59620141 -0.60135753
#  -0.6046805  -0.61504798 -0.61523824 -0.61756332 -0.62144588 -0.62671128
#  -0.62805861 -0.63229239 -0.64051417 -0.64273788 -0.64934579 -0.65248659
#  -0.67459515 -0.70880875 -0.7172975  -0.76647725 -0.77047965 -0.78492186
#  -0.79198265 -0.82527216 -0.8545634  -0.88418861 -0.91294879 -0.91639146
#  -1.11292773 -1.1257492  -1.17610381 -1.17610381 -1.21528436 -1.22591971
#  -1.2914006  -1.30065285 -1.31294125 -1.64715275 -1.85333105 -2.01034075
#  -2.0120059  -2.47723891 -2.96255806]

# %%
# Prueba de outliers (los grandes operadores)
green_diamond = dict(markerfacecolor='g', marker='D')
fig1, ax1 = plt.subplots(figsize=(10, 8))
ax1.set_title('Ingresos acumulados totales por operador al cierre 2021 (ln)')
ax1.set_ylabel('ln(MX$)')
ax1.boxplot(ln_ingresos, flierprops=green_diamond, whis=0.75, vert=False)
plt.savefig('criterio_2021.png')
plt.show()

# %%
ln_ingresos
# Out:
# 9     27
# 56    25
# 12    25
# 84    24
# 139   24
#       ..
# 40    11
# 13    11
# 31    11
# 103    9
# 64     8
# Name: INGRESOS_TOTAL_E, Length: 153, dtype: float64

# %%
sns.set_style("darkgrid", {"axes.facecolor": ".9"})
df = ln_ingresos

# Usual boxplot
ax = sns.boxplot(data=df, orient="h")
 
# Add jitter with the swarmplot function
ax = sns.swarmplot(color="blue", data=df, orient="h")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda4\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-850c599b8288> in <module>
#       3
#       4 # Usual boxplot
# ----> 5 ax = sns.boxplot(data=df, orient="h")
#       6
#       7 # Add jitter with the swarmplot function
#
# ~\Anaconda4\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\Anaconda4\lib\site-packages\seaborn\categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2238 ):
#    2239
# -> 2240     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2241                           orient, color, palette, saturation,
#    2242                           width, dodge, fliersize, linewidth)
#
# ~\Anaconda4\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth)
#     404                  width, dodge, fliersize, linewidth):
#     405
# --> 406         self.establish_variables(x, y, hue, data, orient, order, hue_order)
#     407         self.establish_colors(color, palette, saturation)
#     408
#
# ~\Anaconda4\lib\site-packages\seaborn\categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#      96                 if hasattr(data, "shape"):
#      97                     if len(data.shape) == 1:
# ---> 98                         if np.isscalar(data[0]):
#      99                             plot_data = [data]
#     100                         else:
#
# ~\Anaconda4\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     851
#     852         elif key_is_scalar:
# --> 853             return self._get_value(key)
#     854
#     855         if is_hashable(key):
#
# ~\Anaconda4\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#     959
#     960         # Similar to Index.get_value, but we do not fall back to positional
# --> 961         loc = self.index.get_loc(label)
#     962         return self.index._get_values_for_loc(self, loc, label)
#     963
#
# ~\Anaconda4\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 0

# %%
ln_ingresos2 = pd.DataFrame(ln_ingresos)
ln_ingresos3 = ln_ingresos2['INGRESOS_TOTAL_E'].values.astype("float")
ln_ingresos3
# Out:
# array([26.54725844, 24.8059108 , 24.74492825, 23.97771236, 23.93699178,
#        23.88083078, 23.16533712, 22.36395156, 21.76516941, 20.83139546,
#        20.36302965, 20.31969459, 20.25101676, 20.05547391, 20.03705847,
#        19.86188368, 19.85197294, 19.61294559, 19.44996932, 19.11320254,
#        19.08879684, 18.95721111, 18.94029603, 18.93160975, 18.839676  ,
#        18.81074584, 18.80296931, 18.61681864, 18.55456558, 18.53793852,
#        18.40104514, 18.26841012, 18.24271372, 18.23952603, 18.23136339,
#        17.87444519, 17.85650317, 17.81938348, 17.69898941, 17.58694855,
#        17.5840466 , 17.53620457, 17.53359844, 17.49869154, 17.32545666,
#        17.24938221, 17.23915779, 17.17111995, 17.12835637, 17.10103933,
#        17.06328059, 16.94890035, 16.94587848, 16.92525951, 16.9235347 ,
#        16.87157028, 16.85900466, 16.83961608, 16.81415941, 16.79283513,
#        16.77851278, 16.62641399, 16.62638509, 16.49178006, 16.47749274,
#        16.45152899, 16.40532671, 16.39876071, 16.39437544, 16.37500708,
#        16.374549  , 16.33565069, 16.32880917, 16.27224068, 16.22246178,
#        16.21018009, 16.1787748 , 16.05025922, 15.94609271, 15.92101231,
#        15.89424763, 15.86437734, 15.81704613, 15.805183  , 15.80352074,
#        15.69240137, 15.64747682, 15.61460355, 15.61124264, 15.60157004,
#        15.52659508, 15.50891915, 15.40837061, 15.38349769, 15.3750994 ,
#        15.36735743, 15.28705982, 15.26621437, 15.23508204, 15.20267905,
#        15.14493717, 15.0094506 , 15.00151054, 14.97398043, 14.93496687,
#        14.86523718, 14.85648213, 14.81855211, 14.81530912, 14.7702825 ,
#        14.7702825 , 14.76598936, 14.73068186, 14.71591447, 14.70639732,
#        14.67670435, 14.67615943, 14.66950026, 14.65838044, 14.64330008,
#        14.63944123, 14.62731548, 14.6037679 , 14.59739908, 14.57847371,
#        14.56947829, 14.50615826, 14.40816881, 14.3838566 , 14.24300335,
#        14.23154027, 14.19017708, 14.16995462, 14.0746118 , 13.99072022,
#        13.90587215, 13.82350154, 13.81364156, 13.25075188, 13.21403057,
#        13.06981245, 13.06981245, 12.95759741, 12.92713723, 12.7395967 ,
#        12.71309779, 12.6779032 , 11.72070479, 11.13019984, 10.68051622,
#        10.67574716,  9.3432966 ,  7.95331835])

# %%
ln_ingresos2.index
# Out:
# Int64Index([  9,  56,  12,  84, 139,  54,  14,  87,   8, 120,
#             ...
#              92,  53, 144,  16,  29,  40,  13,  31, 103,  64],
#            dtype='int64', length=153)

# %% [markdown]
# # Buscando el número de centroides (valores medios) óptimos a partir de la metodología Elbow y minimizar las distorciones.

# %%
ln_ingresos3.shape
# Out:
# (153,)

# %%
# Cuantificando las distorsiones.

from sklearn.cluster import KMeans
distortions = []
K = range(1,10)
for k in K:
    kmeanModel = KMeans(n_clusters=k)
    kmeanModel.fit(ln_ingresos3.reshape(-1, 1))
    distortions.append(kmeanModel.inertia_)
# Out:
# D:\Users\rodrigo.guarneros\Anaconda4\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
plt.figure(figsize=(16,8))
plt.plot(K, distortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('El método Elbow que muestra el k óptimo')
plt.show()

# %%
# Busquemos los clusters estadísticamente significativos
#use the kmeans function from scipy
from numpy import random
random.seed((1000,2000))
centroids, avg_distance = kmeans(ln_ingresos3, 4, iter=1000)
#extract the groups from the data
groups, cdit = vq(ln_ingresos3, centroids)
#plot the results
#assign groups back to the dataframe
ln_ingresos2["Tipo_de_Operadores"] = groups
#plot the scatter plot
# Usual boxplot

ax = sns.swarmplot(data=ln_ingresos2, x=np.ones(len(ln_ingresos2)), 
              y='INGRESOS_TOTAL_E', 
              hue=ln_ingresos2['Tipo_de_Operadores'])

ax = sns.swarmplot(data=centroids, color="red")
#ax = sns.boxplot(data=ln_ingresos2["INGRESOS_TOTAL_E"])

# remove legend if necessary
# plt.legend().remove()
plt.savefig('clusters_ingresos.png')
plt.show()

# %%
grande = ln_ingresos2[ln_ingresos2['Tipo_de_Operadores']==1].reset_index()
grande

mediano =  ln_ingresos2[ln_ingresos2['Tipo_de_Operadores']==3].reset_index()
mediano

pequeño1 = ln_ingresos2[ln_ingresos2['Tipo_de_Operadores']==0].reset_index()
pequeño1

pequeño2 = ln_ingresos2[ln_ingresos2['Tipo_de_Operadores']==2].reset_index()
pequeño2
# Out:
#     index  INGRESOS_TOTAL_E  Tipo_de_Operadores
# 0     132                15                   2
# 1      49                15                   2
# 2     128                15                   2
# 3     114                15                   2
# 4      98                15                   2
# 5      70                15                   2
# 6      57                15                   2
# 7     154                15                   2
# 8     113                15                   2
# 9     119                15                   2
# 10     85                15                   2
# 11      3                15                   2
# 12    107                15                   2
# 13     67                15                   2
# 14     52                15                   2
# 15    141                15                   2
# 16     11                15                   2
# 17    126                15                   2
# 18    118                15                   2
# 19    124                15                   2
# 20    104                15                   2
# 21     34                15                   2
# 22     82                15                   2
# 23     33                15                   2
# 24     72                15                   2
# 25     44                15                   2
# 26     79                15                   2
# 27     68                15                   2
# 28    102                15                   2
# 29     37                15                   2
# 30    138                15                   2
# 31     42                14                   2
# 32     58                14                   2
# 33     74                14                   2
# 34     25                14                   2
# 35     99                14                   2
# 36     36                14                   2
# 37    115                14                   2
# 38     21                14                   2
# 39    150                14                   2
# 40     43                14                   2
# 41     96                14                   2
# 42    129                13                   2
# 43    146                13                   2
# 44     22                13                   2
# 45     71                13                   2
# 46     66                13                   2
# 47     92                13                   2
# 48     53                13                   2
# 49    144                13                   2
# 50     16                13                   2
# 51     29                12                   2
# 52     40                11                   2
# 53     13                11                   2
# 54     31                11                   2
# 55    103                 9                   2
# 56     64                 8                   2

# %%
# Se reemplazan las variables categóricas por la etiqueta correspondiente
ln_ingresos2["Tipo_de_Operadores"].replace({3: "Mediano", 1: "Grande", 2:"Pequeño2", 0:"Pequeño1"}, inplace=True)
ln_ingresos2 = ln_ingresos2.reset_index()
ln_ingresos2
# Out:
#      index  INGRESOS_TOTAL_E Tipo_de_Operadores
# 0        9                27             Grande
# 1       56                25             Grande
# 2       12                25             Grande
# 3       84                24             Grande
# 4      139                24             Grande
# ..     ...               ...                ...
# 148     40                11           Pequeño2
# 149     13                11           Pequeño2
# 150     31                11           Pequeño2
# 151    103                 9           Pequeño2
# 152     64                 8           Pequeño2
#
# [153 rows x 3 columns]

# %%
ingresos_por_grupo = ingresos_agrupados.reset_index()
cluster_total = ingresos_por_grupo.merge(ln_ingresos2, how='left', on='index')
cluster_total.to_csv("Clusters_totales2.csv", encoding="Latin1")

# %%
grande = ln_ingresos2[ln_ingresos2['Tipo_de_Operadores']=="Grande"]
grande

mediano =  ln_ingresos2[ln_ingresos2['Tipo_de_Operadores']=="Mediano"]
mediano

pequeño_1 = ln_ingresos2[ln_ingresos2['Tipo_de_Operadores']=="Pequeño1"]
pequeño_1

pequeño_2 = ln_ingresos2[ln_ingresos2['Tipo_de_Operadores']=="Pequeño2"]
pequeño_2
# Out:
#      index  INGRESOS_TOTAL_E Tipo_de_Operadores
# 96     132                15           Pequeño2
# 97      49                15           Pequeño2
# 98     128                15           Pequeño2
# 99     114                15           Pequeño2
# 100     98                15           Pequeño2
# 101     70                15           Pequeño2
# 102     57                15           Pequeño2
# 103    154                15           Pequeño2
# 104    113                15           Pequeño2
# 105    119                15           Pequeño2
# 106     85                15           Pequeño2
# 107      3                15           Pequeño2
# 108    107                15           Pequeño2
# 109     67                15           Pequeño2
# 110     52                15           Pequeño2
# 111    141                15           Pequeño2
# 112     11                15           Pequeño2
# 113    126                15           Pequeño2
# 114    118                15           Pequeño2
# 115    124                15           Pequeño2
# 116    104                15           Pequeño2
# 117     34                15           Pequeño2
# 118     82                15           Pequeño2
# 119     33                15           Pequeño2
# 120     72                15           Pequeño2
# 121     44                15           Pequeño2
# 122     79                15           Pequeño2
# 123     68                15           Pequeño2
# 124    102                15           Pequeño2
# 125     37                15           Pequeño2
# 126    138                15           Pequeño2
# 127     42                14           Pequeño2
# 128     58                14           Pequeño2
# 129     74                14           Pequeño2
# 130     25                14           Pequeño2
# 131     99                14           Pequeño2
# 132     36                14           Pequeño2
# 133    115                14           Pequeño2
# 134     21                14           Pequeño2
# 135    150                14           Pequeño2
# 136     43                14           Pequeño2
# 137     96                14           Pequeño2
# 138    129                13           Pequeño2
# 139    146                13           Pequeño2
# 140     22                13           Pequeño2
# 141     71                13           Pequeño2
# 142     66                13           Pequeño2
# 143     92                13           Pequeño2
# 144     53                13           Pequeño2
# 145    144                13           Pequeño2
# 146     16                13           Pequeño2
# 147     29                12           Pequeño2
# 148     40                11           Pequeño2
# 149     13                11           Pequeño2
# 150     31                11           Pequeño2
# 151    103                 9           Pequeño2
# 152     64                 8           Pequeño2

# %%
ln_ingresos2
# Out:
#      index  INGRESOS_TOTAL_E Tipo_de_Operadores
# 0        9                27             Grande
# 1       56                25             Grande
# 2       12                25             Grande
# 3       84                24             Grande
# 4      139                24             Grande
# ..     ...               ...                ...
# 148     40                11           Pequeño2
# 149     13                11           Pequeño2
# 150     31                11           Pequeño2
# 151    103                 9           Pequeño2
# 152     64                 8           Pequeño2
#
# [153 rows x 3 columns]

# %%
ax = sns.swarmplot(data=ln_ingresos2, x="INGRESOS_TOTAL_E", y="Tipo_de_Operadores", alpha=0.8, linewidth=.9)
ax = sns.boxplot(data=ln_ingresos2, x='INGRESOS_TOTAL_E', y="Tipo_de_Operadores",orient="h", color="lightblue")
plt.savefig("clusters_distribución.jpg")
#plt.show()
# Out:
# D:\Users\rodrigo.guarneros\Anaconda4\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 26.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# D:\Users\rodrigo.guarneros\Anaconda4\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 24.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
ax = sns.boxplot(data=ln_ingresos2, x='INGRESOS_TOTAL_E', y="Tipo_de_Operadores",orient="h", color="lightblue")

# %%
dir(ax)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_add_text',
#  '_adjustable',
#  '_agg_filter',
#  '_alias_map',
#  '_alpha',
#  '_anchor',
#  '_animated',
#  '_aspect',
#  '_autoscaleXon',
#  '_autoscaleYon',
#  '_autotitlepos',
#  '_axes',
#  '_axes_class',
#  '_axes_locator',
#  '_axisbelow',
#  '_box_aspect',
#  '_clipon',
#  '_clippath',
#  '_contains',
#  '_convert_dx',
#  '_current_image',
#  '_default_contains',
#  '_facecolor',
#  '_fill_between_x_or_y',
#  '_frameon',
#  '_gci',
#  '_gen_axes_patch',
#  '_gen_axes_spines',
#  '_get_axis_list',
#  '_get_axis_map',
#  '_get_clipping_extent_bbox',
#  '_get_lines',
#  '_get_patches_for_fill',
#  '_get_view',
#  '_gid',
#  '_gridOn',
#  '_in_layout',
#  '_init_axis',
#  '_label',
#  '_layoutbox',
#  '_left_title',
#  '_make_twin_axes',
#  '_mouseover',
#  '_mouseover_set',
#  '_navigate',
#  '_navigate_mode',
#  '_oid',
#  '_on_units_changed',
#  '_originalPosition',
#  '_parse_scatter_color_args',
#  '_path_effects',
#  '_pcolorargs',
#  '_picker',
#  '_position',
#  '_poslayoutbox',
#  '_process_unit_info',
#  '_propobservers',
#  '_quiver_units',
#  '_rasterization_zorder',
#  '_rasterized',
#  '_remove_legend',
#  '_remove_method',
#  '_request_autoscale_view',
#  '_right_title',
#  '_sci',
#  '_set_artist_props',
#  '_set_gc_clip',
#  '_set_lim_and_transforms',
#  '_set_position',
#  '_set_title_offset_trans',
#  '_set_view',
#  '_set_view_from_bbox',
#  '_shared_x_axes',
#  '_shared_y_axes',
#  '_sharex',
#  '_sharey',
#  '_sketch',
#  '_snap',
#  '_stale',
#  '_stale_viewlim_x',
#  '_stale_viewlim_y',
#  '_sticky_edges',
#  '_subplotspec',
#  '_tight',
#  '_transform',
#  '_transformSet',
#  '_twinned_axes',
#  '_unstale_viewLim',
#  '_update_image_limits',
#  '_update_line_limits',
#  '_update_patch_limits',
#  '_update_title_position',
#  '_update_transScale',
#  '_url',
#  '_use_sticky_edges',
#  '_validate_converted_limits',
#  '_viewLim',
#  '_visible',
#  '_xaxis_transform',
#  '_xcid',
#  '_xmargin',
#  '_yaxis_transform',
#  '_ycid',
#  '_ymargin',
#  'acorr',
#  'add_artist',
#  'add_callback',
#  'add_child_axes',
#  'add_collection',
#  'add_container',
#  'add_image',
#  'add_line',
#  'add_patch',
#  'add_table',
#  'angle_spectrum',
#  'annotate',
#  'apply_aspect',
#  'arrow',
#  'artists',
#  'autoscale',
#  'autoscale_view',
#  'axes',
#  'axhline',
#  'axhspan',
#  'axis',
#  'axison',
#  'axline',
#  'axvline',
#  'axvspan',
#  'bar',
#  'barbs',
#  'barh',
#  'bbox',
#  'boxplot',
#  'broken_barh',
#  'bxp',
#  'callbacks',
#  'can_pan',
#  'can_zoom',
#  'change_geometry',
#  'child_axes',
#  'cla',
#  'clabel',
#  'clear',
#  'clipbox',
#  'cohere',
#  'colNum',
#  'collections',
#  'containers',
#  'contains',
#  'contains_point',
#  'contour',
#  'contourf',
#  'convert_xunits',
#  'convert_yunits',
#  'csd',
#  'dataLim',
#  'drag_pan',
#  'draw',
#  'draw_artist',
#  'end_pan',
#  'errorbar',
#  'eventplot',
#  'eventson',
#  'figbox',
#  'figure',
#  'fill',
#  'fill_between',
#  'fill_betweenx',
#  'findobj',
#  'fmt_xdata',
#  'fmt_ydata',
#  'format_coord',
#  'format_cursor_data',
#  'format_xdata',
#  'format_ydata',
#  'get_adjustable',
#  'get_agg_filter',
#  'get_alpha',
#  'get_anchor',
#  'get_animated',
#  'get_aspect',
#  'get_autoscale_on',
#  'get_autoscalex_on',
#  'get_autoscaley_on',
#  'get_axes_locator',
#  'get_axisbelow',
#  'get_box_aspect',
#  'get_children',
#  'get_clip_box',
#  'get_clip_on',
#  'get_clip_path',
#  'get_contains',
#  'get_cursor_data',
#  'get_data_ratio',
#  'get_data_ratio_log',
#  'get_default_bbox_extra_artists',
#  'get_facecolor',
#  'get_fc',
#  'get_figure',
#  'get_frame_on',
#  'get_geometry',
#  'get_gid',
#  'get_gridspec',
#  'get_images',
#  'get_in_layout',
#  'get_label',
#  'get_legend',
#  'get_legend_handles_labels',
#  'get_lines',
#  'get_navigate',
#  'get_navigate_mode',
#  'get_path_effects',
#  'get_picker',
#  'get_position',
#  'get_rasterization_zorder',
#  'get_rasterized',
#  'get_renderer_cache',
#  'get_shared_x_axes',
#  'get_shared_y_axes',
#  'get_sketch_params',
#  'get_snap',
#  'get_subplotspec',
#  'get_tightbbox',
#  'get_title',
#  'get_transform',
#  'get_transformed_clip_path_and_affine',
#  'get_url',
#  'get_visible',
#  'get_window_extent',
#  'get_xaxis',
#  'get_xaxis_text1_transform',
#  'get_xaxis_text2_transform',
#  'get_xaxis_transform',
#  'get_xbound',
#  'get_xgridlines',
#  'get_xlabel',
#  'get_xlim',
#  'get_xmajorticklabels',
#  'get_xminorticklabels',
#  'get_xscale',
#  'get_xticklabels',
#  'get_xticklines',
#  'get_xticks',
#  'get_yaxis',
#  'get_yaxis_text1_transform',
#  'get_yaxis_text2_transform',
#  'get_yaxis_transform',
#  'get_ybound',
#  'get_ygridlines',
#  'get_ylabel',
#  'get_ylim',
#  'get_ymajorticklabels',
#  'get_yminorticklabels',
#  'get_yscale',
#  'get_yticklabels',
#  'get_yticklines',
#  'get_yticks',
#  'get_zorder',
#  'grid',
#  'has_data',
#  'have_units',
#  'hexbin',
#  'hist',
#  'hist2d',
#  'hlines',
#  'ignore_existing_data_limits',
#  'images',
#  'imshow',
#  'in_axes',
#  'indicate_inset',
#  'indicate_inset_zoom',
#  'inset_axes',
#  'invert_xaxis',
#  'invert_yaxis',
#  'is_first_col',
#  'is_first_row',
#  'is_last_col',
#  'is_last_row',
#  'is_transform_set',
#  'label_outer',
#  'legend',
#  'legend_',
#  'lines',
#  'locator_params',
#  'loglog',
#  'magnitude_spectrum',
#  'margins',
#  'matshow',
#  'minorticks_off',
#  'minorticks_on',
#  'mouseover',
#  'name',
#  'numCols',
#  'numRows',
#  'patch',
#  'patches',
#  'pchanged',
#  'pcolor',
#  'pcolorfast',
#  'pcolormesh',
#  'phase_spectrum',
#  'pick',
#  'pickable',
#  'pie',
#  'plot',
#  'plot_date',
#  'properties',
#  'psd',
#  'quiver',
#  'quiverkey',
#  'redraw_in_frame',
#  'relim',
#  'remove',
#  'remove_callback',
#  'reset_position',
#  'rowNum',
#  'scatter',
#  'secondary_xaxis',
#  'secondary_yaxis',
#  'semilogx',
#  'semilogy',
#  'set',
#  'set_adjustable',
#  'set_agg_filter',
#  'set_alpha',
#  'set_anchor',
#  'set_animated',
#  'set_aspect',
#  'set_autoscale_on',
#  'set_autoscalex_on',
#  'set_autoscaley_on',
#  'set_axes_locator',
#  'set_axis_off',
#  'set_axis_on',
#  'set_axisbelow',
#  'set_box_aspect',
#  'set_clip_box',
#  'set_clip_on',
#  'set_clip_path',
#  'set_contains',
#  'set_facecolor',
#  'set_fc',
#  'set_figure',
#  'set_frame_on',
#  'set_gid',
#  'set_in_layout',
#  'set_label',
#  'set_navigate',
#  'set_navigate_mode',
#  'set_path_effects',
#  'set_picker',
#  'set_position',
#  'set_prop_cycle',
#  'set_rasterization_zorder',
#  'set_rasterized',
#  'set_sketch_params',
#  'set_snap',
#  'set_subplotspec',
#  'set_title',
#  'set_transform',
#  'set_url',
#  'set_visible',
#  'set_xbound',
#  'set_xlabel',
#  'set_xlim',
#  'set_xmargin',
#  'set_xscale',
#  'set_xticklabels',
#  'set_xticks',
#  'set_ybound',
#  'set_ylabel',
#  'set_ylim',
#  'set_ymargin',
#  'set_yscale',
#  'set_yticklabels',
#  'set_yticks',
#  'set_zorder',
#  'sharex',
#  'sharey',
#  'specgram',
#  'spines',
#  'spy',
#  'stackplot',
#  'stale',
#  'stale_callback',
#  'start_pan',
#  'stem',
#  'step',
#  'sticky_edges',
#  'streamplot',
#  'table',
#  'tables',
#  'text',
#  'texts',
#  'tick_params',
#  'ticklabel_format',
#  'title',
#  'titleOffsetTrans',
#  'transAxes',
#  'transData',
#  'transLimits',
#  'transScale',
#  'tricontour',
#  'tricontourf',
#  'tripcolor',
#  'triplot',
#  'twinx',
#  'twiny',
#  'update',
#  'update_datalim',
#  'update_datalim_bounds',
#  'update_from',
#  'update_params',
#  'use_sticky_edges',
#  'viewLim',
#  'violin',
#  'violinplot',
#  'vlines',
#  'xaxis',
#  'xaxis_date',
#  'xaxis_inverted',
#  'xcorr',
#  'yaxis',
#  'yaxis_date',
#  'yaxis_inverted',
#  'zorder']

# %%
print(ax.findobj())
# Out:
# [<matplotlib.lines.Line2D object at 0x000001FB48232D60>, <matplotlib.lines.Line2D object at 0x000001FB4823E0A0>, <matplotlib.lines.Line2D object at 0x000001FB4823E400>, <matplotlib.lines.Line2D object at 0x000001FB4823E760>, <matplotlib.lines.Line2D object at 0x000001FB4823EAC0>, <matplotlib.lines.Line2D object at 0x000001FB4823EE20>, <matplotlib.lines.Line2D object at 0x000001FB4824B4F0>, <matplotlib.lines.Line2D object at 0x000001FB4824B850>, <matplotlib.lines.Line2D object at 0x000001FB4824BBB0>, <matplotlib.lines.Line2D object at 0x000001FB4824BF10>, <matplotlib.lines.Line2D object at 0x000001FB482582B0>, <matplotlib.lines.Line2D object at 0x000001FB48258610>, <matplotlib.lines.Line2D object at 0x000001FB48258BB0>, <matplotlib.lines.Line2D object at 0x000001FB48258F10>, <matplotlib.lines.Line2D object at 0x000001FB482642E0>, <matplotlib.lines.Line2D object at 0x000001FB48264640>, <matplotlib.lines.Line2D object at 0x000001FB482649A0>, <matplotlib.lines.Line2D object at 0x000001FB48264D00>, <matplotlib.lines.Line2D object at 0x000001FB48270310>, <matplotlib.lines.Line2D object at 0x000001FB48270670>, <matplotlib.lines.Line2D object at 0x000001FB482709D0>, <matplotlib.lines.Line2D object at 0x000001FB48270D30>, <matplotlib.lines.Line2D object at 0x000001FB4827B0D0>, <matplotlib.lines.Line2D object at 0x000001FB4827B430>, <matplotlib.patches.PathPatch object at 0x000001FB482329D0>, <matplotlib.patches.PathPatch object at 0x000001FB4824B160>, <matplotlib.patches.PathPatch object at 0x000001FB48258820>, <matplotlib.patches.PathPatch object at 0x000001FB48264F40>, <matplotlib.spines.Spine object at 0x000001FB48209880>, <matplotlib.spines.Spine object at 0x000001FB48209970>, <matplotlib.spines.Spine object at 0x000001FB48209A90>, <matplotlib.spines.Spine object at 0x000001FB48209B80>, Text(0.5, 16.200000000000003, 'INGRESOS_TOTAL_E'), Text(1, 17.200000000000003, ''), <matplotlib.lines.Line2D object at 0x000001FB482127F0>, <matplotlib.lines.Line2D object at 0x000001FB482128E0>, <matplotlib.lines.Line2D object at 0x000001FB482129A0>, Text(5.0, 0, '5.0'), Text(5.0, 1, '5.0'), <matplotlib.axis.XTick object at 0x000001FB482123D0>, <matplotlib.lines.Line2D object at 0x000001FB48212430>, <matplotlib.lines.Line2D object at 0x000001FB482124F0>, <matplotlib.lines.Line2D object at 0x000001FB482125B0>, Text(7.5, 0, '7.5'), Text(7.5, 1, '7.5'), <matplotlib.axis.XTick object at 0x000001FB482123A0>, <matplotlib.lines.Line2D object at 0x000001FB48208F70>, <matplotlib.lines.Line2D object at 0x000001FB48208CA0>, <matplotlib.lines.Line2D object at 0x000001FB48208D60>, Text(10.0, 0, '10.0'), Text(10.0, 1, '10.0'), <matplotlib.axis.XTick object at 0x000001FB47DD8FA0>, <matplotlib.lines.Line2D object at 0x000001FB4827BFD0>, <matplotlib.lines.Line2D object at 0x000001FB482860D0>, <matplotlib.lines.Line2D object at 0x000001FB48286190>, Text(12.5, 0, '12.5'), Text(12.5, 1, '12.5'), <matplotlib.axis.XTick object at 0x000001FB4827BFA0>, <matplotlib.lines.Line2D object at 0x000001FB48286520>, <matplotlib.lines.Line2D object at 0x000001FB482865E0>, <matplotlib.lines.Line2D object at 0x000001FB482866A0>, Text(15.0, 0, '15.0'), Text(15.0, 1, '15.0'), <matplotlib.axis.XTick object at 0x000001FB482864F0>, <matplotlib.lines.Line2D object at 0x000001FB48286A30>, <matplotlib.lines.Line2D object at 0x000001FB48286AF0>, <matplotlib.lines.Line2D object at 0x000001FB48286BB0>, Text(17.5, 0, '17.5'), Text(17.5, 1, '17.5'), <matplotlib.axis.XTick object at 0x000001FB48286A00>, <matplotlib.lines.Line2D object at 0x000001FB48286F40>, <matplotlib.lines.Line2D object at 0x000001FB4828C040>, <matplotlib.lines.Line2D object at 0x000001FB4828C100>, Text(20.0, 0, '20.0'), Text(20.0, 1, '20.0'), <matplotlib.axis.XTick object at 0x000001FB48286F10>, <matplotlib.lines.Line2D object at 0x000001FB4828C490>, <matplotlib.lines.Line2D object at 0x000001FB4828C550>, <matplotlib.lines.Line2D object at 0x000001FB4828C610>, Text(22.5, 0, '22.5'), Text(22.5, 1, '22.5'), <matplotlib.axis.XTic ...

# %%
np.exp(17.7200000000003)
# Out:
# 49624737.138494045

# %%
avg_distance
# Out:
# 0.7772274401397564

# %% [markdown]
# # ¿Quiénes son los operadores en cada cluster?

# %%
# Primero preparemos la lista de operadores
ingresos = ingresos[['CONCESIONARIO', 'EMPRESA', 'GRUPO', 'INGRESOS_TOTAL_E']]
ingresos['INGRESOS_TOTAL_E'] = pd.to_numeric(ingresos['INGRESOS_TOTAL_E'])
ingresos = ingresos.groupby(['CONCESIONARIO', 'EMPRESA', 'GRUPO']).sum().reset_index().sort_values(by=['INGRESOS_TOTAL_E'], ascending=False)
ingresos
# Out:
# <ipython-input-51-daabab6c15c7>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ingresos['INGRESOS_TOTAL_E'] = pd.to_numeric(ingresos['INGRESOS_TOTAL_E'])
#                                          CONCESIONARIO  \
# 123                     RADIOMOVIL DIPSA, S.A. DE C.V.
# 166                TELEFONOS DE MEXICO, S.A.B. DE C.V.
# 12   AT&T COMUNICACIONES DIGITALES, S. DE R.L. DE C.V.
# 120                           PEGASO PCS, S.A. DE C.V.
# 47   CORPORACION DE RADIO Y TELEVISION DEL NORTE DE...
# ..                                                 ...
# 71                       GRUPO PROFREZAC, S.A. DE C.V.
# 91                                 JOAQUIN LEON ASPANO
# 1                           ADA CRISTINA MAGAÑA CASTRO
# 130                            SERGIO PEDROZA AGUILERA
# 0                              ABILIO VILLARREAL MORGA
#
#                         EMPRESA                       GRUPO  INGRESOS_TOTAL_E
# 123                      TELCEL               AMÉRICA MÓVIL      218288998808
# 166                      TELMEX               AMÉRICA MÓVIL      120031140723
# 12                         AT&T                        AT&T       55793781168
# 120                    MOVISTAR                  TELEFÓNICA       24871583943
# 47                          SKY              GRUPO TELEVISA       24112031768
# ..                          ...                         ...               ...
# 71                       STARKA                      STARKA                 0
# 91          JOAQUIN LEON ASPANO         JOAQUIN LEON ASPANO                 0
# 1    ADA CRISTINA MAGAÑA CASTRO  ADA CRISTINA MAGAÑA CASTRO                 0
# 130     SERGIO PEDROZA AGUILERA     SERGIO PEDROZA AGUILERA                 0
# 0       ABILIO VILLARREAL MORGA     ABILIO VILLARREAL MORGA                 0
#
# [191 rows x 4 columns]

# %% [markdown]
# ## Grandes

# %%
lista_grandes = grande["index"]
lista_original = ingresos_agrupados_transformables.reset_index()
grandes_operadores = lista_original[lista_original['index'].isin(lista_grandes)]
grandes_operadores.sort_values(by=["INGRESOS_TOTAL_E"], ascending=False)
# Out:
#    index           GRUPO  INGRESOS_TOTAL_E
# 0      9   AMÉRICA MÓVIL      338320139531
# 1     56  GRUPO TELEVISA       59302114566
# 2     12            AT&T       55793781168
# 3     84   MEGACABLE-MCM       25905272620
# 4    139      TELEFÓNICA       24871583943
# 5     54   GRUPO SALINAS       23513270106
# 6     14           AXTEL       11496829253
# 7     87             MVS        5158705766
# 8      8           ALTAN        2834607753

# %%
# Las empresas que no serían elegibles por estar en el cluster de los grandes operadores:

lista_cluster_grande = grandes_operadores['GRUPO'].unique()
lista_cluster_grande
# Out:
# array(['AMÉRICA MÓVIL', 'GRUPO TELEVISA', 'AT&T', 'MEGACABLE-MCM',
#        'TELEFÓNICA', 'GRUPO SALINAS', 'AXTEL', 'MVS', 'ALTAN'],
#       dtype=object)

# %%
# Se trata de 27 operadores que son por sí solos grandes operadores o pertenecen a un GIE grande. 

lista_empresas_cluster_grande = ingresos[ingresos['GRUPO'].isin(lista_cluster_grande)].sort_values(by=['INGRESOS_TOTAL_E'], ascending = False)

lista_empresas_cluster_grande.to_csv("Empresas_grandes.csv", encoding="Latin1")

lista_empresas_cluster_grande
# Out:
#                                          CONCESIONARIO  \
# 123                     RADIOMOVIL DIPSA, S.A. DE C.V.
# 166                TELEFONOS DE MEXICO, S.A.B. DE C.V.
# 12   AT&T COMUNICACIONES DIGITALES, S. DE R.L. DE C.V.
# 120                           PEGASO PCS, S.A. DE C.V.
# 47   CORPORACION DE RADIO Y TELEVISION DEL NORTE DE...
# 108                           MEGA CABLE, S.A. DE C.V.
# 179        TOTAL PLAY TELECOMUNICACIONES, S.A. DE C.V.
# 15                               AXTEL, S.A.B. DE C.V.
# 25           CABLEMAS TELECOMUNICACIONES, S.A. DE C.V.
# 30                           CABLEVISION, S.A. DE C.V.
# 37   COMERCIALIZADORA DE FRECUENCIAS SATELITALES, S...
# 173             TELEVISION INTERNACIONAL, S.A. DE C.V.
# 110  MEXICO RED DE TELECOMUNICACIONES, S. DE R.L. D...
# 180                  TV CABLE DE ORIENTE, S.A. DE C.V.
# 29                       CABLEVISION RED, S.A. DE C.V.
# 119                              OPERBES, S.A. DE C.V.
# 9                        ALTAN REDES, S.A.P.I. DE C.V.
# 131  SERVICIO Y EQUIPO EN TELEFONIA INTERNET Y TV, ...
# 109   MEGACABLE COMUNICACIONES DE MEXICO, S.A. DE C.V.
# 69   GRUPO DE TELECOMUNICACIONES DE ALTA CAPACIDAD,...
# 162               TELECOMUNICACIONES 360, S.A. DE C.V.
# 23                            CABLE SORO, S.A. DE C.V.
# 35                               COMBAND, S.A. DE C.V.
# 150                  TELECABLE DE COENEO, S.A. DE C.V.
# 165           TELEDISTRIBUCION POR CABLE, S.A. DE C.V.
# 2                                 ADOLFO MERINO MEDINA
# 101                   MANUEL ENRIQUE VELAZQUEZ VAUGHAN
# 59                     ELEKTRA SATELITAL, S.A. DE C.V.
#
#                               EMPRESA           GRUPO  INGRESOS_TOTAL_E
# 123                            TELCEL   AMÉRICA MÓVIL      218288998808
# 166                            TELMEX   AMÉRICA MÓVIL      120031140723
# 12                               AT&T            AT&T       55793781168
# 120                          MOVISTAR      TELEFÓNICA       24871583943
# 47                                SKY  GRUPO TELEVISA       24112031768
# 108                         MEGACABLE   MEGACABLE-MCM       23567319612
# 179                         TOTALPLAY   GRUPO SALINAS       22784126736
# 15                              AXTEL           AXTEL       11496829253
# 25                               IZZI  GRUPO TELEVISA        9765026568
# 30                        CABLEVISION  GRUPO TELEVISA        7858397482
# 37                               DISH             MVS        5147296438
# 173          TELEVISION INTERNACIONAL  GRUPO TELEVISA        4877002991
# 110                          CABLECOM  GRUPO TELEVISA        2954414555
# 180                              IZZI  GRUPO TELEVISA        2907451220
# 29                    CABLEVISION RED  GRUPO TELEVISA        2883757649
# 119                            BESTEL  GRUPO TELEVISA        2879231196
# 9                               ALTAN           ALTAN        2834607753
# 131                         MEGACABLE   MEGACABLE-MCM        1228500764
# 109                       MCM TELECOM   MEGACABLE-MCM        1075678092
# 69         GTAC REDES DE FIBRA OPTICA  GRUPO TELEVISA        1062534797
# 162                               OUI   GRUPO SALINAS         729143370
# 23                          MEGACABLE   MEGACABLE-MCM          13749617
# 35                              MVSTV             MVS          11409328
# 150                         MEGACABLE   MEGACABLE-MCM          11094520
# 165                         MEGACABLE   MEGACABLE-MCM           8930016
# 2                            CABLEMAS  GRUPO TELEVISA           1648000
# 101  MANUEL ENRIQUE VELAZQUEZ VAUGHAN  GRUPO TELEVISA            618340
# 59                      GRUPO ELEKTRA   GRUPO SALINAS                 0

# %% [markdown]
# ## Medianos

# %%
lista_medianos = mediano["index"]
lista_original = ingresos_agrupados_transformables.reset_index()
operadores_medianos = lista_original[lista_original['index'].isin(lista_medianos)]
operadores_medianos.sort_values(by=["INGRESOS_TOTAL_E"], ascending=False)
# Out:
#     index                                   GRUPO  INGRESOS_TOTAL_E
# 9     120                               STARGROUP        1114192165
# 10     80                                MARCATEL         697511564
# 11     89                                  NETWEY         667930436
# 12    147                              TRANSTELCO         623598170
# 13     28                             CENTURYLINK         512839717
# 14     63                           HNS DE MEXICO         503481972
# 15    143     TELIA CARRIER COMMUNICATIONS MEXICO         422577610
# 16     62                                HISPASAT         418410240
# 17    152                              UC TELECOM         329453439
# 18     17                         BT LATAM MEXICO         279907380
# 19     41                    ELARA COMUNICACIONES         199874961
# 20    156  VERIZON SERVICIOS EMPRESARIALES MEXICO         195055919
# 21     51                               GLOBALSAT         171006327
# 22     90                                   NEWWW         168138067
# 23    159                             WIMOTELECOM         166683899
# 24     65                                   IENTC         152043314
# 25    109                               SERVITRON         147707694
# 26    157                           VIRGIN MOBILE         146563495
# 27     55                         GRUPO TELECABLE         121669467
# 28    134                   TELECABLE DEL MINERAL         114326115
# 29     48                                 FREEDOM         112440924
# 30     38                              DIRI MOVIL          98055592
# 31     46                            FLASH MOBILE          85875585
# 32     69                                     IST          83697002
# 33     61                  HIPERCABLE DE MONCLOVA          83430627
# 34     97                              QUATTROCOM          82752385

# %%
# Las empresas que no serían elegibles por estar en el cluster de los medianos operadores:

lista_cluster_mediano = operadores_medianos['GRUPO'].unique()
lista_cluster_mediano
# Out:
# array(['STARGROUP', 'MARCATEL', 'NETWEY', 'TRANSTELCO', 'CENTURYLINK',
#        'HNS DE MEXICO', 'TELIA CARRIER COMMUNICATIONS MEXICO', 'HISPASAT',
#        'UC TELECOM', 'BT LATAM MEXICO', 'ELARA COMUNICACIONES',
#        'VERIZON SERVICIOS EMPRESARIALES MEXICO', 'GLOBALSAT', 'NEWWW',
#        'WIMOTELECOM', 'IENTC', 'SERVITRON', 'VIRGIN MOBILE',
#        'GRUPO TELECABLE', 'TELECABLE DEL MINERAL', 'FREEDOM',
#        'DIRI MOVIL', 'FLASH MOBILE', 'IST', 'HIPERCABLE DE MONCLOVA',
#        'QUATTROCOM'], dtype=object)

# %%
# Se trata de 34 operadores que son por sí solos son medianos operadores o pertenecen a un GIE mediano. 

lista_empresas_cluster_medianos = ingresos[ingresos['GRUPO'].isin(lista_cluster_mediano)].sort_values(by=['INGRESOS_TOTAL_E'], ascending = False)

lista_empresas_cluster_medianos.to_csv("Empresas_medianas.csv", encoding="Latin1")

lista_empresas_cluster_medianos
# Out:
#                                          CONCESIONARIO  \
# 72                           GRUPO W COM, S.A. DE C.V.
# 103                         MARCATEL COM, S.A. DE C.V.
# 87                       ISLIM TELCO, S.A.P.I. DE C.V.
# 106          MAXCOM TELECOMUNICACIONES, S.A.B. DE C.V.
# 52                      CTL MEXICO LANDING, S. DE R.L.
# 80                         HNS DE MEXICO, S.A. DE C.V.
# 176  TELIA CARRIER COMMUNICATIONS MEXICO, S.A. DE C.V.
# 183            UC TELECOMUNICACIONES, S.A.P.I. DE C.V.
# 18                       BT LATAM MEXICO, S.A. DE C.V.
# 171                     TELEVERA RED, S.A.P.I. DE C.V.
# 14            AXESS NET.SOLUTIONS MEXICO, S.A. DE C.V.
# 187  VERIZON SERVICIOS EMPRESARIALES MEXICO, S. DE ...
# 73                   GSAT COMUNICACIONES, S.A. DE C.V.
# 146                    TALENTO NET, S. DE R.L. DE C.V.
# 190                          WIMOTELECOM, S.A. DE C.V.
# 83                           IENTC, S. DE R.L. DE C.V.
# 132              SERVICIOS TRONCALIZADOS, S.A. DE C.V.
# 188           VIRGIN MOBILE MEXICO, S. DE R.L. DE C.V.
# 79                       HISPASAT MEXICO, S.A. DE C.V.
# 57              ELARA COMUNICACIONES, S.A.P.I. DE C.V.
# 160                TELECABLE DEL MINERAL, S.A. DE C.V.
# 64                     FREEDOMPOP MEXICO, S.A. DE C.V.
# 54               DIRI TELECOMUNICACIONES, S.A. DE C.V.
# 99            LOGISTICA ACN MEXICO, S. DE R.L. DE C.V.
# 85   INTEGRACION DE SERVICIOS Y TECNOLOGIA, S.A. DE...
# 78                HIPERCABLE DE MONCLOVA, S.A. DE C.V.
# 96                         LANTOINTERNET, S.A. DE C.V.
# 58              ELARA COMUNICACIONES, S.A.P.I. DE C.V.
# 13            AXESS NET.SOLUTIONS MEXICO, S.A. DE C.V.
# 168            TELESISTEMAS PENINSULARES, S.A. DE C.V.
# 148                TELECABLE DE CAMPECHE, S.A. DE C.V.
# 157                   TELECABLE DE TICUL, S.A. DE C.V.
# 151              TELECABLE DE CUERNAVACA, S.A. DE C.V.
# 156                   TELECABLE DE TEKAX, S.A. DE C.V.
#
#                                     EMPRESA  \
# 72                          STAR GO/STAR TV
# 103                                MARCATEL
# 87                                   NETWEY
# 106                                  MAXCOM
# 52                              CENTURYLINK
# 80                            HNS DE MEXICO
# 176     TELIA CARRIER COMMUNICATIONS MEXICO
# 183                              UC TELECOM
# 18                          BT LATAM MEXICO
# 171                            TELEVERA RED
# 14                                    AXESS
# 187  VERIZON SERVICIOS EMPRESARIALES MEXICO
# 73                               GLOBAL SAT
# 146                                   NEWWW
# 190                             WIMOTELECOM
# 83                 IENTC TELECOMUNICACIONES
# 132                               SERVITRON
# 188                           VIRGIN MOBILE
# 79                                 HISPASAT
# 57                     ELARA COMUNICACIONES
# 160                   TELECABLE DEL MINERAL
# 64                               FREEDOMPOP
# 54                               DIRI MOVIL
# 99                             FLASH MOBILE
# 85                                      IST
# 78                   HIPERCABLE DE MONCLOVA
# 96                               QUATTROCOM
# 58                 IVEEP INTERNET SATELITAL
# 13                                   AXESAT
# 168               TELESISTEMAS PENINSULARES
# 148                   TELECABLE DE CAMPECHE
# 157                      TELECABLE DE TICUL
# 151                 TELECABLE DE CUERNAVACA
# 156                      TELECABLE DE TEKAX
#
#                                       GRUPO  INGRESOS_TOTAL_E
# 72                                STARGROUP         858427009
# 103                                MARCATEL         697511564
# 87                                   NETWEY         667930436
# 106                              TRANSTELCO         623598170
# 52                              CENTURYLINK         512839717
# 80                            HNS DE MEXICO         503481972
# 176     TELIA CARRIER COMMUNICATIONS MEXICO         422577610
# 183                              UC TELECOM         329453439
# 18                          BT LATAM MEXICO         279907380
# 171                               STARGROUP         255765156
# 14                                 HISPASAT         217920735
# 187  VERIZON SERVICIOS EMPRESARIALES MEXICO         195055919
# 73                                GLOBALSAT         171006327
# 146                                   NEWWW         168138067
# 190                             WIMOTELECOM         166683899
# 83                                    IENTC         152043314
# 132                               SERVITRON         147707694
# 188                           VIRGIN MOBILE         146563495
# 79                                 HISPASAT         139535703
# 57                     ELARA COMUNICACIONES         134141678
# 160                   TELECABLE DEL MINERAL         114326115
# 64                                  FREEDOM         112440924
# 54                               DIRI MOVIL          98055592
# 99                             FLASH MOBILE          85875585
# 85                                      IST          83697002
# 78                   HIPERCABLE DE MONCLOVA          83430627
# 96                               QUATTROCOM          82752385
# 58                     ELARA COMUNICACIONES          65733284
# 13                                 HISPASAT          60953802
# 168                         GRUPO TELECABLE          56882777
# 148                         GRUPO TELECABLE          37452991
# 157                         GRUPO TELECABLE          13975584
# 151                         GRUPO TELECABLE           7884565
# 156                         GRUPO TELECABLE           5473549

# %% [markdown]
# ## Cluster_1 de operadores pequeños

# %%
lista_pequeños1 = pequeño_1["index"]
operadores_pequeños_1 = lista_original[lista_original['index'].isin(lista_pequeños1)]
operadores_pequeños_1.sort_values(by=["INGRESOS_TOTAL_E"], ascending=False)
# Out:
#     index                 GRUPO  INGRESOS_TOTAL_E
# 35    135      TELECABLE MERIDA          57912580
# 36    100            RAVS CABLE          56882777
# 37    155               VASANTA          54810014
# 38     32      COMUNICACION B15          48592969
# 39    110  SIERRA MADRE TELECOM          43442490
# ..    ...                   ...               ...
# 91     10                 ANKLA           5437985
# 92     60           HERMOVISION           4917794
# 93     45     EYCO DE LOS ALTOS           4796983
# 94     88              NET LINK           4756865
# 95    145            TOKA MOVIL           4720180
#
# [61 rows x 3 columns]

# %%
# Las empresas que no serían elegibles por estar en el cluster de los pequeños1:
lista_cluster_pequeños_1 = operadores_pequeños_1['GRUPO'].unique()
lista_cluster_pequeños_1
# Out:
# array(['TELECABLE MERIDA', 'RAVS CABLE', 'VASANTA', 'COMUNICACION B15',
#        'SIERRA MADRE TELECOM', 'YOBI TELECOM', 'TELECABLE', 'RBACATV',
#        'LINK TE CONECTAMOS', 'WEEX', 'BBG COMUNICACION',
#        'SARA QUIROZ CHAPA', 'SCT', 'ALESTRA', 'COSMORED', 'CCA',
#        'CABLEVISION DE APATZINGAN', 'MARCO ANTONIO ROSALES HERRERA',
#        'NEXT TELEKOM', 'SIHI MEXICO', 'TELECABLE DE RIOVERDE',
#        'TELECABLE DE XALTIANGUIS', 'TELECOM NACIONAL', 'LAREDONET',
#        'TELECABLE DE TAMAYO', 'DIVERSICABLE', 'SPACENET',
#        'CABLE DEL VALLE DE TOLUCA', 'USA TELECOM', 'SUPERCOM',
#        'TELEVISION DE PEDRO ESCOBEDO', 'AIRECABLE',
#        'OPERADORA TELEFONICA PENINSULAR', 'MAXICABLE', 'COMCAB',
#        'GURUCOMM', 'CABLEPLAY', 'SIMPATI', 'MUCHOS MEGAS', 'LOGITEL',
#        'CABLE DIVERSION', 'OTROS', 'TELECOMUNICACIONES DE CERRITOS',
#        'TV OJO CALIENTE', 'FRANCISCO GUERRA GARCIA',
#        'TELECABLE DE COAHUAYANA', 'ALEJANDRO MELGAREJO CORTES', 'TELEWEB',
#        'PROTOKOL TELECOMUNICACIONES', 'BUENO CELL', 'SISTV',
#        'ALEJANDRO ALFONSO MELGAREJO ALTAMIRANO',
#        'GENY MARGARITA MOGUEL REJON', 'TVDIG', 'LUMENET COMUNICACIONES',
#        'ADDINTELI', 'ANKLA', 'HERMOVISION', 'EYCO DE LOS ALTOS',
#        'NET LINK', 'TOKA MOVIL'], dtype=object)

# %%
# Se trata de 64 operadores que por sí solos son pequeños operadores o pertenecen a un GIE pequeño. 

lista_empresas_cluster_pequeños_1 = ingresos[ingresos['GRUPO'].isin(lista_cluster_pequeños_1)].sort_values(by=['INGRESOS_TOTAL_E'], ascending = False)

lista_empresas_cluster_pequeños_1.to_csv("Empresas_pequeñas_c1.csv", encoding="Latin1")

lista_empresas_cluster_pequeños_1
# Out:
#                                 CONCESIONARIO            EMPRESA  \
# 153         TELECABLE DE MERIDA, S.A. DE C.V.   TELECABLE MERIDA
# 127       ROBERTO ANTONIO MALDONADO GUTIERREZ         RAVS CABLE
# 186  VASANTA COMUNICACIONES, S.A.P.I. DE C.V.            VASANTA
# 40             COMUNICACION B15, S.A. DE C.V.   COMUNICACION B15
# 133       SIERRA MADRE INTERNET, S.A. DE C.V.       SIERRA MADRE
# ..                                        ...                ...
# 10                        ANKLA, S.A. DE C.V.              ANKLA
# 77            HERMOVISION, S. DE R.L. DE C.V.        HERMOVISION
# 62      EYCO DE LOS ALTOS, S. DE R.L. DE C.V.  EYCO DE LOS ALTOS
# 112                          NATALIA CHAREEVA           NET LINK
# 116       OPENIP COMUNICACIONES, S.A. DE C.V.         TOKA MOVIL
#
#                     GRUPO  INGRESOS_TOTAL_E
# 153      TELECABLE MERIDA          57912580
# 127            RAVS CABLE          56882777
# 186               VASANTA          54810014
# 40       COMUNICACION B15          48592969
# 133  SIERRA MADRE TELECOM          43442490
# ..                    ...               ...
# 10                  ANKLA           5437985
# 77            HERMOVISION           4917794
# 62      EYCO DE LOS ALTOS           4796983
# 112              NET LINK           4756865
# 116            TOKA MOVIL           4720180
#
# [64 rows x 4 columns]

# %% [markdown]
# # Cluster 2 de operadores pequeños

# %%
lista_pequeños2 = pequeño_2["index"]
operadores_pequeños_2 = lista_original[lista_original['index'].isin(lista_pequeños2)]
operadores_pequeños_2.sort_values(by=["INGRESOS_TOTAL_E"], ascending=False)
# Out:
#      index                                 GRUPO  INGRESOS_TOTAL_E
# 96     132               TELECABLE DE VILLANUEVA           4355978
# 97      49                 GABRIEL BUTRON CHIAPA           4266116
# 98     128               TELECABLE DE EL NARANJO           4135348
# 99     114                      SISCAB DE MEXICO           4003498
# 100     98       RADIO FRECUENCIAS CONCESIONADAS           3778876
# 101     70                          JACE TELECOM           3300058
# 102     57              GUILLERMO MEDELLIN MILAN           3273959
# 103    154                                 VADSA           3185056
# 104    113                              SINOTECA           3063188
# 105    119                              STAR NET           2856870
# 106     85                                  MIIO           2831967
# 107      3                  AGUSTIN PEREZ VIEYRA           2726562
# 108    107                                 SECSA           2717734
# 110     52                                  GOBO           2598078
# 109     67                INTEGRA COMUNICACIONES           2598078
# 111    141       TELEVISION POR CABLE DE MUZQUIZ           2586948
# 112     11             ARELY ISABEL GONGORA PECH           2497203
# 113    126                TELECABLE DE AGUILILLA           2460597
# 114    118                       SPACEX-STARLINK           2437290
# 115    124                               TELECAB           2365984
# 116    104                   ROBERTO LOPEZ BRAVO           2364695
# 117     34         CONSORCIO JAGO COMUNICACIONES           2349000
# 118     82                         MARKETING 358           2323024
# 119     33                            CONCABLETV           2288255
# 120     72       JESUS MIGUEL FERNANDEZ GUERRERO           2279442
# 121     44                                 ESPID           2251969
# 122     79                    MANUEL LOPEZ AVILA           2199560
# 123     68                  INTERCABLE DEL MAYAB           2185596
# 124    102                               RED DOG           2144622
# 125     37                 DANIEL GARCIA GODINEZ           2125416
# 126    138     TELECOMUNICACIONES DIVERSIFICADAS           1995007
# 127     42  ENTRETENIMIENTO Y TELECOMUNICACIONES           1808790
# 128     58               GUILLERMO ZARATE GARCIA           1765345
# 129     74          JOSE JULIAN SACRAMENTO GARZA           1533408
# 130     25             CABLEVISION DE LA HUACANA           1515931
# 131     99              RAFAEL SANCHEZ NAZARIEGA           1454506
# 132     36                               CRO.NET           1425388
# 133    115                 SISTEMA DE CABLE HKAN           1295765
# 134     21                  CABLE SALTO DEL AGUA           1191496
# 135    150                                  TV-K           1094570
# 136     43                             ES TV COM           1008023
# 137     96                               QBO CEL            998133
# 138    129         TELECABLE DE MARIANO ESCOBEDO            568497
# 139    146                  TOMAS CRISTOBAL CRUZ            548000
# 140     22              CABLE SISTEMA DEL CENTRO            474403
# 141     71                 JAIME SANCHEZ SANCHEZ            474403
# 142     66                          IGOU TELECOM            424046
# 143     92                  NORMA GUTIERREZ FONG            411324
# 144     53           GRUPO CORPORATIVO ZUNUN PAZ            340986
# 145    144                              TELMOVIL            332069
# 146     16                              BROMOVIL            320585
# 147     29                         CITRO TELECOM            123094
# 148     40                 EDUARDO PEDRERO PEREZ             68200
# 149     13                      AXIA CABLECENTRO             43500
# 150     31                                COMNET             43293
# 151    103                             REX MOVIL             11422
# 152     64             HUGO ABEL PUENTE ANGUIANO              2845

# %%
# Las empresas que no serían elegibles por estar en el cluster de los pequeños1:
lista_cluster_pequeños_2 = operadores_pequeños_2['GRUPO'].unique()
lista_cluster_pequeños_2
# Out:
# array(['TELECABLE DE VILLANUEVA', 'GABRIEL BUTRON CHIAPA',
#        'TELECABLE DE EL NARANJO', 'SISCAB DE MEXICO',
#        'RADIO FRECUENCIAS CONCESIONADAS', 'JACE TELECOM',
#        'GUILLERMO MEDELLIN MILAN', 'VADSA', 'SINOTECA', 'STAR NET',
#        'MIIO', 'AGUSTIN PEREZ VIEYRA', 'SECSA', 'INTEGRA COMUNICACIONES',
#        'GOBO', 'TELEVISION POR CABLE DE MUZQUIZ',
#        'ARELY ISABEL GONGORA PECH', 'TELECABLE DE AGUILILLA',
#        'SPACEX-STARLINK', 'TELECAB', 'ROBERTO LOPEZ BRAVO',
#        'CONSORCIO JAGO COMUNICACIONES', 'MARKETING 358', 'CONCABLETV',
#        'JESUS MIGUEL FERNANDEZ GUERRERO', 'ESPID', 'MANUEL LOPEZ AVILA',
#        'INTERCABLE DEL MAYAB', 'RED DOG', 'DANIEL GARCIA GODINEZ',
#        'TELECOMUNICACIONES DIVERSIFICADAS',
#        'ENTRETENIMIENTO Y TELECOMUNICACIONES', 'GUILLERMO ZARATE GARCIA',
#        'JOSE JULIAN SACRAMENTO GARZA', 'CABLEVISION DE LA HUACANA',
#        'RAFAEL SANCHEZ NAZARIEGA', 'CRO.NET', 'SISTEMA DE CABLE HKAN',
#        'CABLE SALTO DEL AGUA', 'TV-K', 'ES TV COM', 'QBO CEL',
#        'TELECABLE DE MARIANO ESCOBEDO', 'TOMAS CRISTOBAL CRUZ',
#        'CABLE SISTEMA DEL CENTRO', 'JAIME SANCHEZ SANCHEZ',
#        'IGOU TELECOM', 'NORMA GUTIERREZ FONG',
#        'GRUPO CORPORATIVO ZUNUN PAZ', 'TELMOVIL', 'BROMOVIL',
#        'CITRO TELECOM', 'EDUARDO PEDRERO PEREZ', 'AXIA CABLECENTRO',
#        'COMNET', 'REX MOVIL', 'HUGO ABEL PUENTE ANGUIANO'], dtype=object)

# %%
# Se trata de 57, antes 43 operadores, que por sí solos son pequeños operadores o pertenecen a un GIE pequeño. 

lista_empresas_cluster_pequeños_2 = ingresos[ingresos['GRUPO'].isin(lista_cluster_pequeños_2)].sort_values(by=['INGRESOS_TOTAL_E'], ascending = False)

lista_empresas_cluster_pequeños_2.to_csv("Empresas_pequeñas_c2.csv", encoding="Latin1")

lista_empresas_cluster_pequeños_2
# Out:
#                                          CONCESIONARIO  \
# 158              TELECABLE DE VILLANUEVA, S.A. DE C.V.
# 65                               GABRIEL BUTRON CHIAPA
# 152              TELECABLE DE EL NARANJO, S.A. DE C.V.
# 136                     SISCAB DE MEXICO, S.A. DE C.V.
# 122      RADIO FRECUENCIAS CONCESIONADAS, S.A. DE C.V.
# 88                          JACE TELECOM, S.A. DE C.V.
# 74                            GUILLERMO MEDELLIN MILAN
# 185               VALOR AGREGADO DIGITAL, S.A. DE C.V.
# 134    SIERRA NORTE TELEVISION POR CABLE, S.A. DE C.V.
# 142                             STAR NET, S.A. DE C.V.
# 94                 KING DAVID MOBILE, S.A.P.I. DE C.V.
# 4                                 AGUSTIN PEREZ VIEYRA
# 138          SISTEMAS ESPECIALES DE COMUNICACION, S.A.
# 84          INTEGRA COMUNICACIONES, S. DE R.L. DE C.V.
# 67                        GO 3PLAY, S. DE R.L. DE C.V.
# 174      TELEVISION POR CABLE DE MUZQUIZ, S.A. DE C.V.
# 11                           ARELY ISABEL GONGORA PECH
# 144                    SUCN. DE HORTENSIA TOSCANO MORA
# 143  STARLINK SATELLITE SYSTEMS MEXICO, S. DE R.L. ...
# 147                              TELECAB, S.A. DE C.V.
# 128                                ROBERTO LOPEZ BRAVO
# 43         CONSORCIO JAGO COMUNICACIONES, S.A. DE C.V.
# 105                        MARKETING 358, S.A. DE C.V.
# 41                            CONCABLETV, S.A. DE C.V.
# 90                     JESUS MIGUEL FERNANDEZ GUERRERO
# 170     TELESISTEMAS Y REDES MEXIQUENSES, S.A. DE C.V.
# 102                                 MANUEL LOPEZ AVILA
# 86            INTERCABLE DEL MAYAB, S. DE R.L. DE C.V.
# 44     CONVERGENCIA Y DESARROLLO DIGITAL, S.A. DE C.V.
# 53                               DANIEL GARCIA GODINEZ
# 164    TELECOMUNICACIONES DIVERSIFICADAS, S.A. DE C.V.
# 60   ENTRETENIMIENTO Y TELECOMUNICACIONES, S.A. DE ...
# 75                             GUILLERMO ZARATE GARCIA
# 92                        JOSE JULIAN SACRAMENTO GARZA
# 115                              OBDULIA NAVA BECERRIL
# 124                           RAFAEL SANCHEZ NAZARIEGA
# 51                               CRO.NET, S.A. DE C.V.
# 137                SISTEMA DE CABLE HKAN, S.A. DE C.V.
# 21                   CABLE SALTO DE AGUA, S.A. DE C.V.
# 42   CONSORCIO DE RADIODIFUSORAS DE MEXICO, S.A. DE...
# 61                             ES TV COM, S.A. DE C.V.
# 95                          KUBO CEL, S.A.P.I. DE C.V.
# 93                      JOSÉ ASCENCIÓN GODÍNEZ RAMÍREZ
# 178                               TOMAS CRISTOBAL CRUZ
# 22              CABLE SISTEMA DEL CENTRO, S.A. DE C.V.
# 89                               JAIME SANCHEZ SANCHEZ
# 140  SOLUCIONES Y ASESORIA EN COBRANZA, S. DE R.L. ...
# 114                               NORMA GUTIERREZ FONG
# 68          GRUPO CORPORATIVO ZUNUN PAZ, S. A. DE C.V.
# 177                         TELMOV MOVIL, S.A. DE C.V.
# 17         BROCOMUNICACIONES MOVILES, S.A.P.I. DE C.V.
# 34                         CITRO TELECOM, S.A. DE C.V.
# 56                               EDUARDO PEDRERO PEREZ
# 70          GRUPO MAGERCA COMUNICACIONES, S.A. DE C.V.
# 38                                COMNET, S.A. DE C.V.
# 126                     REX MOVIL MEXICO, S.A. DE C.V.
# 81                           HUGO ABEL PUENTE ANGUIANO
#
#                                                EMPRESA  \
# 158                            TELECABLE DE VILLANUEVA
# 65                               GABRIEL BUTRON CHIAPA
# 152                            TELECABLE DE EL NARANJO
# 136                                   SISCAB DE MEXICO
# 122                    RADIO FRECUENCIAS CONCESIONADAS
# 88                                        JACE TELECOM
# 74                            GUILLERMO MEDELLIN MILAN
# 185                                              VADSA
# 134                                           SINOTECA
# 142                                           STAR NET
# 94                                                MIIO
# 4                                 AGUSTIN PEREZ VIEYRA
# 138                                              SECSA
# 84                              INTEGRA COMUNICACIONES
# 67                                                GOBO
# 174                                         TV MUZQUIZ
# 11                           ARELY ISABEL GONGORA PECH
# 144                             TELECABLE DE AGUILILLA
# 143                                    SPACEX-STARLINK
# 147                                            TELECAB
# 128                                ROBERTO LOPEZ BRAVO
# 43                       CONSORCIO JAGO COMUNICACIONES
# 105                                      MARKETING 358
# 41                                          CONCABLETV
# 90                     JESUS MIGUEL FERNANDEZ GUERRERO
# 170                                              ESPID
# 102                                 MANUEL LOPEZ AVILA
# 86                                INTERCABLE DEL MAYAB
# 44                                             RED DOG
# 53                               DANIEL GARCIA GODINEZ
# 164                  TELECOMUNICACIONES DIVERSIFICADAS
# 60                ENTRETENIMIENTO Y TELECOMUNICACIONES
# 75                             GUILLERMO ZARATE GARCIA
# 92                        JOSE JULIAN SACRAMENTO GARZA
# 115                          CABLEVISION DE LA HUACANA
# 124                           RAFAEL SANCHEZ NAZARIEGA
# 51                                             CRO.NET
# 137                              SISTEMA DE CABLE HKAN
# 21                                CABLE SALTO DEL AGUA
# 42                                                TV-K
# 61                                           ES TV COM
# 95                                             QBO CEL
# 93   TELECABLE DE MARIANO ESCOBEDO Y SAN AGUSTIN DE...
# 178                               TOMAS CRISTOBAL CRUZ
# 22                            CABLE SISTEMA DEL CENTRO
# 89                               JAIME SANCHEZ SANCHEZ
# 140                                       IGOU TELECOM
# 114                               NORMA GUTIERREZ FONG
# 68                         GRUPO CORPORATIVO ZUNUN PAZ
# 177                                           TELMOVIL
# 17                                            BROMOVIL
# 34                                       CITRO TELECOM
# 56                               EDUARDO PEDRERO PEREZ
# 70                                    AXIA CABLECENTRO
# 38                                              COMNET
# 126                                          REX MOVIL
# 81                           HUGO ABEL PUENTE ANGUIANO
#
#                                     GRUPO  INGRESOS_TOTAL_E
# 158               TELECABLE DE VILLANUEVA           4355978
# 65                  GABRIEL BUTRON CHIAPA           4266116
# 152               TELECABLE DE EL NARANJO           4135348
# 136                      SISCAB DE MEXICO           4003498
# 122       RADIO FRECUENCIAS CONCESIONADAS           3778876
# 88                           JACE TELECOM           3300058
# 74               GUILLERMO MEDELLIN MILAN           3273959
# 185                                 VADSA           3185056
# 134                              SINOTECA           3063188
# 142                              STAR NET           2856870
# 94                                   MIIO           2831967
# 4                    AGUSTIN PEREZ VIEYRA           2726562
# 138                                 SECSA           2717734
# 84                 INTEGRA COMUNICACIONES           2598078
# 67                                   GOBO           2598078
# 174       TELEVISION POR CABLE DE MUZQUIZ           2586948
# 11              ARELY ISABEL GONGORA PECH           2497203
# 144                TELECABLE DE AGUILILLA           2460597
# 143                       SPACEX-STARLINK           2437290
# 147                               TELECAB           2365984
# 128                   ROBERTO LOPEZ BRAVO           2364695
# 43          CONSORCIO JAGO COMUNICACIONES           2349000
# 105                         MARKETING 358           2323024
# 41                             CONCABLETV           2288255
# 90        JESUS MIGUEL FERNANDEZ GUERRERO           2279442
# 170                                 ESPID           2251969
# 102                    MANUEL LOPEZ AVILA           2199560
# 86                   INTERCABLE DEL MAYAB           2185596
# 44                                RED DOG           2144622
# 53                  DANIEL GARCIA GODINEZ           2125416
# 164     TELECOMUNICACIONES DIVERSIFICADAS           1995007
# 60   ENTRETENIMIENTO Y TELECOMUNICACIONES           1808790
# 75                GUILLERMO ZARATE GARCIA           1765345
# 92           JOSE JULIAN SACRAMENTO GARZA           1533408
# 115             CABLEVISION DE LA HUACANA           1515931
# 124              RAFAEL SANCHEZ NAZARIEGA           1454506
# 51                                CRO.NET           1425388
# 137                 SISTEMA DE CABLE HKAN           1295765
# 21                   CABLE SALTO DEL AGUA           1191496
# 42                                   TV-K           1094570
# 61                              ES TV COM           1008023
# 95                                QBO CEL            998133
# 93          TELECABLE DE MARIANO ESCOBEDO            568497
# 178                  TOMAS CRISTOBAL CRUZ            548000
# 22               CABLE SISTEMA DEL CENTRO            474403
# 89                  JAIME SANCHEZ SANCHEZ            474403
# 140                          IGOU TELECOM            424046
# 114                  NORMA GUTIERREZ FONG            411324
# 68            GRUPO CORPORATIVO ZUNUN PAZ            340986
# 177                              TELMOVIL            332069
# 17                               BROMOVIL            320585
# 34                          CITRO TELECOM            123094
# 56                  EDUARDO PEDRERO PEREZ             68200
# 70                       AXIA CABLECENTRO             43500
# 38                                 COMNET             43293
# 126                             REX MOVIL             11422
# 81              HUGO ABEL PUENTE ANGUIANO              2845

# %%
total_ingresos = ingresos_agrupados_transformables["INGRESOS_TOTAL_E"].sum()
ingreos_grandes= lista_empresas_cluster_grande["INGRESOS_TOTAL_E"].sum()
ingresos_medianas = lista_empresas_cluster_medianos["INGRESOS_TOTAL_E"].sum()
ingresos_pequeñas1 = lista_empresas_cluster_pequeños_1["INGRESOS_TOTAL_E"].sum()
ingresos_pequeñas2 = lista_empresas_cluster_pequeños_2["INGRESOS_TOTAL_E"].sum()

print(f"El 14.8% del total de empresas(cluster empresas grandes) generan el {round(ingreos_grandes/total_ingresos*100,2)}% de los ingresos")
print(f"El 19.9% del total de empresas (cluster empresas medianas) generan el {round(ingresos_medianas/total_ingresos*100,2)}% de los ingresos")
print(f"El 62.5% del total de empresas (cluster empresas pequeñas 1 y 2) generan el {round((ingresos_pequeñas1+ingresos_pequeñas2)/total_ingresos*100,2)}% de los ingresos")
# Out:
# El 17.6% del total de empresas(cluster empresas grandes) generan el 98.38% de los ingresos
# El 19.9% del total de empresas (cluster empresas medianas) generan el 1.38% de los ingresos
# El 62.5% del total de empresas (cluster empresas pequeñas 1 y 2) generan el 0.23% de los ingresos

# %%
# Análisis con quartiles y rango intercuantil para efectos de identificar los outliers

quartiles = lista_empresas_cluster_pequeños_1["INGRESOS_TOTAL_E"].quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

print(f"El cuartil más bajo de los ingresos es: {lowerq}")
print(f"El cuartil más alto de los ingresos es: {upperq}")
print(f"El rango intercuantil de los ingresos es: {iqr}")
print(f"El ingreso medio es: {quartiles[0.5]} ")


lower_bound = lowerq - (2.4*iqr)
upper_bound = upperq + (2.4*iqr) # se circunscribe al 95.44% de los datos.
print(f"Umbral final donde los valores por encima de {upper_bound} no son elegibles.")
# Out:
# El cuartil más bajo de los ingresos es: 7935550.5375
# El cuartil más alto de los ingresos es: 22899709.945
# El rango intercuantil de los ingresos es: 14964159.4075
# El ingreso medio es: 13283710.895
# Umbral final donde los valores por encima de 58813692.523 no son elegibles.

# %% [markdown]
# # Conclusiones
#
# ### <font color="green"> El umbral para ser elegible como pequeño operador implica ingresos nominales acumulados al cierre de 2021 menores o iguales a <font color="red"> MX$58,813,692</font>, para efectos de garantizar que la empresa en cuestión se encuentra dentro de alguno de los dos clusters identificados por su ingreso relativamente pequeño.
#
# - Con base en los datos del BIT se registran 121 empresas con ingresos menores o iguales al umbral definido. Esto equivale al 66.5% de todas las empresas.
#
# - El 14.8% del total de empresas (cluster empresas grandes) generan el 98.38% de los ingresos.
#
# - El 18.7% del total de empresas (cluster empresas medianas) generan el 1.38% de los ingresos.
#
# - El 66.48% del total de empresas (cluster empresas pequeñas 1 y 2) generan el 0.23% de los ingresos.
#
# - La definición de este umbral con base en una técnica confiable y robusta permite contar con un criterio cuantitativo y objetivo sobre lo que se debe considerar como un operador elegible para participar en el Comité de Pequeños Operadores.
#
# -  Se trata de un criterio claro, transparente y replicable, que brinda certeza jurídica y confianza al sector.
#
# </font>
